# %% [markdown]
# <a href="https://colab.research.google.com/github/DineshJoshi2/Hydrological-Residual-Error-Modelling/blob/main/SimpleRNNs_ONLY_for_3_Year_Training_and_3_year_testing_Data_(HYDROLOGICAL_RESIDUAL_ERROR_MODELLING).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# for reproducibility of the code
import os
os.environ["PYTHONHASHSEED"] = "0"
import numpy as np
import random as rn
import tensorflow as tf
# setting the seed for numpy generated random numbers
np.random.seed(73)
# setting the seed for python random number
rn.seed(723)
# setting the seed for tensorflow random number
tf.random.set_seed(1)

# %%
# importing necessary libraries
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras import optimizers
from tensorflow.keras.layers import Dropout
from tensorflow.keras.constraints import MaxNorm
from sklearn.model_selection import GridSearchCV

# %%
# loading data set
df= pd.read_csv("/content/drive/MyDrive/Data/OneYearResidualErrorModelling.csv")
df=df[365:].reset_index(drop=True)

# %%
# Retriving the necessary columns from the datasets.
 df=df[['Temperature (Deg C)', 'Precipitation (mm)',
       'Precipitation0816 (mm)', 'Temperature0816 (Deg C)', 'Observed Discharge (m3/s)']]

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error

# %%
# extrating the vaules from the data frame
values = df.values
values
# change all datatype to float
values = values.astype('float32')

# %%
# normalization all features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)

# %%
#converting the data into 3D array
l=[]
for i in range(len(scaled)-365):
    l.append(scaled[i:366+i,:])
Data=np.array(l)

# %%
# checking the shape of the data
Data.shape
# Out:
# (2192, 366, 5)

# %%
## test and train data
X=Data[:,:,:-1]
y=Data[:,-1,-1]
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.50, shuffle =False)
#four year test_size 0.50
#One year test_size 0.833

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1096, 366, 4)
# (1096, 366, 4)
# (1096,)
# (1096,)

# %%
# Useful functions to undo normalization later
def inv_yhat(yhat):
  yhat=[i[0] for i in yhat]
  A=np.zeros((len(yhat),5))
  A[:,0]=yhat
  A[:,1]=yhat
  A[:,2]=yhat
  A[:,3]=yhat
  A[:,4]=yhat
  inv_yhat= scaler.inverse_transform(A)
  inv_yhat = [i[-1] for i in inv_yhat]
  return inv_yhat
def inv_y(y):
  A=np.zeros((len(y),5))
  A[:,0]=y
  A[:,1]=y
  A[:,2]=y
  A[:,3]=y
  A[:,4]=y
  inv_y= scaler.inverse_transform(A)
  inv_y = [i[-1] for i in inv_y]
  return inv_y

# %%
# Importing necessary libraries
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import GRU,SimpleRNN
from keras import optimizers
from tensorflow.keras.layers import Dropout
from tensorflow.keras.constraints import MaxNorm
from sklearn.model_selection import GridSearchCV

# %%
# Defining Some model parameters
epochs=1000
learning_rate1 = 0.01
decay_rate = (learning_rate1*64)/epochs

# %%
# for reproducibility of the code
import os
os.environ["PYTHONHASHSEED"] = "0"
import numpy as np
import random as rn
import tensorflow as tf
# setting the seed for numpy generated random numbers
np.random.seed(73)
# setting the seed for python random number
rn.seed(723)
# setting the seed for tensorflow random number
tf.random.set_seed(1)

# %%
# Building The Main Model
model = Sequential()
model.add(SimpleRNN(32,kernel_initializer="GlorotUniform",return_sequences=False,input_shape=(X_train.shape[1], X_train.shape[2]))) # main model
model.add(Dense(1))
#lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(initial_learning_rate=1e-2,decay_steps=1000,decay_rate=0.9)
Adam=tf.keras.optimizers.Adam(learning_rate = learning_rate1, beta_1 = 0.9, beta_2 = 0.999, amsgrad = False)
model.compile(loss="mae", optimizer=Adam, metrics=[tf.keras.metrics.MeanAbsoluteError()])

# %%
#Add Callbacks, e.g. ModelCheckpoints, earlystopping, csvlogger.
from keras.callbacks import ModelCheckpoint, EarlyStopping, CSVLogger,LearningRateScheduler

#ModelCheckpoint callback saves a model at some interval.
filepath="saved_models/weights-improvement-{epoch:02d}-{val_acc:.2f}.hdf5" #File name includes epoch and validation accuracy.
#Use Mode = max for accuracy and min for loss.
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

#https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/EarlyStopping
early_stop = EarlyStopping(monitor='val_loss',min_delta=0.0001, patience= 100,verbose=1,restore_best_weights=True)
#This callback will stop the training when there is no improvement in
# the validation loss for three consecutive epochs.

#CSVLogger logs epoch, acc, loss, val_acc, val_loss
log_csv = CSVLogger("/content/drive/MyDrive/Data/LSTMlogs.csv", separator=',', append=False)

#learning rate decay
def exp_decay(epoch):
  lrate = learning_rate1 * np.exp(-decay_rate*epoch)
  return lrate

# learning schedule callback
lr_rate = LearningRateScheduler(exp_decay)

callbacks_list = [early_stop,lr_rate]

# %%
# Training The Model
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs =epochs ,callbacks=callbacks_list, batch_size=len(X_train), verbose = 2, shuffle = True)
# Out:
# Epoch 1/1000
# 1/1 - 1s - loss: 0.3567 - mean_absolute_error: 0.3567 - val_loss: 0.6642 - val_mean_absolute_error: 0.6642 - lr: 0.0100 - 873ms/epoch - 873ms/step
# Epoch 2/1000
# 1/1 - 0s - loss: 0.7049 - mean_absolute_error: 0.7049 - val_loss: 0.2768 - val_mean_absolute_error: 0.2768 - lr: 0.0100 - 126ms/epoch - 126ms/step
# Epoch 3/1000
# 1/1 - 0s - loss: 0.3081 - mean_absolute_error: 0.3081 - val_loss: 0.2129 - val_mean_absolute_error: 0.2129 - lr: 0.0100 - 127ms/epoch - 127ms/step
# Epoch 4/1000
# 1/1 - 0s - loss: 0.1999 - mean_absolute_error: 0.1999 - val_loss: 0.2751 - val_mean_absolute_error: 0.2751 - lr: 0.0100 - 122ms/epoch - 122ms/step
# Epoch 5/1000
# 1/1 - 0s - loss: 0.2501 - mean_absolute_error: 0.2501 - val_loss: 0.1598 - val_mean_absolute_error: 0.1598 - lr: 0.0100 - 124ms/epoch - 124ms/step
# Epoch 6/1000
# 1/1 - 0s - loss: 0.1329 - mean_absolute_error: 0.1329 - val_loss: 0.1853 - val_mean_absolute_error: 0.1853 - lr: 0.0100 - 137ms/epoch - 137ms/step
# Epoch 7/1000
# 1/1 - 0s - loss: 0.1645 - mean_absolute_error: 0.1645 - val_loss: 0.2226 - val_mean_absolute_error: 0.2226 - lr: 0.0100 - 137ms/epoch - 137ms/step
# Epoch 8/1000
# 1/1 - 0s - loss: 0.2021 - mean_absolute_error: 0.2021 - val_loss: 0.1973 - val_mean_absolute_error: 0.1973 - lr: 0.0100 - 125ms/epoch - 125ms/step
# Epoch 9/1000
# 1/1 - 0s - loss: 0.1688 - mean_absolute_error: 0.1688 - val_loss: 0.1632 - val_mean_absolute_error: 0.1632 - lr: 0.0099 - 126ms/epoch - 126ms/step
# Epoch 10/1000
# 1/1 - 0s - loss: 0.1274 - mean_absolute_error: 0.1274 - val_loss: 0.1994 - val_mean_absolute_error: 0.1994 - lr: 0.0099 - 123ms/epoch - 123ms/step
# Epoch 11/1000
# 1/1 - 0s - loss: 0.1660 - mean_absolute_error: 0.1660 - val_loss: 0.1895 - val_mean_absolute_error: 0.1895 - lr: 0.0099 - 126ms/epoch - 126ms/step
# Epoch 12/1000
# 1/1 - 0s - loss: 0.1559 - mean_absolute_error: 0.1559 - val_loss: 0.1399 - val_mean_absolute_error: 0.1399 - lr: 0.0099 - 131ms/epoch - 131ms/step
# Epoch 13/1000
# 1/1 - 0s - loss: 0.1063 - mean_absolute_error: 0.1063 - val_loss: 0.1398 - val_mean_absolute_error: 0.1398 - lr: 0.0099 - 129ms/epoch - 129ms/step
# Epoch 14/1000
# 1/1 - 0s - loss: 0.1140 - mean_absolute_error: 0.1140 - val_loss: 0.1402 - val_mean_absolute_error: 0.1402 - lr: 0.0099 - 140ms/epoch - 140ms/step
# Epoch 15/1000
# 1/1 - 0s - loss: 0.1217 - mean_absolute_error: 0.1217 - val_loss: 0.1251 - val_mean_absolute_error: 0.1251 - lr: 0.0099 - 124ms/epoch - 124ms/step
# Epoch 16/1000
# 1/1 - 0s - loss: 0.1067 - mean_absolute_error: 0.1067 - val_loss: 0.1216 - val_mean_absolute_error: 0.1216 - lr: 0.0099 - 131ms/epoch - 131ms/step
# Epoch 17/1000
# 1/1 - 0s - loss: 0.0974 - mean_absolute_error: 0.0974 - val_loss: 0.1373 - val_mean_absolute_error: 0.1373 - lr: 0.0099 - 125ms/epoch - 125ms/step
# Epoch 18/1000
# 1/1 - 0s - loss: 0.1082 - mean_absolute_error: 0.1082 - val_loss: 0.1428 - val_mean_absolute_error: 0.1428 - lr: 0.0099 - 125ms/epoch - 125ms/step
# Epoch 19/1000
# 1/1 - 0s - loss: 0.1123 - mean_absolute_error: 0.1123 - val_loss: 0.1289 - val_mean_absolute_error: 0.1289 - lr: 0.0099 - 122ms/epoch - 122ms/step
# Epoch 20/1000
# 1/1 - 0s - loss: 0.1007 - mean_absolute_error: 0.1007 - val_loss: 0.1160 - val_mean_absolute_error: 0.1160 - lr: 0.0099 - 127ms/epoch - 127ms/step
# Epoch 21/1000
# 1/1 - 0s - loss: 0.0938 - mean_absolute_error: 0.0938 - val_loss: 0.1127 - val_mean_absolute_error: 0.1127 - lr: 0.0099 - 139ms/epoch - 139ms/step
# Epoch 22/1000
# 1/1 - 0s - loss: 0.0987 - mean_absolute_error: 0.0987 - val_loss: 0.1125 - val_mean_absolute_error: 0.1125 - lr: 0.0099 - 129ms/epoch - 129ms/step
# Epoch 23/1000
# 1/1 - 0s - loss: 0.0989 - mean_absolute_error: 0.0989 - val_loss: 0.1111 - val_mean_absolute_error: 0.1111 - lr: 0.0099 - 125ms/epoch - 125ms/step
# Epoch 24/1000
# 1/1 - 0s - loss: 0.0900 - mean_absolute_error: 0.0900 - val_loss: 0.1147 - val_mean_absolute_error: 0.1147 - lr: 0.0099 - 183ms/epoch - 183ms/step
# Epoch 25/1000
# 1/1 - 0s - loss: 0.0870 - mean_absolute_error: 0.0870 - val_loss: 0.1206 - val_mean_absolute_error: 0.1206 - lr: 0.0098 - 209ms/epoch - 209ms/step
# Epoch 26/1000
# 1/1 - 0s - loss: 0.0899 - mean_absolute_error: 0.0899 - val_loss: 0.1223 - val_mean_absolute_error: 0.1223 - lr: 0.0098 - 193ms/epoch - 193ms/step
# Epoch 27/1000
# 1/1 - 0s - loss: 0.0906 - mean_absolute_error: 0.0906 - val_loss: 0.1181 - val_mean_absolute_error: 0.1181 - lr: 0.0098 - 204ms/epoch - 204ms/step
# Epoch 28/1000
# 1/1 - 0s - loss: 0.0870 - mean_absolute_error: 0.0870 - val_loss: 0.1154 - val_mean_absolute_error: 0.1154 - lr: 0.0098 - 201ms/epoch - 201ms/step
# Epoch 29/1000
# 1/1 - 0s - loss: 0.0861 - mean_absolute_error: 0.0861 - val_loss: 0.1143 - val_mean_absolute_error: 0.1143 - lr: 0.0098 - 198ms/epoch - 198ms/step
# Epoch 30/1000
# 1/1 - 0s - loss: 0.0868 - mean_absolute_error: 0.0868 - val_loss: 0.1116 - val_mean_absolute_error: 0.1116 - lr: 0.0098 - 235ms/epoch - 235ms/step
# Epoch 31/1000
# 1/1 - 0s - loss: 0.0843 - mean_absolute_error: 0.0843 - val_loss: 0.1090 - val_mean_absolute_error: 0.1090 - lr: 0.0098 - 216ms/epoch - 216ms/step
# Epoch 32/1000
# 1/1 - 0s - loss: 0.0806 - mean_absolute_error: 0.0806 - val_loss: 0.1095 - val_mean_absolute_error: 0.1095 - lr: 0.0098 - 223ms/epoch - 223ms/step
# Epoch 33/1000
# 1/1 - 0s - loss: 0.0798 - mean_absolute_error: 0.0798 - val_loss: 0.1109 - val_mean_absolute_error: 0.1109 - lr: 0.0098 - 212ms/epoch - 212ms/step
# Epoch 34/1000
# 1/1 - 0s - loss: 0.0807 - mean_absolute_error: 0.0807 - val_loss: 0.1092 - val_mean_absolute_error: 0.1092 - lr: 0.0098 - 210ms/epoch - 210ms/step
# Epoch 35/1000
# 1/1 - 0s - loss: 0.0804 - mean_absolute_error: 0.0804 - val_loss: 0.1054 - val_mean_absolute_error: 0.1054 - lr: 0.0098 - 204ms/epoch - 204ms/step
# Epoch 36/1000
# 1/1 - 0s - loss: 0.0795 - mean_absolute_error: 0.0795 - val_loss: 0.1030 - val_mean_absolute_error: 0.1030 - lr: 0.0098 - 206ms/epoch - 206ms/step
# Epoch 37/1000
# 1/1 - 0s - loss: 0.0794 - mean_absolute_error: 0.0794 - val_loss: 0.1026 - val_mean_absolute_error: 0.1026 - lr: 0.0098 - 220ms/epoch - 220ms/step
# Epoch 38/1000
# 1/1 - 0s - loss: 0.0772 - mean_absolute_error: 0.0772 - val_loss: 0.1040 - val_mean_absolute_error: 0.1040 - lr: 0.0098 - 203ms/epoch - 203ms/step
# Epoch 39/1000
# 1/1 - 0s - loss: 0.0749 - mean_absolute_error: 0.0749 - val_loss: 0.1063 - val_mean_absolute_error: 0.1063 - lr: 0.0098 - 206ms/epoch - 206ms/step
# Epoch 40/1000
# 1/1 - 0s - loss: 0.0745 - mean_absolute_error: 0.0745 - val_loss: 0.1074 - val_mean_absolute_error: 0.1074 - lr: 0.0098 - 283ms/epoch - 283ms/step
# Epoch 41/1000
# 1/1 - 0s - loss: 0.0742 - mean_absolute_error: 0.0742 - val_loss: 0.1069 - val_mean_absolute_error: 0.1069 - lr: 0.0097 - 317ms/epoch - 317ms/step
# Epoch 42/1000
# 1/1 - 0s - loss: 0.0738 - mean_absolute_error: 0.0738 - val_loss: 0.1055 - val_mean_absolute_error: 0.1055 - lr: 0.0097 - 220ms/epoch - 220ms/step
# Epoch 43/1000
# 1/1 - 0s - loss: 0.0729 - mean_absolute_error: 0.0729 - val_loss: 0.1032 - val_mean_absolute_error: 0.1032 - lr: 0.0097 - 128ms/epoch - 128ms/step
# Epoch 44/1000
# 1/1 - 0s - loss: 0.0710 - mean_absolute_error: 0.0710 - val_loss: 0.1010 - val_mean_absolute_error: 0.1010 - lr: 0.0097 - 157ms/epoch - 157ms/step
# Epoch 45/1000
# 1/1 - 0s - loss: 0.0689 - mean_absolute_error: 0.0689 - val_loss: 0.0993 - val_mean_absolute_error: 0.0993 - lr: 0.0097 - 127ms/epoch - 127ms/step
# Epoch 46/1000
# 1/1 - 0s - loss: 0.0683 - mean_absolute_error: 0.0683 - val_loss: 0.0963 - val_mean_absolute_error: 0.0963 - lr: 0.0097 - 128ms/epoch - 128ms/step
# Epoch 47/1000
# 1/1 - 0s - loss: 0.0676 - mean_absolute_error: 0.0676 - val_loss: 0.0941 - val_mean_absolute_error: 0.0941 - lr: 0.0097 - 137ms/epoch - 137ms/step
# Epoch 48/1000
# 1/1 - 0s - loss: 0.0667 - mean_absolute_error: 0.0667 - val_loss: 0.0947 - val_mean_absolute_error: 0.0947 - lr: 0.0097 - 124ms/epoch - 124ms/step
# Epoch 49/1000
# 1/1 - 0s - loss: 0.0640 - mean_absolute_error: 0.0640 - val_loss: 0.0965 - val_mean_absolute_error: 0.0965 - lr: 0.0097 - 155ms/epoch - 155ms/step
# Epoch 50/1000
# 1/1 - 0s - loss: 0.0631 - mean_absolute_error: 0.0631 - val_loss: 0.0957 - val_mean_absolute_error: 0.0957 - lr: 0.0097 - 125ms/epoch - 125ms/step
# Epoch 51/1000
# 1/1 - 0s - loss: 0.0622 - mean_absolute_error: 0.0622 - val_loss: 0.0924 - val_mean_absolute_error: 0.0924 - lr: 0.0097 - 121ms/epoch - 121ms/step
# Epoch 52/1000
# 1/1 - 0s - loss: 0.0613 - mean_absolute_error: 0.0613 - val_loss: 0.0898 - val_mean_absolute_error: 0.0898 - lr: 0.0097 - 130ms/epoch - 130ms/step
# Epoch 53/1000
# 1/1 - 0s - loss: 0.0593 - mean_absolute_error: 0.0593 - val_loss: 0.0888 - val_mean_absolute_error: 0.0888 - lr: 0.0097 - 126ms/epoch - 126ms/step
# Epoch 54/1000
# 1/1 - 0s - loss: 0.0580 - mean_absolute_error: 0.0580 - val_loss: 0.0850 - val_mean_absolute_error: 0.0850 - lr: 0.0097 - 136ms/epoch - 136ms/step
# Epoch 55/1000
# 1/1 - 0s - loss: 0.0571 - mean_absolute_error: 0.0571 - val_loss: 0.0797 - val_mean_absolute_error: 0.0797 - lr: 0.0097 - 131ms/epoch - 131ms/step
# Epoch 56/1000
# 1/1 - 0s - loss: 0.0553 - mean_absolute_error: 0.0553 - val_loss: 0.0807 - val_mean_absolute_error: 0.0807 - lr: 0.0097 - 124ms/epoch - 124ms/step
# Epoch 57/1000
# 1/1 - 0s - loss: 0.0523 - mean_absolute_error: 0.0523 - val_loss: 0.0815 - val_mean_absolute_error: 0.0815 - lr: 0.0096 - 124ms/epoch - 124ms/step
# Epoch 58/1000
# 1/1 - 0s - loss: 0.0508 - mean_absolute_error: 0.0508 - val_loss: 0.0771 - val_mean_absolute_error: 0.0771 - lr: 0.0096 - 130ms/epoch - 130ms/step
# Epoch 59/1000
# 1/1 - 0s - loss: 0.0490 - mean_absolute_error: 0.0490 - val_loss: 0.0742 - val_mean_absolute_error: 0.0742 - lr: 0.0096 - 126ms/epoch - 126ms/step
# Epoch 60/1000
# 1/1 - 0s - loss: 0.0461 - mean_absolute_error: 0.0461 - val_loss: 0.0716 - val_mean_absolute_error: 0.0716 - lr: 0.0096 - 124ms/epoch - 124ms/step
# Epoch 61/1000
# 1/1 - 0s - loss: 0.0455 - mean_absolute_error: 0.0455 - val_loss: 0.0677 - val_mean_absolute_error: 0.0677 - lr: 0.0096 - 125ms/epoch - 125ms/step
# Epoch 62/1000
# 1/1 - 0s - loss: 0.0448 - mean_absolute_error: 0.0448 - val_loss: 0.0723 - val_mean_absolute_error: 0.0723 - lr: 0.0096 - 139ms/epoch - 139ms/step
# Epoch 63/1000
# 1/1 - 0s - loss: 0.0440 - mean_absolute_error: 0.0440 - val_loss: 0.0683 - val_mean_absolute_error: 0.0683 - lr: 0.0096 - 132ms/epoch - 132ms/step
# Epoch 64/1000
# 1/1 - 0s - loss: 0.0432 - mean_absolute_error: 0.0432 - val_loss: 0.0638 - val_mean_absolute_error: 0.0638 - lr: 0.0096 - 155ms/epoch - 155ms/step
# Epoch 65/1000
# 1/1 - 0s - loss: 0.0422 - mean_absolute_error: 0.0422 - val_loss: 0.0627 - val_mean_absolute_error: 0.0627 - lr: 0.0096 - 129ms/epoch - 129ms/step
# Epoch 66/1000
# 1/1 - 0s - loss: 0.0424 - mean_absolute_error: 0.0424 - val_loss: 0.0630 - val_mean_absolute_error: 0.0630 - lr: 0.0096 - 230ms/epoch - 230ms/step
# Epoch 67/1000
# 1/1 - 0s - loss: 0.0455 - mean_absolute_error: 0.0455 - val_loss: 0.0779 - val_mean_absolute_error: 0.0779 - lr: 0.0096 - 237ms/epoch - 237ms/step
# Epoch 68/1000
# 1/1 - 0s - loss: 0.0545 - mean_absolute_error: 0.0545 - val_loss: 0.0643 - val_mean_absolute_error: 0.0643 - lr: 0.0096 - 334ms/epoch - 334ms/step
# Epoch 69/1000
# 1/1 - 1s - loss: 0.0535 - mean_absolute_error: 0.0535 - val_loss: 0.0625 - val_mean_absolute_error: 0.0625 - lr: 0.0096 - 593ms/epoch - 593ms/step
# Epoch 70/1000
# 1/1 - 1s - loss: 0.0428 - mean_absolute_error: 0.0428 - val_loss: 0.0640 - val_mean_absolute_error: 0.0640 - lr: 0.0096 - 629ms/epoch - 629ms/step
# Epoch 71/1000
# 1/1 - 0s - loss: 0.0437 - mean_absolute_error: 0.0437 - val_loss: 0.0617 - val_mean_absolute_error: 0.0617 - lr: 0.0096 - 457ms/epoch - 457ms/step
# Epoch 72/1000
# 1/1 - 1s - loss: 0.0505 - mean_absolute_error: 0.0505 - val_loss: 0.0710 - val_mean_absolute_error: 0.0710 - lr: 0.0096 - 964ms/epoch - 964ms/step
# Epoch 73/1000
# 1/1 - 1s - loss: 0.0479 - mean_absolute_error: 0.0479 - val_loss: 0.0590 - val_mean_absolute_error: 0.0590 - lr: 0.0095 - 665ms/epoch - 665ms/step
# Epoch 74/1000
# 1/1 - 1s - loss: 0.0400 - mean_absolute_error: 0.0400 - val_loss: 0.0584 - val_mean_absolute_error: 0.0584 - lr: 0.0095 - 637ms/epoch - 637ms/step
# Epoch 75/1000
# 1/1 - 0s - loss: 0.0394 - mean_absolute_error: 0.0394 - val_loss: 0.0696 - val_mean_absolute_error: 0.0696 - lr: 0.0095 - 451ms/epoch - 451ms/step
# Epoch 76/1000
# 1/1 - 0s - loss: 0.0448 - mean_absolute_error: 0.0448 - val_loss: 0.0629 - val_mean_absolute_error: 0.0629 - lr: 0.0095 - 407ms/epoch - 407ms/step
# Epoch 77/1000
# 1/1 - 0s - loss: 0.0497 - mean_absolute_error: 0.0497 - val_loss: 0.0643 - val_mean_absolute_error: 0.0643 - lr: 0.0095 - 292ms/epoch - 292ms/step
# Epoch 78/1000
# 1/1 - 0s - loss: 0.0385 - mean_absolute_error: 0.0385 - val_loss: 0.0683 - val_mean_absolute_error: 0.0683 - lr: 0.0095 - 453ms/epoch - 453ms/step
# Epoch 79/1000
# 1/1 - 1s - loss: 0.0428 - mean_absolute_error: 0.0428 - val_loss: 0.0636 - val_mean_absolute_error: 0.0636 - lr: 0.0095 - 591ms/epoch - 591ms/step
# Epoch 80/1000
# 1/1 - 1s - loss: 0.0525 - mean_absolute_error: 0.0525 - val_loss: 0.0681 - val_mean_absolute_error: 0.0681 - lr: 0.0095 - 627ms/epoch - 627ms/step
# Epoch 81/1000
# 1/1 - 1s - loss: 0.0402 - mean_absolute_error: 0.0402 - val_loss: 0.0671 - val_mean_absolute_error: 0.0671 - lr: 0.0095 - 593ms/epoch - 593ms/step
# Epoch 82/1000
# 1/1 - 1s - loss: 0.0408 - mean_absolute_error: 0.0408 - val_loss: 0.0606 - val_mean_absolute_error: 0.0606 - lr: 0.0095 - 512ms/epoch - 512ms/step
# Epoch 83/1000
# 1/1 - 1s - loss: 0.0517 - mean_absolute_error: 0.0517 - val_loss: 0.0643 - val_mean_absolute_error: 0.0643 - lr: 0.0095 - 521ms/epoch - 521ms/step
# Epoch 84/1000
# 1/1 - 1s - loss: 0.0387 - mean_absolute_error: 0.0387 - val_loss: 0.0675 - val_mean_absolute_error: 0.0675 - lr: 0.0095 - 561ms/epoch - 561ms/step
# Epoch 85/1000
# 1/1 - 0s - loss: 0.0401 - mean_absolute_error: 0.0401 - val_loss: 0.0574 - val_mean_absolute_error: 0.0574 - lr: 0.0095 - 473ms/epoch - 473ms/step
# Epoch 86/1000
# 1/1 - 0s - loss: 0.0433 - mean_absolute_error: 0.0433 - val_loss: 0.0616 - val_mean_absolute_error: 0.0616 - lr: 0.0095 - 422ms/epoch - 422ms/step
# Epoch 87/1000
# 1/1 - 0s - loss: 0.0394 - mean_absolute_error: 0.0394 - val_loss: 0.0658 - val_mean_absolute_error: 0.0658 - lr: 0.0095 - 315ms/epoch - 315ms/step
# Epoch 88/1000
# 1/1 - 0s - loss: 0.0387 - mean_absolute_error: 0.0387 - val_loss: 0.0620 - val_mean_absolute_error: 0.0620 - lr: 0.0095 - 121ms/epoch - 121ms/step
# Epoch 89/1000
# 1/1 - 0s - loss: 0.0431 - mean_absolute_error: 0.0431 - val_loss: 0.0606 - val_mean_absolute_error: 0.0606 - lr: 0.0095 - 154ms/epoch - 154ms/step
# Epoch 90/1000
# 1/1 - 0s - loss: 0.0365 - mean_absolute_error: 0.0365 - val_loss: 0.0688 - val_mean_absolute_error: 0.0688 - lr: 0.0094 - 131ms/epoch - 131ms/step
# Epoch 91/1000
# 1/1 - 0s - loss: 0.0417 - mean_absolute_error: 0.0417 - val_loss: 0.0586 - val_mean_absolute_error: 0.0586 - lr: 0.0094 - 124ms/epoch - 124ms/step
# Epoch 92/1000
# 1/1 - 0s - loss: 0.0390 - mean_absolute_error: 0.0390 - val_loss: 0.0620 - val_mean_absolute_error: 0.0620 - lr: 0.0094 - 122ms/epoch - 122ms/step
# Epoch 93/1000
# 1/1 - 0s - loss: 0.0363 - mean_absolute_error: 0.0363 - val_loss: 0.0702 - val_mean_absolute_error: 0.0702 - lr: 0.0094 - 141ms/epoch - 141ms/step
# Epoch 94/1000
# 1/1 - 0s - loss: 0.0412 - mean_absolute_error: 0.0412 - val_loss: 0.0569 - val_mean_absolute_error: 0.0569 - lr: 0.0094 - 127ms/epoch - 127ms/step
# Epoch 95/1000
# 1/1 - 0s - loss: 0.0400 - mean_absolute_error: 0.0400 - val_loss: 0.0574 - val_mean_absolute_error: 0.0574 - lr: 0.0094 - 128ms/epoch - 128ms/step
# Epoch 96/1000
# 1/1 - 0s - loss: 0.0353 - mean_absolute_error: 0.0353 - val_loss: 0.0695 - val_mean_absolute_error: 0.0695 - lr: 0.0094 - 121ms/epoch - 121ms/step
# Epoch 97/1000
# 1/1 - 0s - loss: 0.0405 - mean_absolute_error: 0.0405 - val_loss: 0.0573 - val_mean_absolute_error: 0.0573 - lr: 0.0094 - 129ms/epoch - 129ms/step
# Epoch 98/1000
# 1/1 - 0s - loss: 0.0398 - mean_absolute_error: 0.0398 - val_loss: 0.0554 - val_mean_absolute_error: 0.0554 - lr: 0.0094 - 122ms/epoch - 122ms/step
# Epoch 99/1000
# 1/1 - 0s - loss: 0.0356 - mean_absolute_error: 0.0356 - val_loss: 0.0676 - val_mean_absolute_error: 0.0676 - lr: 0.0094 - 120ms/epoch - 120ms/step
# Epoch 100/1000
# 1/1 - 0s - loss: 0.0389 - mean_absolute_error: 0.0389 - val_loss: 0.0602 - val_mean_absolute_error: 0.0602 - lr: 0.0094 - 131ms/epoch - 131ms/step
# Epoch 101/1000
# 1/1 - 0s - loss: 0.0400 - mean_absolute_error: 0.0400 - val_loss: 0.0590 - val_mean_absolute_error: 0.0590 - lr: 0.0094 - 126ms/epoch - 126ms/step
# Epoch 102/1000
# 1/1 - 0s - loss: 0.0344 - mean_absolute_error: 0.0344 - val_loss: 0.0721 - val_mean_absolute_error: 0.0721 - lr: 0.0094 - 158ms/epoch - 158ms/step
# Epoch 103/1000
# 1/1 - 0s - loss: 0.0423 - mean_absolute_error: 0.0423 - val_loss: 0.0576 - val_mean_absolute_error: 0.0576 - lr: 0.0094 - 127ms/epoch - 127ms/step
# Epoch 104/1000
# 1/1 - 0s - loss: 0.0405 - mean_absolute_error: 0.0405 - val_loss: 0.0627 - val_mean_absolute_error: 0.0627 - lr: 0.0094 - 130ms/epoch - 130ms/step
# Epoch 105/1000
# 1/1 - 0s - loss: 0.0346 - mean_absolute_error: 0.0346 - val_loss: 0.0686 - val_mean_absolute_error: 0.0686 - lr: 0.0094 - 153ms/epoch - 153ms/step
# Epoch 106/1000
# 1/1 - 0s - loss: 0.0388 - mean_absolute_error: 0.0388 - val_loss: 0.0561 - val_mean_absolute_error: 0.0561 - lr: 0.0094 - 128ms/epoch - 128ms/step
# Epoch 107/1000
# 1/1 - 0s - loss: 0.0426 - mean_absolute_error: 0.0426 - val_loss: 0.0591 - val_mean_absolute_error: 0.0591 - lr: 0.0093 - 127ms/epoch - 127ms/step
# Epoch 108/1000
# 1/1 - 0s - loss: 0.0341 - mean_absolute_error: 0.0341 - val_loss: 0.0677 - val_mean_absolute_error: 0.0677 - lr: 0.0093 - 131ms/epoch - 131ms/step
# Epoch 109/1000
# 1/1 - 0s - loss: 0.0381 - mean_absolute_error: 0.0381 - val_loss: 0.0558 - val_mean_absolute_error: 0.0558 - lr: 0.0093 - 121ms/epoch - 121ms/step
# Epoch 110/1000
# 1/1 - 0s - loss: 0.0396 - mean_absolute_error: 0.0396 - val_loss: 0.0579 - val_mean_absolute_error: 0.0579 - lr: 0.0093 - 128ms/epoch - 128ms/step
# Epoch 111/1000
# 1/1 - 0s - loss: 0.0351 - mean_absolute_error: 0.0351 - val_loss: 0.0664 - val_mean_absolute_error: 0.0664 - lr: 0.0093 - 127ms/epoch - 127ms/step
# Epoch 112/1000
# 1/1 - 0s - loss: 0.0363 - mean_absolute_error: 0.0363 - val_loss: 0.0605 - val_mean_absolute_error: 0.0605 - lr: 0.0093 - 130ms/epoch - 130ms/step
# Epoch 113/1000
# 1/1 - 0s - loss: 0.0395 - mean_absolute_error: 0.0395 - val_loss: 0.0605 - val_mean_absolute_error: 0.0605 - lr: 0.0093 - 129ms/epoch - 129ms/step
# Epoch 114/1000
# 1/1 - 0s - loss: 0.0343 - mean_absolute_error: 0.0343 - val_loss: 0.0647 - val_mean_absolute_error: 0.0647 - lr: 0.0093 - 126ms/epoch - 126ms/step
# Epoch 115/1000
# 1/1 - 0s - loss: 0.0348 - mean_absolute_error: 0.0348 - val_loss: 0.0601 - val_mean_absolute_error: 0.0601 - lr: 0.0093 - 131ms/epoch - 131ms/step
# Epoch 116/1000
# 1/1 - 0s - loss: 0.0391 - mean_absolute_error: 0.0391 - val_loss: 0.0627 - val_mean_absolute_error: 0.0627 - lr: 0.0093 - 135ms/epoch - 135ms/step
# Epoch 117/1000
# 1/1 - 0s - loss: 0.0340 - mean_absolute_error: 0.0340 - val_loss: 0.0597 - val_mean_absolute_error: 0.0597 - lr: 0.0093 - 122ms/epoch - 122ms/step
# Epoch 118/1000
# 1/1 - 0s - loss: 0.0334 - mean_absolute_error: 0.0334 - val_loss: 0.0581 - val_mean_absolute_error: 0.0581 - lr: 0.0093 - 123ms/epoch - 123ms/step
# Epoch 119/1000
# 1/1 - 0s - loss: 0.0365 - mean_absolute_error: 0.0365 - val_loss: 0.0639 - val_mean_absolute_error: 0.0639 - lr: 0.0093 - 129ms/epoch - 129ms/step
# Epoch 120/1000
# 1/1 - 0s - loss: 0.0347 - mean_absolute_error: 0.0347 - val_loss: 0.0560 - val_mean_absolute_error: 0.0560 - lr: 0.0093 - 122ms/epoch - 122ms/step
# Epoch 121/1000
# 1/1 - 0s - loss: 0.0334 - mean_absolute_error: 0.0334 - val_loss: 0.0574 - val_mean_absolute_error: 0.0574 - lr: 0.0093 - 124ms/epoch - 124ms/step
# Epoch 122/1000
# 1/1 - 0s - loss: 0.0328 - mean_absolute_error: 0.0328 - val_loss: 0.0664 - val_mean_absolute_error: 0.0664 - lr: 0.0093 - 125ms/epoch - 125ms/step
# Epoch 123/1000
# 1/1 - 0s - loss: 0.0357 - mean_absolute_error: 0.0357 - val_loss: 0.0574 - val_mean_absolute_error: 0.0574 - lr: 0.0092 - 133ms/epoch - 133ms/step
# Epoch 124/1000
# 1/1 - 0s - loss: 0.0380 - mean_absolute_error: 0.0380 - val_loss: 0.0619 - val_mean_absolute_error: 0.0619 - lr: 0.0092 - 130ms/epoch - 130ms/step
# Epoch 125/1000
# 1/1 - 0s - loss: 0.0337 - mean_absolute_error: 0.0337 - val_loss: 0.0602 - val_mean_absolute_error: 0.0602 - lr: 0.0092 - 125ms/epoch - 125ms/step
# Epoch 126/1000
# 1/1 - 0s - loss: 0.0329 - mean_absolute_error: 0.0329 - val_loss: 0.0572 - val_mean_absolute_error: 0.0572 - lr: 0.0092 - 129ms/epoch - 129ms/step
# Epoch 127/1000
# 1/1 - 0s - loss: 0.0327 - mean_absolute_error: 0.0327 - val_loss: 0.0620 - val_mean_absolute_error: 0.0620 - lr: 0.0092 - 121ms/epoch - 121ms/step
# Epoch 128/1000
# 1/1 - 0s - loss: 0.0330 - mean_absolute_error: 0.0330 - val_loss: 0.0595 - val_mean_absolute_error: 0.0595 - lr: 0.0092 - 128ms/epoch - 128ms/step
# Epoch 129/1000
# 1/1 - 0s - loss: 0.0354 - mean_absolute_error: 0.0354 - val_loss: 0.0624 - val_mean_absolute_error: 0.0624 - lr: 0.0092 - 129ms/epoch - 129ms/step
# Epoch 130/1000
# 1/1 - 0s - loss: 0.0340 - mean_absolute_error: 0.0340 - val_loss: 0.0562 - val_mean_absolute_error: 0.0562 - lr: 0.0092 - 123ms/epoch - 123ms/step
# Epoch 131/1000
# 1/1 - 0s - loss: 0.0345 - mean_absolute_error: 0.0345 - val_loss: 0.0636 - val_mean_absolute_error: 0.0636 - lr: 0.0092 - 127ms/epoch - 127ms/step
# Epoch 132/1000
# 1/1 - 0s - loss: 0.0345 - mean_absolute_error: 0.0345 - val_loss: 0.0569 - val_mean_absolute_error: 0.0569 - lr: 0.0092 - 129ms/epoch - 129ms/step
# Epoch 133/1000
# 1/1 - 0s - loss: 0.0362 - mean_absolute_error: 0.0362 - val_loss: 0.0615 - val_mean_absolute_error: 0.0615 - lr: 0.0092 - 125ms/epoch - 125ms/step
# Epoch 134/1000
# 1/1 - 0s - loss: 0.0334 - mean_absolute_error: 0.0334 - val_loss: 0.0572 - val_mean_absolute_error: 0.0572 - lr: 0.0092 - 122ms/epoch - 122ms/step
# Epoch 135/1000
# 1/1 - 0s - loss: 0.0324 - mean_absolute_error: 0.0324 - val_loss: 0.0586 - val_mean_absolute_error: 0.0586 - lr: 0.0092 - 133ms/epoch - 133ms/step
# Epoch 136/1000
# 1/1 - 0s - loss: 0.0319 - mean_absolute_error: 0.0319 - val_loss: 0.0621 - val_mean_absolute_error: 0.0621 - lr: 0.0092 - 128ms/epoch - 128ms/step
# Epoch 137/1000
# 1/1 - 0s - loss: 0.0327 - mean_absolute_error: 0.0327 - val_loss: 0.0567 - val_mean_absolute_error: 0.0567 - lr: 0.0092 - 130ms/epoch - 130ms/step
# Epoch 138/1000
# 1/1 - 0s - loss: 0.0337 - mean_absolute_error: 0.0337 - val_loss: 0.0631 - val_mean_absolute_error: 0.0631 - lr: 0.0092 - 161ms/epoch - 161ms/step
# Epoch 139/1000
# 1/1 - 0s - loss: 0.0329 - mean_absolute_error: 0.0329 - val_loss: 0.0551 - val_mean_absolute_error: 0.0551 - lr: 0.0092 - 125ms/epoch - 125ms/step
# Epoch 140/1000
# 1/1 - 0s - loss: 0.0327 - mean_absolute_error: 0.0327 - val_loss: 0.0620 - val_mean_absolute_error: 0.0620 - lr: 0.0091 - 131ms/epoch - 131ms/step
# Epoch 141/1000
# 1/1 - 0s - loss: 0.0349 - mean_absolute_error: 0.0349 - val_loss: 0.0603 - val_mean_absolute_error: 0.0603 - lr: 0.0091 - 144ms/epoch - 144ms/step
# Epoch 142/1000
# 1/1 - 0s - loss: 0.0397 - mean_absolute_error: 0.0397 - val_loss: 0.0648 - val_mean_absolute_error: 0.0648 - lr: 0.0091 - 137ms/epoch - 137ms/step
# Epoch 143/1000
# 1/1 - 0s - loss: 0.0346 - mean_absolute_error: 0.0346 - val_loss: 0.0560 - val_mean_absolute_error: 0.0560 - lr: 0.0091 - 124ms/epoch - 124ms/step
# Epoch 144/1000
# 1/1 - 0s - loss: 0.0373 - mean_absolute_error: 0.0373 - val_loss: 0.0614 - val_mean_absolute_error: 0.0614 - lr: 0.0091 - 127ms/epoch - 127ms/step
# Epoch 145/1000
# 1/1 - 0s - loss: 0.0372 - mean_absolute_error: 0.0372 - val_loss: 0.0721 - val_mean_absolute_error: 0.0721 - lr: 0.0091 - 139ms/epoch - 139ms/step
# Epoch 146/1000
# 1/1 - 0s - loss: 0.0401 - mean_absolute_error: 0.0401 - val_loss: 0.0540 - val_mean_absolute_error: 0.0540 - lr: 0.0091 - 128ms/epoch - 128ms/step
# Epoch 147/1000
# 1/1 - 0s - loss: 0.0364 - mean_absolute_error: 0.0364 - val_loss: 0.0562 - val_mean_absolute_error: 0.0562 - lr: 0.0091 - 126ms/epoch - 126ms/step
# Epoch 148/1000
# 1/1 - 0s - loss: 0.0344 - mean_absolute_error: 0.0344 - val_loss: 0.0776 - val_mean_absolute_error: 0.0776 - lr: 0.0091 - 168ms/epoch - 168ms/step
# Epoch 149/1000
# 1/1 - 0s - loss: 0.0462 - mean_absolute_error: 0.0462 - val_loss: 0.0569 - val_mean_absolute_error: 0.0569 - lr: 0.0091 - 125ms/epoch - 125ms/step
# Epoch 150/1000
# 1/1 - 0s - loss: 0.0385 - mean_absolute_error: 0.0385 - val_loss: 0.0514 - val_mean_absolute_error: 0.0514 - lr: 0.0091 - 128ms/epoch - 128ms/step
# Epoch 151/1000
# 1/1 - 0s - loss: 0.0347 - mean_absolute_error: 0.0347 - val_loss: 0.0684 - val_mean_absolute_error: 0.0684 - lr: 0.0091 - 132ms/epoch - 132ms/step
# Epoch 152/1000
# 1/1 - 0s - loss: 0.0380 - mean_absolute_error: 0.0380 - val_loss: 0.0644 - val_mean_absolute_error: 0.0644 - lr: 0.0091 - 155ms/epoch - 155ms/step
# Epoch 153/1000
# 1/1 - 0s - loss: 0.0440 - mean_absolute_error: 0.0440 - val_loss: 0.0582 - val_mean_absolute_error: 0.0582 - lr: 0.0091 - 122ms/epoch - 122ms/step
# Epoch 154/1000
# 1/1 - 0s - loss: 0.0315 - mean_absolute_error: 0.0315 - val_loss: 0.0740 - val_mean_absolute_error: 0.0740 - lr: 0.0091 - 124ms/epoch - 124ms/step
# Epoch 155/1000
# 1/1 - 0s - loss: 0.0478 - mean_absolute_error: 0.0478 - val_loss: 0.0577 - val_mean_absolute_error: 0.0577 - lr: 0.0091 - 204ms/epoch - 204ms/step
# Epoch 156/1000
# 1/1 - 0s - loss: 0.0365 - mean_absolute_error: 0.0365 - val_loss: 0.0809 - val_mean_absolute_error: 0.0809 - lr: 0.0091 - 199ms/epoch - 199ms/step
# Epoch 157/1000
# 1/1 - 0s - loss: 0.0526 - mean_absolute_error: 0.0526 - val_loss: 0.0722 - val_mean_absolute_error: 0.0722 - lr: 0.0090 - 208ms/epoch - 208ms/step
# Epoch 158/1000
# 1/1 - 0s - loss: 0.0441 - mean_absolute_error: 0.0441 - val_loss: 0.0630 - val_mean_absolute_error: 0.0630 - lr: 0.0090 - 203ms/epoch - 203ms/step
# Epoch 159/1000
# 1/1 - 0s - loss: 0.0490 - mean_absolute_error: 0.0490 - val_loss: 0.0700 - val_mean_absolute_error: 0.0700 - lr: 0.0090 - 214ms/epoch - 214ms/step
# Epoch 160/1000
# 1/1 - 0s - loss: 0.0461 - mean_absolute_error: 0.0461 - val_loss: 0.0677 - val_mean_absolute_error: 0.0677 - lr: 0.0090 - 201ms/epoch - 201ms/step
# Epoch 161/1000
# 1/1 - 0s - loss: 0.0404 - mean_absolute_error: 0.0404 - val_loss: 0.0654 - val_mean_absolute_error: 0.0654 - lr: 0.0090 - 215ms/epoch - 215ms/step
# Epoch 162/1000
# 1/1 - 0s - loss: 0.0449 - mean_absolute_error: 0.0449 - val_loss: 0.0681 - val_mean_absolute_error: 0.0681 - lr: 0.0090 - 199ms/epoch - 199ms/step
# Epoch 163/1000
# 1/1 - 0s - loss: 0.0380 - mean_absolute_error: 0.0380 - val_loss: 0.0536 - val_mean_absolute_error: 0.0536 - lr: 0.0090 - 198ms/epoch - 198ms/step
# Epoch 164/1000
# 1/1 - 0s - loss: 0.0356 - mean_absolute_error: 0.0356 - val_loss: 0.0608 - val_mean_absolute_error: 0.0608 - lr: 0.0090 - 200ms/epoch - 200ms/step
# Epoch 165/1000
# 1/1 - 0s - loss: 0.0343 - mean_absolute_error: 0.0343 - val_loss: 0.0633 - val_mean_absolute_error: 0.0633 - lr: 0.0090 - 199ms/epoch - 199ms/step
# Epoch 166/1000
# 1/1 - 0s - loss: 0.0342 - mean_absolute_error: 0.0342 - val_loss: 0.0553 - val_mean_absolute_error: 0.0553 - lr: 0.0090 - 215ms/epoch - 215ms/step
# Epoch 167/1000
# 1/1 - 0s - loss: 0.0380 - mean_absolute_error: 0.0380 - val_loss: 0.0551 - val_mean_absolute_error: 0.0551 - lr: 0.0090 - 213ms/epoch - 213ms/step
# Epoch 168/1000
# 1/1 - 0s - loss: 0.0329 - mean_absolute_error: 0.0329 - val_loss: 0.0697 - val_mean_absolute_error: 0.0697 - lr: 0.0090 - 211ms/epoch - 211ms/step
# Epoch 169/1000
# 1/1 - 0s - loss: 0.0390 - mean_absolute_error: 0.0390 - val_loss: 0.0579 - val_mean_absolute_error: 0.0579 - lr: 0.0090 - 210ms/epoch - 210ms/step
# Epoch 170/1000
# 1/1 - 0s - loss: 0.0321 - mean_absolute_error: 0.0321 - val_loss: 0.0532 - val_mean_absolute_error: 0.0532 - lr: 0.0090 - 192ms/epoch - 192ms/step
# Epoch 171/1000
# 1/1 - 0s - loss: 0.0390 - mean_absolute_error: 0.0390 - val_loss: 0.0691 - val_mean_absolute_error: 0.0691 - lr: 0.0090 - 129ms/epoch - 129ms/step
# Epoch 172/1000
# 1/1 - 0s - loss: 0.0382 - mean_absolute_error: 0.0382 - val_loss: 0.0591 - val_mean_absolute_error: 0.0591 - lr: 0.0090 - 123ms/epoch - 123ms/step
# Epoch 173/1000
# 1/1 - 0s - loss: 0.0346 - mean_absolute_error: 0.0346 - val_loss: 0.0503 - val_mean_absolute_error: 0.0503 - lr: 0.0090 - 125ms/epoch - 125ms/step
# Epoch 174/1000
# 1/1 - 0s - loss: 0.0348 - mean_absolute_error: 0.0348 - val_loss: 0.0625 - val_mean_absolute_error: 0.0625 - lr: 0.0090 - 133ms/epoch - 133ms/step
# Epoch 175/1000
# 1/1 - 0s - loss: 0.0368 - mean_absolute_error: 0.0368 - val_loss: 0.0615 - val_mean_absolute_error: 0.0615 - lr: 0.0089 - 126ms/epoch - 126ms/step
# Epoch 176/1000
# 1/1 - 0s - loss: 0.0356 - mean_absolute_error: 0.0356 - val_loss: 0.0571 - val_mean_absolute_error: 0.0571 - lr: 0.0089 - 128ms/epoch - 128ms/step
# Epoch 177/1000
# 1/1 - 0s - loss: 0.0327 - mean_absolute_error: 0.0327 - val_loss: 0.0696 - val_mean_absolute_error: 0.0696 - lr: 0.0089 - 137ms/epoch - 137ms/step
# Epoch 178/1000
# 1/1 - 0s - loss: 0.0407 - mean_absolute_error: 0.0407 - val_loss: 0.0576 - val_mean_absolute_error: 0.0576 - lr: 0.0089 - 132ms/epoch - 132ms/step
# Epoch 179/1000
# 1/1 - 0s - loss: 0.0347 - mean_absolute_error: 0.0347 - val_loss: 0.0696 - val_mean_absolute_error: 0.0696 - lr: 0.0089 - 128ms/epoch - 128ms/step
# Epoch 180/1000
# 1/1 - 0s - loss: 0.0407 - mean_absolute_error: 0.0407 - val_loss: 0.0616 - val_mean_absolute_error: 0.0616 - lr: 0.0089 - 128ms/epoch - 128ms/step
# Epoch 181/1000
# 1/1 - 0s - loss: 0.0328 - mean_absolute_error: 0.0328 - val_loss: 0.0601 - val_mean_absolute_error: 0.0601 - lr: 0.0089 - 129ms/epoch - 129ms/step
# Epoch 182/1000
# 1/1 - 0s - loss: 0.0458 - mean_absolute_error: 0.0458 - val_loss: 0.0570 - val_mean_absolute_error: 0.0570 - lr: 0.0089 - 139ms/epoch - 139ms/step
# Epoch 183/1000
# 1/1 - 0s - loss: 0.0329 - mean_absolute_error: 0.0329 - val_loss: 0.0738 - val_mean_absolute_error: 0.0738 - lr: 0.0089 - 136ms/epoch - 136ms/step
# Epoch 184/1000
# 1/1 - 0s - loss: 0.0475 - mean_absolute_error: 0.0475 - val_loss: 0.0648 - val_mean_absolute_error: 0.0648 - lr: 0.0089 - 124ms/epoch - 124ms/step
# Epoch 185/1000
# 1/1 - 0s - loss: 0.0412 - mean_absolute_error: 0.0412 - val_loss: 0.0628 - val_mean_absolute_error: 0.0628 - lr: 0.0089 - 129ms/epoch - 129ms/step
# Epoch 186/1000
# 1/1 - 0s - loss: 0.0386 - mean_absolute_error: 0.0386 - val_loss: 0.0654 - val_mean_absolute_error: 0.0654 - lr: 0.0089 - 131ms/epoch - 131ms/step
# Epoch 187/1000
# 1/1 - 0s - loss: 0.0384 - mean_absolute_error: 0.0384 - val_loss: 0.0641 - val_mean_absolute_error: 0.0641 - lr: 0.0089 - 139ms/epoch - 139ms/step
# Epoch 188/1000
# 1/1 - 0s - loss: 0.0381 - mean_absolute_error: 0.0381 - val_loss: 0.0682 - val_mean_absolute_error: 0.0682 - lr: 0.0089 - 138ms/epoch - 138ms/step
# Epoch 189/1000
# 1/1 - 0s - loss: 0.0380 - mean_absolute_error: 0.0380 - val_loss: 0.0591 - val_mean_absolute_error: 0.0591 - lr: 0.0089 - 135ms/epoch - 135ms/step
# Epoch 190/1000
# 1/1 - 0s - loss: 0.0349 - mean_absolute_error: 0.0349 - val_loss: 0.0539 - val_mean_absolute_error: 0.0539 - lr: 0.0089 - 130ms/epoch - 130ms/step
# Epoch 191/1000
# 1/1 - 0s - loss: 0.0325 - mean_absolute_error: 0.0325 - val_loss: 0.0650 - val_mean_absolute_error: 0.0650 - lr: 0.0089 - 132ms/epoch - 132ms/step
# Epoch 192/1000
# 1/1 - 0s - loss: 0.0377 - mean_absolute_error: 0.0377 - val_loss: 0.0568 - val_mean_absolute_error: 0.0568 - lr: 0.0088 - 125ms/epoch - 125ms/step
# Epoch 193/1000
# 1/1 - 0s - loss: 0.0330 - mean_absolute_error: 0.0330 - val_loss: 0.0563 - val_mean_absolute_error: 0.0563 - lr: 0.0088 - 128ms/epoch - 128ms/step
# Epoch 194/1000
# 1/1 - 0s - loss: 0.0375 - mean_absolute_error: 0.0375 - val_loss: 0.0570 - val_mean_absolute_error: 0.0570 - lr: 0.0088 - 126ms/epoch - 126ms/step
# Epoch 195/1000
# 1/1 - 0s - loss: 0.0304 - mean_absolute_error: 0.0304 - val_loss: 0.0651 - val_mean_absolute_error: 0.0651 - lr: 0.0088 - 135ms/epoch - 135ms/step
# Epoch 196/1000
# 1/1 - 0s - loss: 0.0364 - mean_absolute_error: 0.0364 - val_loss: 0.0573 - val_mean_absolute_error: 0.0573 - lr: 0.0088 - 143ms/epoch - 143ms/step
# Epoch 197/1000
# 1/1 - 0s - loss: 0.0315 - mean_absolute_error: 0.0315 - val_loss: 0.0676 - val_mean_absolute_error: 0.0676 - lr: 0.0088 - 133ms/epoch - 133ms/step
# Epoch 198/1000
# 1/1 - 0s - loss: 0.0381 - mean_absolute_error: 0.0381 - val_loss: 0.0531 - val_mean_absolute_error: 0.0531 - lr: 0.0088 - 133ms/epoch - 133ms/step
# Epoch 199/1000
# 1/1 - 0s - loss: 0.0342 - mean_absolute_error: 0.0342 - val_loss: 0.0626 - val_mean_absolute_error: 0.0626 - lr: 0.0088 - 125ms/epoch - 125ms/step
# Epoch 200/1000
# 1/1 - 0s - loss: 0.0339 - mean_absolute_error: 0.0339 - val_loss: 0.0554 - val_mean_absolute_error: 0.0554 - lr: 0.0088 - 123ms/epoch - 123ms/step
# Epoch 201/1000
# 1/1 - 0s - loss: 0.0317 - mean_absolute_error: 0.0317 - val_loss: 0.0504 - val_mean_absolute_error: 0.0504 - lr: 0.0088 - 132ms/epoch - 132ms/step
# Epoch 202/1000
# 1/1 - 0s - loss: 0.0349 - mean_absolute_error: 0.0349 - val_loss: 0.0621 - val_mean_absolute_error: 0.0621 - lr: 0.0088 - 129ms/epoch - 129ms/step
# Epoch 203/1000
# 1/1 - 0s - loss: 0.0326 - mean_absolute_error: 0.0326 - val_loss: 0.0563 - val_mean_absolute_error: 0.0563 - lr: 0.0088 - 125ms/epoch - 125ms/step
# Epoch 204/1000
# 1/1 - 0s - loss: 0.0306 - mean_absolute_error: 0.0306 - val_loss: 0.0567 - val_mean_absolute_error: 0.0567 - lr: 0.0088 - 137ms/epoch - 137ms/step
# Epoch 205/1000
# 1/1 - 0s - loss: 0.0312 - mean_absolute_error: 0.0312 - val_loss: 0.0650 - val_mean_absolute_error: 0.0650 - lr: 0.0088 - 134ms/epoch - 134ms/step
# Epoch 206/1000
# 1/1 - 0s - loss: 0.0332 - mean_absolute_error: 0.0332 - val_loss: 0.0554 - val_mean_absolute_error: 0.0554 - lr: 0.0088 - 123ms/epoch - 123ms/step
# Epoch 207/1000
# 1/1 - 0s - loss: 0.0395 - mean_absolute_error: 0.0395 - val_loss: 0.0682 - val_mean_absolute_error: 0.0682 - lr: 0.0088 - 124ms/epoch - 124ms/step
# Epoch 208/1000
# 1/1 - 0s - loss: 0.0380 - mean_absolute_error: 0.0380 - val_loss: 0.0518 - val_mean_absolute_error: 0.0518 - lr: 0.0088 - 158ms/epoch - 158ms/step
# Epoch 209/1000
# 1/1 - 0s - loss: 0.0325 - mean_absolute_error: 0.0325 - val_loss: 0.0473 - val_mean_absolute_error: 0.0473 - lr: 0.0088 - 158ms/epoch - 158ms/step
# Epoch 210/1000
# 1/1 - 0s - loss: 0.0347 - mean_absolute_error: 0.0347 - val_loss: 0.0663 - val_mean_absolute_error: 0.0663 - lr: 0.0087 - 130ms/epoch - 130ms/step
# Epoch 211/1000
# 1/1 - 0s - loss: 0.0381 - mean_absolute_error: 0.0381 - val_loss: 0.0569 - val_mean_absolute_error: 0.0569 - lr: 0.0087 - 138ms/epoch - 138ms/step
# Epoch 212/1000
# 1/1 - 0s - loss: 0.0364 - mean_absolute_error: 0.0364 - val_loss: 0.0590 - val_mean_absolute_error: 0.0590 - lr: 0.0087 - 128ms/epoch - 128ms/step
# Epoch 213/1000
# 1/1 - 0s - loss: 0.0308 - mean_absolute_error: 0.0308 - val_loss: 0.0680 - val_mean_absolute_error: 0.0680 - lr: 0.0087 - 126ms/epoch - 126ms/step
# Epoch 214/1000
# 1/1 - 0s - loss: 0.0381 - mean_absolute_error: 0.0381 - val_loss: 0.0545 - val_mean_absolute_error: 0.0545 - lr: 0.0087 - 125ms/epoch - 125ms/step
# Epoch 215/1000
# 1/1 - 0s - loss: 0.0383 - mean_absolute_error: 0.0383 - val_loss: 0.0721 - val_mean_absolute_error: 0.0721 - lr: 0.0087 - 127ms/epoch - 127ms/step
# Epoch 216/1000
# 1/1 - 0s - loss: 0.0421 - mean_absolute_error: 0.0421 - val_loss: 0.0628 - val_mean_absolute_error: 0.0628 - lr: 0.0087 - 128ms/epoch - 128ms/step
# Epoch 217/1000
# 1/1 - 0s - loss: 0.0350 - mean_absolute_error: 0.0350 - val_loss: 0.0532 - val_mean_absolute_error: 0.0532 - lr: 0.0087 - 126ms/epoch - 126ms/step
# Epoch 218/1000
# 1/1 - 0s - loss: 0.0465 - mean_absolute_error: 0.0465 - val_loss: 0.0504 - val_mean_absolute_error: 0.0504 - lr: 0.0087 - 129ms/epoch - 129ms/step
# Epoch 219/1000
# 1/1 - 0s - loss: 0.0342 - mean_absolute_error: 0.0342 - val_loss: 0.0754 - val_mean_absolute_error: 0.0754 - lr: 0.0087 - 129ms/epoch - 129ms/step
# Epoch 220/1000
# 1/1 - 0s - loss: 0.0480 - mean_absolute_error: 0.0480 - val_loss: 0.0657 - val_mean_absolute_error: 0.0657 - lr: 0.0087 - 125ms/epoch - 125ms/step
# Epoch 221/1000
# 1/1 - 0s - loss: 0.0383 - mean_absolute_error: 0.0383 - val_loss: 0.0556 - val_mean_absolute_error: 0.0556 - lr: 0.0087 - 124ms/epoch - 124ms/step
# Epoch 222/1000
# 1/1 - 0s - loss: 0.0460 - mean_absolute_error: 0.0460 - val_loss: 0.0639 - val_mean_absolute_error: 0.0639 - lr: 0.0087 - 130ms/epoch - 130ms/step
# Epoch 223/1000
# 1/1 - 0s - loss: 0.0390 - mean_absolute_error: 0.0390 - val_loss: 0.0660 - val_mean_absolute_error: 0.0660 - lr: 0.0087 - 128ms/epoch - 128ms/step
# Epoch 224/1000
# 1/1 - 0s - loss: 0.0365 - mean_absolute_error: 0.0365 - val_loss: 0.0628 - val_mean_absolute_error: 0.0628 - lr: 0.0087 - 131ms/epoch - 131ms/step
# Epoch 225/1000
# 1/1 - 0s - loss: 0.0383 - mean_absolute_error: 0.0383 - val_loss: 0.0568 - val_mean_absolute_error: 0.0568 - lr: 0.0087 - 137ms/epoch - 137ms/step
# Epoch 226/1000
# 1/1 - 0s - loss: 0.0329 - mean_absolute_error: 0.0329 - val_loss: 0.0609 - val_mean_absolute_error: 0.0609 - lr: 0.0087 - 141ms/epoch - 141ms/step
# Epoch 227/1000
# 1/1 - 0s - loss: 0.0355 - mean_absolute_error: 0.0355 - val_loss: 0.0572 - val_mean_absolute_error: 0.0572 - lr: 0.0087 - 132ms/epoch - 132ms/step
# Epoch 228/1000
# 1/1 - 0s - loss: 0.0352 - mean_absolute_error: 0.0352 - val_loss: 0.0625 - val_mean_absolute_error: 0.0625 - lr: 0.0086 - 135ms/epoch - 135ms/step
# Epoch 229/1000
# 1/1 - 0s - loss: 0.0342 - mean_absolute_error: 0.0342 - val_loss: 0.0593 - val_mean_absolute_error: 0.0593 - lr: 0.0086 - 137ms/epoch - 137ms/step
# Epoch 230/1000
# 1/1 - 0s - loss: 0.0338 - mean_absolute_error: 0.0338 - val_loss: 0.0511 - val_mean_absolute_error: 0.0511 - lr: 0.0086 - 139ms/epoch - 139ms/step
# Epoch 231/1000
# 1/1 - 0s - loss: 0.0361 - mean_absolute_error: 0.0361 - val_loss: 0.0646 - val_mean_absolute_error: 0.0646 - lr: 0.0086 - 129ms/epoch - 129ms/step
# Epoch 232/1000
# 1/1 - 0s - loss: 0.0342 - mean_absolute_error: 0.0342 - val_loss: 0.0610 - val_mean_absolute_error: 0.0610 - lr: 0.0086 - 130ms/epoch - 130ms/step
# Epoch 233/1000
# 1/1 - 0s - loss: 0.0321 - mean_absolute_error: 0.0321 - val_loss: 0.0504 - val_mean_absolute_error: 0.0504 - lr: 0.0086 - 139ms/epoch - 139ms/step
# Epoch 234/1000
# 1/1 - 0s - loss: 0.0362 - mean_absolute_error: 0.0362 - val_loss: 0.0587 - val_mean_absolute_error: 0.0587 - lr: 0.0086 - 129ms/epoch - 129ms/step
# Epoch 235/1000
# 1/1 - 0s - loss: 0.0335 - mean_absolute_error: 0.0335 - val_loss: 0.0626 - val_mean_absolute_error: 0.0626 - lr: 0.0086 - 127ms/epoch - 127ms/step
# Epoch 236/1000
# 1/1 - 0s - loss: 0.0350 - mean_absolute_error: 0.0350 - val_loss: 0.0566 - val_mean_absolute_error: 0.0566 - lr: 0.0086 - 135ms/epoch - 135ms/step
# Epoch 237/1000
# 1/1 - 0s - loss: 0.0335 - mean_absolute_error: 0.0335 - val_loss: 0.0642 - val_mean_absolute_error: 0.0642 - lr: 0.0086 - 126ms/epoch - 126ms/step
# Epoch 238/1000
# 1/1 - 0s - loss: 0.0370 - mean_absolute_error: 0.0370 - val_loss: 0.0565 - val_mean_absolute_error: 0.0565 - lr: 0.0086 - 125ms/epoch - 125ms/step
# Epoch 239/1000
# 1/1 - 0s - loss: 0.0321 - mean_absolute_error: 0.0321 - val_loss: 0.0637 - val_mean_absolute_error: 0.0637 - lr: 0.0086 - 123ms/epoch - 123ms/step
# Epoch 240/1000
# 1/1 - 0s - loss: 0.0364 - mean_absolute_error: 0.0364 - val_loss: 0.0598 - val_mean_absolute_error: 0.0598 - lr: 0.0086 - 129ms/epoch - 129ms/step
# Epoch 241/1000
# 1/1 - 0s - loss: 0.0319 - mean_absolute_error: 0.0319 - val_loss: 0.0574 - val_mean_absolute_error: 0.0574 - lr: 0.0086 - 136ms/epoch - 136ms/step
# Epoch 242/1000
# 1/1 - 0s - loss: 0.0366 - mean_absolute_error: 0.0366 - val_loss: 0.0515 - val_mean_absolute_error: 0.0515 - lr: 0.0086 - 126ms/epoch - 126ms/step
# Epoch 243/1000
# 1/1 - 0s - loss: 0.0314 - mean_absolute_error: 0.0314 - val_loss: 0.0630 - val_mean_absolute_error: 0.0630 - lr: 0.0086 - 165ms/epoch - 165ms/step
# Epoch 244/1000
# 1/1 - 0s - loss: 0.0350 - mean_absolute_error: 0.0350 - val_loss: 0.0593 - val_mean_absolute_error: 0.0593 - lr: 0.0086 - 207ms/epoch - 207ms/step
# Epoch 245/1000
# 1/1 - 0s - loss: 0.0311 - mean_absolute_error: 0.0311 - val_loss: 0.0546 - val_mean_absolute_error: 0.0546 - lr: 0.0086 - 197ms/epoch - 197ms/step
# Epoch 246/1000
# 1/1 - 0s - loss: 0.0370 - mean_absolute_error: 0.0370 - val_loss: 0.0585 - val_mean_absolute_error: 0.0585 - lr: 0.0085 - 199ms/epoch - 199ms/step
# Epoch 247/1000
# 1/1 - 0s - loss: 0.0304 - mean_absolute_error: 0.0304 - val_loss: 0.0617 - val_mean_absolute_error: 0.0617 - lr: 0.0085 - 217ms/epoch - 217ms/step
# Epoch 248/1000
# 1/1 - 0s - loss: 0.0363 - mean_absolute_error: 0.0363 - val_loss: 0.0554 - val_mean_absolute_error: 0.0554 - lr: 0.0085 - 193ms/epoch - 193ms/step
# Epoch 249/1000
# 1/1 - 0s - loss: 0.0303 - mean_absolute_error: 0.0303 - val_loss: 0.0625 - val_mean_absolute_error: 0.0625 - lr: 0.0085 - 196ms/epoch - 196ms/step
# Epoch 250/1000
# 1/1 - 0s - loss: 0.0383 - mean_absolute_error: 0.0383 - val_loss: 0.0545 - val_mean_absolute_error: 0.0545 - lr: 0.0085 - 208ms/epoch - 208ms/step
# Epoch 251/1000
# 1/1 - 0s - loss: 0.0332 - mean_absolute_error: 0.0332 - val_loss: 0.0696 - val_mean_absolute_error: 0.0696 - lr: 0.0085 - 209ms/epoch - 209ms/step
# Epoch 252/1000
# 1/1 - 0s - loss: 0.0394 - mean_absolute_error: 0.0394 - val_loss: 0.0650 - val_mean_absolute_error: 0.0650 - lr: 0.0085 - 209ms/epoch - 209ms/step
# Epoch 253/1000
# 1/1 - 0s - loss: 0.0354 - mean_absolute_error: 0.0354 - val_loss: 0.0514 - val_mean_absolute_error: 0.0514 - lr: 0.0085 - 214ms/epoch - 214ms/step
# Epoch 254/1000
# 1/1 - 0s - loss: 0.0371 - mean_absolute_error: 0.0371 - val_loss: 0.0560 - val_mean_absolute_error: 0.0560 - lr: 0.0085 - 215ms/epoch - 215ms/step
# Epoch 255/1000
# 1/1 - 0s - loss: 0.0348 - mean_absolute_error: 0.0348 - val_loss: 0.0619 - val_mean_absolute_error: 0.0619 - lr: 0.0085 - 193ms/epoch - 193ms/step
# Epoch 256/1000
# 1/1 - 0s - loss: 0.0391 - mean_absolute_error: 0.0391 - val_loss: 0.0608 - val_mean_absolute_error: 0.0608 - lr: 0.0085 - 202ms/epoch - 202ms/step
# Epoch 257/1000
# 1/1 - 0s - loss: 0.0374 - mean_absolute_error: 0.0374 - val_loss: 0.0571 - val_mean_absolute_error: 0.0571 - lr: 0.0085 - 219ms/epoch - 219ms/step
# Epoch 258/1000
# 1/1 - 0s - loss: 0.0345 - mean_absolute_error: 0.0345 - val_loss: 0.0522 - val_mean_absolute_error: 0.0522 - lr: 0.0085 - 208ms/epoch - 208ms/step
# Epoch 259/1000
# 1/1 - 0s - loss: 0.0381 - mean_absolute_error: 0.0381 - val_loss: 0.0678 - val_mean_absolute_error: 0.0678 - lr: 0.0085 - 181ms/epoch - 181ms/step
# Epoch 260/1000
# 1/1 - 0s - loss: 0.0367 - mean_absolute_error: 0.0367 - val_loss: 0.0661 - val_mean_absolute_error: 0.0661 - lr: 0.0085 - 129ms/epoch - 129ms/step
# Epoch 261/1000
# 1/1 - 0s - loss: 0.0370 - mean_absolute_error: 0.0370 - val_loss: 0.0502 - val_mean_absolute_error: 0.0502 - lr: 0.0085 - 131ms/epoch - 131ms/step
# Epoch 262/1000
# 1/1 - 0s - loss: 0.0351 - mean_absolute_error: 0.0351 - val_loss: 0.0678 - val_mean_absolute_error: 0.0678 - lr: 0.0085 - 143ms/epoch - 143ms/step
# Epoch 263/1000
# 1/1 - 0s - loss: 0.0447 - mean_absolute_error: 0.0447 - val_loss: 0.0542 - val_mean_absolute_error: 0.0542 - lr: 0.0085 - 129ms/epoch - 129ms/step
# Epoch 264/1000
# 1/1 - 0s - loss: 0.0314 - mean_absolute_error: 0.0314 - val_loss: 0.0640 - val_mean_absolute_error: 0.0640 - lr: 0.0085 - 136ms/epoch - 136ms/step
# Epoch 265/1000
# 1/1 - 0s - loss: 0.0479 - mean_absolute_error: 0.0479 - val_loss: 0.0694 - val_mean_absolute_error: 0.0694 - lr: 0.0084 - 137ms/epoch - 137ms/step
# Epoch 266/1000
# 1/1 - 0s - loss: 0.0438 - mean_absolute_error: 0.0438 - val_loss: 0.0701 - val_mean_absolute_error: 0.0701 - lr: 0.0084 - 151ms/epoch - 151ms/step
# Epoch 267/1000
# 1/1 - 0s - loss: 0.0400 - mean_absolute_error: 0.0400 - val_loss: 0.0511 - val_mean_absolute_error: 0.0511 - lr: 0.0084 - 127ms/epoch - 127ms/step
# Epoch 268/1000
# 1/1 - 0s - loss: 0.0372 - mean_absolute_error: 0.0372 - val_loss: 0.0507 - val_mean_absolute_error: 0.0507 - lr: 0.0084 - 138ms/epoch - 138ms/step
# Epoch 269/1000
# 1/1 - 0s - loss: 0.0328 - mean_absolute_error: 0.0328 - val_loss: 0.0703 - val_mean_absolute_error: 0.0703 - lr: 0.0084 - 136ms/epoch - 136ms/step
# Epoch 270/1000
# 1/1 - 0s - loss: 0.0400 - mean_absolute_error: 0.0400 - val_loss: 0.0632 - val_mean_absolute_error: 0.0632 - lr: 0.0084 - 125ms/epoch - 125ms/step
# Epoch 271/1000
# 1/1 - 0s - loss: 0.0342 - mean_absolute_error: 0.0342 - val_loss: 0.0486 - val_mean_absolute_error: 0.0486 - lr: 0.0084 - 132ms/epoch - 132ms/step
# Epoch 272/1000
# 1/1 - 0s - loss: 0.0399 - mean_absolute_error: 0.0399 - val_loss: 0.0548 - val_mean_absolute_error: 0.0548 - lr: 0.0084 - 134ms/epoch - 134ms/step
# Epoch 273/1000
# 1/1 - 0s - loss: 0.0342 - mean_absolute_error: 0.0342 - val_loss: 0.0611 - val_mean_absolute_error: 0.0611 - lr: 0.0084 - 127ms/epoch - 127ms/step
# Epoch 274/1000
# 1/1 - 0s - loss: 0.0328 - mean_absolute_error: 0.0328 - val_loss: 0.0591 - val_mean_absolute_error: 0.0591 - lr: 0.0084 - 125ms/epoch - 125ms/step
# Epoch 275/1000
# 1/1 - 0s - loss: 0.0346 - mean_absolute_error: 0.0346 - val_loss: 0.0535 - val_mean_absolute_error: 0.0535 - lr: 0.0084 - 130ms/epoch - 130ms/step
# Epoch 276/1000
# 1/1 - 0s - loss: 0.0304 - mean_absolute_error: 0.0304 - val_loss: 0.0607 - val_mean_absolute_error: 0.0607 - lr: 0.0084 - 135ms/epoch - 135ms/step
# Epoch 277/1000
# 1/1 - 0s - loss: 0.0346 - mean_absolute_error: 0.0346 - val_loss: 0.0565 - val_mean_absolute_error: 0.0565 - lr: 0.0084 - 146ms/epoch - 146ms/step
# Epoch 278/1000
# 1/1 - 0s - loss: 0.0300 - mean_absolute_error: 0.0300 - val_loss: 0.0609 - val_mean_absolute_error: 0.0609 - lr: 0.0084 - 127ms/epoch - 127ms/step
# Epoch 279/1000
# 1/1 - 0s - loss: 0.0325 - mean_absolute_error: 0.0325 - val_loss: 0.0561 - val_mean_absolute_error: 0.0561 - lr: 0.0084 - 123ms/epoch - 123ms/step
# Epoch 280/1000
# 1/1 - 0s - loss: 0.0291 - mean_absolute_error: 0.0291 - val_loss: 0.0516 - val_mean_absolute_error: 0.0516 - lr: 0.0084 - 129ms/epoch - 129ms/step
# Epoch 281/1000
# 1/1 - 0s - loss: 0.0323 - mean_absolute_error: 0.0323 - val_loss: 0.0549 - val_mean_absolute_error: 0.0549 - lr: 0.0084 - 130ms/epoch - 130ms/step
# Epoch 282/1000
# 1/1 - 0s - loss: 0.0295 - mean_absolute_error: 0.0295 - val_loss: 0.0594 - val_mean_absolute_error: 0.0594 - lr: 0.0084 - 124ms/epoch - 124ms/step
# Epoch 283/1000
# 1/1 - 0s - loss: 0.0311 - mean_absolute_error: 0.0311 - val_loss: 0.0547 - val_mean_absolute_error: 0.0547 - lr: 0.0083 - 132ms/epoch - 132ms/step
# Epoch 284/1000
# 1/1 - 0s - loss: 0.0301 - mean_absolute_error: 0.0301 - val_loss: 0.0629 - val_mean_absolute_error: 0.0629 - lr: 0.0083 - 134ms/epoch - 134ms/step
# Epoch 285/1000
# 1/1 - 0s - loss: 0.0339 - mean_absolute_error: 0.0339 - val_loss: 0.0524 - val_mean_absolute_error: 0.0524 - lr: 0.0083 - 125ms/epoch - 125ms/step
# Epoch 286/1000
# 1/1 - 0s - loss: 0.0365 - mean_absolute_error: 0.0365 - val_loss: 0.0642 - val_mean_absolute_error: 0.0642 - lr: 0.0083 - 128ms/epoch - 128ms/step
# Epoch 287/1000
# 1/1 - 0s - loss: 0.0346 - mean_absolute_error: 0.0346 - val_loss: 0.0584 - val_mean_absolute_error: 0.0584 - lr: 0.0083 - 130ms/epoch - 130ms/step
# Epoch 288/1000
# 1/1 - 0s - loss: 0.0320 - mean_absolute_error: 0.0320 - val_loss: 0.0470 - val_mean_absolute_error: 0.0470 - lr: 0.0083 - 128ms/epoch - 128ms/step
# Epoch 289/1000
# 1/1 - 0s - loss: 0.0360 - mean_absolute_error: 0.0360 - val_loss: 0.0512 - val_mean_absolute_error: 0.0512 - lr: 0.0083 - 125ms/epoch - 125ms/step
# Epoch 290/1000
# 1/1 - 0s - loss: 0.0326 - mean_absolute_error: 0.0326 - val_loss: 0.0612 - val_mean_absolute_error: 0.0612 - lr: 0.0083 - 128ms/epoch - 128ms/step
# Epoch 291/1000
# 1/1 - 0s - loss: 0.0315 - mean_absolute_error: 0.0315 - val_loss: 0.0615 - val_mean_absolute_error: 0.0615 - lr: 0.0083 - 127ms/epoch - 127ms/step
# Epoch 292/1000
# 1/1 - 0s - loss: 0.0346 - mean_absolute_error: 0.0346 - val_loss: 0.0565 - val_mean_absolute_error: 0.0565 - lr: 0.0083 - 136ms/epoch - 136ms/step
# Epoch 293/1000
# 1/1 - 0s - loss: 0.0306 - mean_absolute_error: 0.0306 - val_loss: 0.0627 - val_mean_absolute_error: 0.0627 - lr: 0.0083 - 138ms/epoch - 138ms/step
# Epoch 294/1000
# 1/1 - 0s - loss: 0.0360 - mean_absolute_error: 0.0360 - val_loss: 0.0507 - val_mean_absolute_error: 0.0507 - lr: 0.0083 - 133ms/epoch - 133ms/step
# Epoch 295/1000
# 1/1 - 0s - loss: 0.0316 - mean_absolute_error: 0.0316 - val_loss: 0.0544 - val_mean_absolute_error: 0.0544 - lr: 0.0083 - 127ms/epoch - 127ms/step
# Epoch 296/1000
# 1/1 - 0s - loss: 0.0312 - mean_absolute_error: 0.0312 - val_loss: 0.0629 - val_mean_absolute_error: 0.0629 - lr: 0.0083 - 129ms/epoch - 129ms/step
# Epoch 297/1000
# ...
# Epoch 440/1000
# 1/1 - 0s - loss: 0.0312 - mean_absolute_error: 0.0312 - val_loss: 0.0571 - val_mean_absolute_error: 0.0571 - lr: 0.0076 - 126ms/epoch - 126ms/step
# Epoch 441/1000
# 1/1 - 0s - loss: 0.0273 - mean_absolute_error: 0.0273 - val_loss: 0.0508 - val_mean_absolute_error: 0.0508 - lr: 0.0075 - 128ms/epoch - 128ms/step
# Epoch 442/1000
# 1/1 - 0s - loss: 0.0337 - mean_absolute_error: 0.0337 - val_loss: 0.0649 - val_mean_absolute_error: 0.0649 - lr: 0.0075 - 124ms/epoch - 124ms/step
# Epoch 443/1000
# 1/1 - 0s - loss: 0.0338 - mean_absolute_error: 0.0338 - val_loss: 0.0532 - val_mean_absolute_error: 0.0532 - lr: 0.0075 - 124ms/epoch - 124ms/step
# Epoch 444/1000
# 1/1 - 0s - loss: 0.0316 - mean_absolute_error: 0.0316 - val_loss: 0.0573 - val_mean_absolute_error: 0.0573 - lr: 0.0075 - 141ms/epoch - 141ms/step
# Epoch 445/1000
# 1/1 - 0s - loss: 0.0278 - mean_absolute_error: 0.0278 - val_loss: 0.0542 - val_mean_absolute_error: 0.0542 - lr: 0.0075 - 136ms/epoch - 136ms/step
# Epoch 446/1000
# 1/1 - 0s - loss: 0.0288 - mean_absolute_error: 0.0288 - val_loss: 0.0489 - val_mean_absolute_error: 0.0489 - lr: 0.0075 - 126ms/epoch - 126ms/step
# Epoch 447/1000
# 1/1 - 0s - loss: 0.0308 - mean_absolute_error: 0.0308 - val_loss: 0.0553 - val_mean_absolute_error: 0.0553 - lr: 0.0075 - 139ms/epoch - 139ms/step
# Epoch 448/1000
# 1/1 - 0s - loss: 0.0272 - mean_absolute_error: 0.0272 - val_loss: 0.0582 - val_mean_absolute_error: 0.0582 - lr: 0.0075 - 125ms/epoch - 125ms/step
# Epoch 449/1000
# 1/1 - 0s - loss: 0.0275 - mean_absolute_error: 0.0275 - val_loss: 0.0539 - val_mean_absolute_error: 0.0539 - lr: 0.0075 - 127ms/epoch - 127ms/step
# Epoch 450/1000
# 1/1 - 0s - loss: 0.0285 - mean_absolute_error: 0.0285 - val_loss: 0.0613 - val_mean_absolute_error: 0.0613 - lr: 0.0075 - 125ms/epoch - 125ms/step
# Epoch 451/1000
# 1/1 - 0s - loss: 0.0318 - mean_absolute_error: 0.0318 - val_loss: 0.0506 - val_mean_absolute_error: 0.0506 - lr: 0.0075 - 134ms/epoch - 134ms/step
# Epoch 452/1000
# 1/1 - 0s - loss: 0.0308 - mean_absolute_error: 0.0308 - val_loss: 0.0543 - val_mean_absolute_error: 0.0543 - lr: 0.0075 - 156ms/epoch - 156ms/step
# Epoch 453/1000
# 1/1 - 0s - loss: 0.0278 - mean_absolute_error: 0.0278 - val_loss: 0.0548 - val_mean_absolute_error: 0.0548 - lr: 0.0075 - 127ms/epoch - 127ms/step
# Epoch 454/1000
# 1/1 - 0s - loss: 0.0280 - mean_absolute_error: 0.0280 - val_loss: 0.0499 - val_mean_absolute_error: 0.0499 - lr: 0.0075 - 130ms/epoch - 130ms/step
# Epoch 455/1000
# 1/1 - 0s - loss: 0.0287 - mean_absolute_error: 0.0287 - val_loss: 0.0549 - val_mean_absolute_error: 0.0549 - lr: 0.0075 - 122ms/epoch - 122ms/step
# Epoch 456/1000
# 1/1 - 0s - loss: 0.0270 - mean_absolute_error: 0.0270 - val_loss: 0.0594 - val_mean_absolute_error: 0.0594 - lr: 0.0075 - 123ms/epoch - 123ms/step
# Epoch 457/1000
# 1/1 - 0s - loss: 0.0276 - mean_absolute_error: 0.0276 - val_loss: 0.0549 - val_mean_absolute_error: 0.0549 - lr: 0.0075 - 132ms/epoch - 132ms/step
# Epoch 458/1000
# 1/1 - 0s - loss: 0.0345 - mean_absolute_error: 0.0345 - val_loss: 0.0570 - val_mean_absolute_error: 0.0570 - lr: 0.0075 - 129ms/epoch - 129ms/step
# Epoch 459/1000
# 1/1 - 0s - loss: 0.0281 - mean_absolute_error: 0.0281 - val_loss: 0.0528 - val_mean_absolute_error: 0.0528 - lr: 0.0075 - 158ms/epoch - 158ms/step
# Epoch 460/1000
# 1/1 - 0s - loss: 0.0286 - mean_absolute_error: 0.0286 - val_loss: 0.0479 - val_mean_absolute_error: 0.0479 - lr: 0.0075 - 141ms/epoch - 141ms/step
# Epoch 461/1000
# 1/1 - 0s - loss: 0.0321 - mean_absolute_error: 0.0321 - val_loss: 0.0553 - val_mean_absolute_error: 0.0553 - lr: 0.0074 - 129ms/epoch - 129ms/step
# Epoch 462/1000
# 1/1 - 0s - loss: 0.0289 - mean_absolute_error: 0.0289 - val_loss: 0.0571 - val_mean_absolute_error: 0.0571 - lr: 0.0074 - 135ms/epoch - 135ms/step
# Epoch 463/1000
# 1/1 - 0s - loss: 0.0291 - mean_absolute_error: 0.0291 - val_loss: 0.0504 - val_mean_absolute_error: 0.0504 - lr: 0.0074 - 125ms/epoch - 125ms/step
# Epoch 464/1000
# 1/1 - 0s - loss: 0.0311 - mean_absolute_error: 0.0311 - val_loss: 0.0537 - val_mean_absolute_error: 0.0537 - lr: 0.0074 - 124ms/epoch - 124ms/step
# Epoch 465/1000
# 1/1 - 0s - loss: 0.0262 - mean_absolute_error: 0.0262 - val_loss: 0.0615 - val_mean_absolute_error: 0.0615 - lr: 0.0074 - 131ms/epoch - 131ms/step
# Epoch 466/1000
# 1/1 - 0s - loss: 0.0291 - mean_absolute_error: 0.0291 - val_loss: 0.0525 - val_mean_absolute_error: 0.0525 - lr: 0.0074 - 121ms/epoch - 121ms/step
# Epoch 467/1000
# 1/1 - 0s - loss: 0.0308 - mean_absolute_error: 0.0308 - val_loss: 0.0546 - val_mean_absolute_error: 0.0546 - lr: 0.0074 - 133ms/epoch - 133ms/step
# Epoch 468/1000
# 1/1 - 0s - loss: 0.0271 - mean_absolute_error: 0.0271 - val_loss: 0.0500 - val_mean_absolute_error: 0.0500 - lr: 0.0074 - 122ms/epoch - 122ms/step
# Epoch 469/1000
# 1/1 - 0s - loss: 0.0276 - mean_absolute_error: 0.0276 - val_loss: 0.0492 - val_mean_absolute_error: 0.0492 - lr: 0.0074 - 133ms/epoch - 133ms/step
# Epoch 470/1000
# 1/1 - 0s - loss: 0.0284 - mean_absolute_error: 0.0284 - val_loss: 0.0569 - val_mean_absolute_error: 0.0569 - lr: 0.0074 - 123ms/epoch - 123ms/step
# Epoch 471/1000
# 1/1 - 0s - loss: 0.0267 - mean_absolute_error: 0.0267 - val_loss: 0.0531 - val_mean_absolute_error: 0.0531 - lr: 0.0074 - 152ms/epoch - 152ms/step
# Epoch 472/1000
# 1/1 - 0s - loss: 0.0289 - mean_absolute_error: 0.0289 - val_loss: 0.0605 - val_mean_absolute_error: 0.0605 - lr: 0.0074 - 124ms/epoch - 124ms/step
# Epoch 473/1000
# 1/1 - 0s - loss: 0.0286 - mean_absolute_error: 0.0286 - val_loss: 0.0506 - val_mean_absolute_error: 0.0506 - lr: 0.0074 - 126ms/epoch - 126ms/step
# Epoch 474/1000
# 1/1 - 0s - loss: 0.0294 - mean_absolute_error: 0.0294 - val_loss: 0.0522 - val_mean_absolute_error: 0.0522 - lr: 0.0074 - 127ms/epoch - 127ms/step
# Epoch 475/1000
# 1/1 - 0s - loss: 0.0269 - mean_absolute_error: 0.0269 - val_loss: 0.0547 - val_mean_absolute_error: 0.0547 - lr: 0.0074 - 135ms/epoch - 135ms/step
# Epoch 476/1000
# 1/1 - 0s - loss: 0.0276 - mean_absolute_error: 0.0276 - val_loss: 0.0505 - val_mean_absolute_error: 0.0505 - lr: 0.0074 - 126ms/epoch - 126ms/step
# Epoch 477/1000
# 1/1 - 0s - loss: 0.0283 - mean_absolute_error: 0.0283 - val_loss: 0.0532 - val_mean_absolute_error: 0.0532 - lr: 0.0074 - 130ms/epoch - 130ms/step
# Epoch 478/1000
# 1/1 - 0s - loss: 0.0272 - mean_absolute_error: 0.0272 - val_loss: 0.0543 - val_mean_absolute_error: 0.0543 - lr: 0.0074 - 127ms/epoch - 127ms/step
# Epoch 479/1000
# 1/1 - 0s - loss: 0.0265 - mean_absolute_error: 0.0265 - val_loss: 0.0592 - val_mean_absolute_error: 0.0592 - lr: 0.0074 - 125ms/epoch - 125ms/step
# Epoch 480/1000
# 1/1 - 0s - loss: 0.0271 - mean_absolute_error: 0.0271 - val_loss: 0.0499 - val_mean_absolute_error: 0.0499 - lr: 0.0074 - 127ms/epoch - 127ms/step
# Epoch 481/1000
# 1/1 - 0s - loss: 0.0289 - mean_absolute_error: 0.0289 - val_loss: 0.0597 - val_mean_absolute_error: 0.0597 - lr: 0.0074 - 128ms/epoch - 128ms/step
# Epoch 482/1000
# 1/1 - 0s - loss: 0.0311 - mean_absolute_error: 0.0311 - val_loss: 0.0526 - val_mean_absolute_error: 0.0526 - lr: 0.0074 - 136ms/epoch - 136ms/step
# Epoch 483/1000
# 1/1 - 0s - loss: 0.0300 - mean_absolute_error: 0.0300 - val_loss: 0.0491 - val_mean_absolute_error: 0.0491 - lr: 0.0073 - 125ms/epoch - 125ms/step
# Epoch 484/1000
# 1/1 - 0s - loss: 0.0285 - mean_absolute_error: 0.0285 - val_loss: 0.0590 - val_mean_absolute_error: 0.0590 - lr: 0.0073 - 132ms/epoch - 132ms/step
# Epoch 485/1000
# 1/1 - 0s - loss: 0.0332 - mean_absolute_error: 0.0332 - val_loss: 0.0518 - val_mean_absolute_error: 0.0518 - lr: 0.0073 - 128ms/epoch - 128ms/step
# Epoch 486/1000
# 1/1 - 0s - loss: 0.0277 - mean_absolute_error: 0.0277 - val_loss: 0.0540 - val_mean_absolute_error: 0.0540 - lr: 0.0073 - 128ms/epoch - 128ms/step
# Epoch 487/1000
# 1/1 - 0s - loss: 0.0291 - mean_absolute_error: 0.0291 - val_loss: 0.0593 - val_mean_absolute_error: 0.0593 - lr: 0.0073 - 123ms/epoch - 123ms/step
# Epoch 488/1000
# 1/1 - 0s - loss: 0.0301 - mean_absolute_error: 0.0301 - val_loss: 0.0532 - val_mean_absolute_error: 0.0532 - lr: 0.0073 - 122ms/epoch - 122ms/step
# Epoch 489/1000
# 1/1 - 0s - loss: 0.0285 - mean_absolute_error: 0.0285 - val_loss: 0.0602 - val_mean_absolute_error: 0.0602 - lr: 0.0073 - 128ms/epoch - 128ms/step
# Epoch 490/1000
# 1/1 - 0s - loss: 0.0303 - mean_absolute_error: 0.0303 - val_loss: 0.0534 - val_mean_absolute_error: 0.0534 - lr: 0.0073 - 139ms/epoch - 139ms/step
# Epoch 491/1000
# 1/1 - 0s - loss: 0.0261 - mean_absolute_error: 0.0261 - val_loss: 0.0473 - val_mean_absolute_error: 0.0473 - lr: 0.0073 - 130ms/epoch - 130ms/step
# Epoch 492/1000
# 1/1 - 0s - loss: 0.0288 - mean_absolute_error: 0.0288 - val_loss: 0.0532 - val_mean_absolute_error: 0.0532 - lr: 0.0073 - 126ms/epoch - 126ms/step
# Epoch 493/1000
# 1/1 - 0s - loss: 0.0263 - mean_absolute_error: 0.0263 - val_loss: 0.0629 - val_mean_absolute_error: 0.0629 - lr: 0.0073 - 123ms/epoch - 123ms/step
# Epoch 494/1000
# 1/1 - 0s - loss: 0.0295 - mean_absolute_error: 0.0295 - val_loss: 0.0505 - val_mean_absolute_error: 0.0505 - lr: 0.0073 - 127ms/epoch - 127ms/step
# Epoch 495/1000
# 1/1 - 0s - loss: 0.0353 - mean_absolute_error: 0.0353 - val_loss: 0.0576 - val_mean_absolute_error: 0.0576 - lr: 0.0073 - 128ms/epoch - 128ms/step
# Epoch 496/1000
# 1/1 - 0s - loss: 0.0283 - mean_absolute_error: 0.0283 - val_loss: 0.0526 - val_mean_absolute_error: 0.0526 - lr: 0.0073 - 122ms/epoch - 122ms/step
# Epoch 497/1000
# 1/1 - 0s - loss: 0.0272 - mean_absolute_error: 0.0272 - val_loss: 0.0516 - val_mean_absolute_error: 0.0516 - lr: 0.0073 - 133ms/epoch - 133ms/step
# Epoch 498/1000
# 1/1 - 0s - loss: 0.0292 - mean_absolute_error: 0.0292 - val_loss: 0.0556 - val_mean_absolute_error: 0.0556 - lr: 0.0073 - 133ms/epoch - 133ms/step
# Epoch 499/1000
# 1/1 - 0s - loss: 0.0275 - mean_absolute_error: 0.0275 - val_loss: 0.0547 - val_mean_absolute_error: 0.0547 - lr: 0.0073 - 125ms/epoch - 125ms/step
# Epoch 500/1000
# 1/1 - 0s - loss: 0.0264 - mean_absolute_error: 0.0264 - val_loss: 0.0554 - val_mean_absolute_error: 0.0554 - lr: 0.0073 - 123ms/epoch - 123ms/step
# Epoch 501/1000
# 1/1 - 0s - loss: 0.0286 - mean_absolute_error: 0.0286 - val_loss: 0.0638 - val_mean_absolute_error: 0.0638 - lr: 0.0073 - 134ms/epoch - 134ms/step
# Epoch 502/1000
# 1/1 - 0s - loss: 0.0298 - mean_absolute_error: 0.0298 - val_loss: 0.0522 - val_mean_absolute_error: 0.0522 - lr: 0.0073 - 162ms/epoch - 162ms/step
# Epoch 503/1000
# 1/1 - 0s - loss: 0.0299 - mean_absolute_error: 0.0299 - val_loss: 0.0568 - val_mean_absolute_error: 0.0568 - lr: 0.0073 - 201ms/epoch - 201ms/step
# Epoch 504/1000
# 1/1 - 0s - loss: 0.0276 - mean_absolute_error: 0.0276 - val_loss: 0.0539 - val_mean_absolute_error: 0.0539 - lr: 0.0072 - 206ms/epoch - 206ms/step
# Epoch 505/1000
# 1/1 - 0s - loss: 0.0271 - mean_absolute_error: 0.0271 - val_loss: 0.0496 - val_mean_absolute_error: 0.0496 - lr: 0.0072 - 192ms/epoch - 192ms/step
# Epoch 506/1000
# 1/1 - 0s - loss: 0.0263 - mean_absolute_error: 0.0263 - val_loss: 0.0584 - val_mean_absolute_error: 0.0584 - lr: 0.0072 - 203ms/epoch - 203ms/step
# Epoch 507/1000
# 1/1 - 0s - loss: 0.0281 - mean_absolute_error: 0.0281 - val_loss: 0.0530 - val_mean_absolute_error: 0.0530 - lr: 0.0072 - 195ms/epoch - 195ms/step
# Epoch 508/1000
# 1/1 - 0s - loss: 0.0289 - mean_absolute_error: 0.0289 - val_loss: 0.0583 - val_mean_absolute_error: 0.0583 - lr: 0.0072 - 196ms/epoch - 196ms/step
# Epoch 509/1000
# 1/1 - 0s - loss: 0.0271 - mean_absolute_error: 0.0271 - val_loss: 0.0486 - val_mean_absolute_error: 0.0486 - lr: 0.0072 - 218ms/epoch - 218ms/step
# Epoch 510/1000
# 1/1 - 0s - loss: 0.0267 - mean_absolute_error: 0.0267 - val_loss: 0.0499 - val_mean_absolute_error: 0.0499 - lr: 0.0072 - 203ms/epoch - 203ms/step
# Epoch 511/1000
# 1/1 - 0s - loss: 0.0260 - mean_absolute_error: 0.0260 - val_loss: 0.0572 - val_mean_absolute_error: 0.0572 - lr: 0.0072 - 204ms/epoch - 204ms/step
# Epoch 512/1000
# 1/1 - 0s - loss: 0.0257 - mean_absolute_error: 0.0257 - val_loss: 0.0552 - val_mean_absolute_error: 0.0552 - lr: 0.0072 - 195ms/epoch - 195ms/step
# Epoch 513/1000
# 1/1 - 0s - loss: 0.0257 - mean_absolute_error: 0.0257 - val_loss: 0.0525 - val_mean_absolute_error: 0.0525 - lr: 0.0072 - 208ms/epoch - 208ms/step
# Epoch 514/1000
# 1/1 - 0s - loss: 0.0248 - mean_absolute_error: 0.0248 - val_loss: 0.0512 - val_mean_absolute_error: 0.0512 - lr: 0.0072 - 223ms/epoch - 223ms/step
# Epoch 515/1000
# 1/1 - 0s - loss: 0.0254 - mean_absolute_error: 0.0254 - val_loss: 0.0585 - val_mean_absolute_error: 0.0585 - lr: 0.0072 - 192ms/epoch - 192ms/step
# Epoch 516/1000
# 1/1 - 0s - loss: 0.0276 - mean_absolute_error: 0.0276 - val_loss: 0.0512 - val_mean_absolute_error: 0.0512 - lr: 0.0072 - 202ms/epoch - 202ms/step
# Epoch 517/1000
# 1/1 - 0s - loss: 0.0335 - mean_absolute_error: 0.0335 - val_loss: 0.0650 - val_mean_absolute_error: 0.0650 - lr: 0.0072 - 205ms/epoch - 205ms/step
# Epoch 518/1000
# 1/1 - 0s - loss: 0.0311 - mean_absolute_error: 0.0311 - val_loss: 0.0481 - val_mean_absolute_error: 0.0481 - lr: 0.0072 - 191ms/epoch - 191ms/step
# Epoch 519/1000
# 1/1 - 0s - loss: 0.0262 - mean_absolute_error: 0.0262 - val_loss: 0.0470 - val_mean_absolute_error: 0.0470 - lr: 0.0072 - 130ms/epoch - 130ms/step
# Epoch 520/1000
# 1/1 - 0s - loss: 0.0274 - mean_absolute_error: 0.0274 - val_loss: 0.0639 - val_mean_absolute_error: 0.0639 - lr: 0.0072 - 127ms/epoch - 127ms/step
# Epoch 521/1000
# 1/1 - 0s - loss: 0.0310 - mean_absolute_error: 0.0310 - val_loss: 0.0534 - val_mean_absolute_error: 0.0534 - lr: 0.0072 - 123ms/epoch - 123ms/step
# Epoch 522/1000
# 1/1 - 0s - loss: 0.0327 - mean_absolute_error: 0.0327 - val_loss: 0.0549 - val_mean_absolute_error: 0.0549 - lr: 0.0072 - 130ms/epoch - 130ms/step
# Epoch 523/1000
# 1/1 - 0s - loss: 0.0254 - mean_absolute_error: 0.0254 - val_loss: 0.0538 - val_mean_absolute_error: 0.0538 - lr: 0.0072 - 129ms/epoch - 129ms/step
# Epoch 524/1000
# 1/1 - 0s - loss: 0.0253 - mean_absolute_error: 0.0253 - val_loss: 0.0502 - val_mean_absolute_error: 0.0502 - lr: 0.0072 - 126ms/epoch - 126ms/step
# Epoch 525/1000
# 1/1 - 0s - loss: 0.0285 - mean_absolute_error: 0.0285 - val_loss: 0.0580 - val_mean_absolute_error: 0.0580 - lr: 0.0072 - 129ms/epoch - 129ms/step
# Epoch 526/1000
# 1/1 - 0s - loss: 0.0274 - mean_absolute_error: 0.0274 - val_loss: 0.0515 - val_mean_absolute_error: 0.0515 - lr: 0.0071 - 123ms/epoch - 123ms/step
# Epoch 527/1000
# 1/1 - 0s - loss: 0.0254 - mean_absolute_error: 0.0254 - val_loss: 0.0541 - val_mean_absolute_error: 0.0541 - lr: 0.0071 - 138ms/epoch - 138ms/step
# Epoch 528/1000
# 1/1 - 0s - loss: 0.0245 - mean_absolute_error: 0.0245 - val_loss: 0.0549 - val_mean_absolute_error: 0.0549 - lr: 0.0071 - 124ms/epoch - 124ms/step
# Epoch 529/1000
# 1/1 - 0s - loss: 0.0247 - mean_absolute_error: 0.0247 - val_loss: 0.0522 - val_mean_absolute_error: 0.0522 - lr: 0.0071 - 124ms/epoch - 124ms/step
# Epoch 530/1000
# 1/1 - 0s - loss: 0.0258 - mean_absolute_error: 0.0258 - val_loss: 0.0607 - val_mean_absolute_error: 0.0607 - lr: 0.0071 - 132ms/epoch - 132ms/step
# Epoch 531/1000
# 1/1 - 0s - loss: 0.0298 - mean_absolute_error: 0.0298 - val_loss: 0.0508 - val_mean_absolute_error: 0.0508 - lr: 0.0071 - 123ms/epoch - 123ms/step
# Epoch 532/1000
# 1/1 - 0s - loss: 0.0308 - mean_absolute_error: 0.0308 - val_loss: 0.0520 - val_mean_absolute_error: 0.0520 - lr: 0.0071 - 128ms/epoch - 128ms/step
# Epoch 533/1000
# 1/1 - 0s - loss: 0.0268 - mean_absolute_error: 0.0268 - val_loss: 0.0656 - val_mean_absolute_error: 0.0656 - lr: 0.0071 - 127ms/epoch - 127ms/step
# Epoch 534/1000
# 1/1 - 0s - loss: 0.0343 - mean_absolute_error: 0.0343 - val_loss: 0.0526 - val_mean_absolute_error: 0.0526 - lr: 0.0071 - 134ms/epoch - 134ms/step
# Epoch 535/1000
# 1/1 - 0s - loss: 0.0323 - mean_absolute_error: 0.0323 - val_loss: 0.0599 - val_mean_absolute_error: 0.0599 - lr: 0.0071 - 123ms/epoch - 123ms/step
# Epoch 536/1000
# 1/1 - 0s - loss: 0.0321 - mean_absolute_error: 0.0321 - val_loss: 0.0581 - val_mean_absolute_error: 0.0581 - lr: 0.0071 - 122ms/epoch - 122ms/step
# Epoch 537/1000
# Restoring model weights from the end of the best epoch: 437.
# 1/1 - 0s - loss: 0.0271 - mean_absolute_error: 0.0271 - val_loss: 0.0483 - val_mean_absolute_error: 0.0483 - lr: 0.0071 - 150ms/epoch - 150ms/step
# Epoch 537: early stopping

# %%
# Loss Curve
import matplotlib.pyplot as plt
from matplotlib import pyplot
pyplot.plot(history.history['loss'][:], label='train')
pyplot.plot(history.history['val_loss'][:], label='test')
pyplot.legend()
pyplot.show()

# %%
# prediction
yhat_test = model.predict(X_test)
yhat_train = model.predict(X_train)
# Out:
# 35/35 [==============================] - 2s 47ms/step
# 35/35 [==============================] - 1s 29ms/step

# %%
#Evaluating the perfomance of the model for Training data set and Testing data set using Nash-Sutcliffe
def nse(predictions, targets):
    return (1-(np.sum((predictions-targets)**2)/np.sum((targets-np.mean(targets))**2)))
inv_yhat_train = inv_yhat(yhat_train)
inv_yhat_test = inv_yhat(yhat_test)
inv_y_train = inv_y(y_train)
inv_y_test = inv_y(y_test)
print("train",nse(np.array(inv_yhat_train),np.array(inv_y_train)))
print("test",nse(np.array(inv_yhat_test),np.array(inv_y_test)))
# Out:
# train 0.8914353023648474
# test 0.8313912033395459

# %%
# Train PLot
import matplotlib.pyplot as plt
plt.plot(inv_y_train[:])
plt.plot(inv_yhat_train[:])

# %%
# Test Plot
import matplotlib.pyplot as plt
import plotly.express as px
plt.plot(inv_y_test[:])
plt.plot(inv_yhat_test[:])

# %%
import plotly.express as px
def reg_test_discharge_fig(inv_yhat_test,inv_y_test):
    reg_test_discharge_fig = px.scatter( x=inv_yhat_test, y=inv_y_test,
                                        trendline="ols",
                                        template = 'plotly_dark',
                                        title='Regression Plot between Observed and Simulated River Discharge')
    #reg_test_discharge_fig.update_layout(autosize=False,width=500,height=500)
    return reg_test_discharge_fig
reg_test_discharge_fig(inv_yhat_test,inv_y_test)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="196846be-3acc-49cf-a472-0ce28877110f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("196846be-3acc-49cf-a472-0ce28877110f")) {                    Plotly.newPlot(                        "196846be-3acc-49cf-a472-0ce28877110f",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","showlegend":false,"x":[57.978017218132536,63.963187324534495,65.88655780559144,59.093568131767704,61.48064449218732,58.6795105856297,60.51276785486717,67.08521042201562,56.37417508241607,62.653945726988525,62.80747794786627,61.90130799734759,63.12582569207179,61.68102224512203,64.36536676154378,55.738876488477665,54.75767978644412,60.74657194069901,61.14766089879739,62.149315345688436,54.153004724235146,48.12141266022922,47.04118064619606,53.244554681448214,51.46926402671448,49.438242549039515,51.90719495000118,45.1862039209645,50.420926267769744,48.10427141321645,51.01385840418607,54.76722372997016,39.68252982095108,34.71775958404088,60.62953922055823,62.16496957600451,60.20970483985914,62.39240202059659,58.868424791666286,56.233962926251714,54.735410584883375,59.75427218066352,62.12760490191675,53.90591662257953,53.96372101707999,50.41836679660695,56.81491781909287,52.385113104095254,45.32082849923825,57.57232301438562,63.91980248588074,59.82836166104834,47.76527666748293,59.71207695536711,59.371820498497,57.1943864556436,55.85795498310419,65.61043232334953,64.34423310000595,58.905140585740945,62.73570460863932,59.90557838260742,62.54441117588802,59.58857345954012,59.71003118088136,67.824167598047,57.98342455157505,65.39011953445676,65.74081214487092,68.01818272196435,64.23180111940252,69.76068691159165,68.38967554168737,64.05431441137443,61.382339170202435,65.32470882424715,62.6433473534412,64.96723451647385,106.20924606141239,71.7536092190529,78.92443181106101,43.302726042379696,76.28164715825618,84.42973261721839,73.8570033487447,69.82401129231467,56.529676473889126,58.62709550012695,56.48129435791225,72.93968527911206,69.75281022921038,67.01505477671022,64.09767221336098,55.015852921656894,61.1618911979736,66.86984534322275,62.693004698888274,65.83408414064306,67.23101466218178,56.319177995194515,78.19932191475367,78.96308523295257,66.06327847471515,63.507231956439426,62.89616722854588,65.68218763813167,58.94019362478203,70.06640853220891,75.93428456402036,64.40451360261197,71.57286008651452,62.121303105400614,56.56308928845265,57.08055758056751,61.86825567168023,67.13849293392478,70.54122197568475,72.69003770629364,80.17023637510391,75.43471454560023,85.11928479003001,74.86261416127118,79.42575921284997,72.06093050914691,71.27377596769794,68.98072862973243,69.99154400069732,74.78889868811613,69.78453325207313,77.95308997422646,64.30945042763699,72.2873040176065,71.0851726833343,61.34283634634928,71.64126736067351,68.4721599072417,59.43505701005159,62.843704828875495,72.9034155900464,75.17789324374809,72.65684118506782,73.58824535831822,62.83686680512632,63.61211620077936,70.28140410988321,75.96375453128206,82.14124996990058,72.36286249024322,69.04987040001735,69.22361703574768,55.75131335539544,62.440229884895615,76.7123187363963,67.58710108770484,65.88302276135339,65.66187859494383,69.61184555247529,76.49057751025246,95.37488747043393,104.38884923354568,145.0853058952467,168.01479694265987,215.1415644119729,370.3564212859118,357.29086173321656,427.27502247070925,644.8529623527082,623.9372163526212,643.4231912927287,683.1535377127008,667.9597238148118,638.3445516257416,590.4178773202776,662.8177101998784,686.719854362486,645.8142420432285,644.382308049872,688.826263080572,676.8847800039063,710.2208464814382,653.8786670416126,635.944344457279,6 ...
