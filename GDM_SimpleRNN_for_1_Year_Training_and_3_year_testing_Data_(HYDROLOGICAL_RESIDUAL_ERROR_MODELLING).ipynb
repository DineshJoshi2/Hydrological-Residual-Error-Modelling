# %% [markdown]
# <a href="https://colab.research.google.com/github/DineshJoshi2/Hydrological-Residual-Error-Modelling/blob/main/GDM_SimpleRNN_for_1_Year_Training_and_3_year_testing_Data_(HYDROLOGICAL_RESIDUAL_ERROR_MODELLING).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#For reproducibility of the code
import os
os.environ["PYTHONHASHSEED"] = "0"
#os.environ["CUDA_VISIBLE_DEVICES"] = ""
import numpy as np
import random as rn
import tensorflow as tf
# setting the seed for numpy generated random numbers
np.random.seed(73)
# setting the seed for python random number
rn.seed(723)
# setting the seed for tensorflow random number
tf.random.set_seed(1)

# %%
# importing necessary libraries
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras import optimizers
from tensorflow.keras.layers import Dropout
from tensorflow.keras.constraints import MaxNorm
from sklearn.model_selection import GridSearchCV

# %%
# importing data sets
df= pd.read_csv("/content/drive/MyDrive/Data/OneYearResidualErrorModelling.csv")
df=df[365:].reset_index(drop=True)

# %%
# Retriving the necessary columns from the datasets.
 df=df[['Temperature (Deg C)', 'Precipitation (mm)',
       'Precipitation0816 (mm)', 'Temperature0816 (Deg C)', 'Residual Error']]

# %%
# Importing necessary libraries
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error

# %%
# extrating the vaules from the data frame
values = df.values
values
# change all datatype to float
values = values.astype('float32')

# %%
# normalization all features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)

# %%
#converting the data into 3D array
l=[]
for i in range(len(df)-365):
    l.append(scaled[i:366+i,:])
Data=np.array(l)

# %%
# checking the shape of the data
Data.shape
# Out:
# (2192, 366, 5)

# %%
## Test and Train data
X=Data[:,:,:-1]
y=Data[:,-1,-1]
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.833, shuffle =False)

# %%
# Checking Shape of test and Training Data
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (366, 366, 4)
# (1826, 366, 4)
# (366,)
# (1826,)

# %%
# Useful functions to undo normalization later
def inv_yhat(yhat):
  yhat=[i[0] for i in yhat]
  A=np.zeros((len(yhat),5))
  A[:,0]=yhat
  A[:,1]=yhat
  A[:,2]=yhat
  A[:,3]=yhat
  A[:,4]=yhat
  inv_yhat= scaler.inverse_transform(A)
  inv_yhat = [i[-1] for i in inv_yhat]
  return inv_yhat
def inv_y(y):
  A=np.zeros((len(y),5))
  A[:,0]=y
  A[:,1]=y
  A[:,2]=y
  A[:,3]=y
  A[:,4]=y
  inv_y= scaler.inverse_transform(A)
  inv_y = [i[-1] for i in inv_y]
  return inv_y

# %%
# Import necessary libraries
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import GRU,SimpleRNN
from keras import optimizers
from tensorflow.keras.layers import Dropout
from tensorflow.keras.constraints import MaxNorm
from sklearn.model_selection import GridSearchCV

# %%
# Defining model parameters
epochs=1000
learning_rate1 = 0.01
decay_rate = (learning_rate1*128)/epochs

# %%
# For reproducibility of the code
import os
os.environ["PYTHONHASHSEED"] = "0"
#os.environ["CUDA_VISIBLE_DEVICES"] = ""
import numpy as np
import random as rn
import tensorflow as tf
# setting the seed for numpy generated random numbers
np.random.seed(73)
# setting the seed for python random number
rn.seed(723)
# setting the seed for tensorflow random number
tf.random.set_seed(1)

# %%
# Building the Main model
model = Sequential()
model.add(SimpleRNN(64,kernel_initializer="GlorotUniform",dropout=0.4,return_sequences=False,input_shape=(X_train.shape[1], X_train.shape[2]))) # main model
model.add(Dense(1))
Adam=tf.keras.optimizers.Adam(learning_rate = learning_rate1, beta_1 = 0.9, beta_2 = 0.999, amsgrad = False)
model.compile(loss="mae", optimizer=Adam, metrics=[tf.keras.metrics.MeanAbsoluteError()])

# %%
#Add Callbacks, e.g. ModelCheckpoints, earlystopping, csvlogger.
from keras.callbacks import ModelCheckpoint, EarlyStopping, CSVLogger,LearningRateScheduler

#ModelCheckpoint callback saves a model at some interval.
filepath="saved_models/weights-improvement-{epoch:02d}-{val_acc:.2f}.hdf5" #File name includes epoch and validation accuracy.
#Use Mode = max for accuracy and min for loss.
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

#https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/EarlyStopping
early_stop = EarlyStopping(monitor='val_loss',min_delta=0.0001, patience= 100,verbose=1,restore_best_weights=True)
#This callback will stop the training when there is no improvement in
# the validation loss for three consecutive epochs.

#CSVLogger logs epoch, acc, loss, val_acc, val_loss
log_csv = CSVLogger("/content/drive/MyDrive/Data/LSTMlogs.csv", separator=',', append=False)

#learning rate decay
def exp_decay(epoch):
  lrate = learning_rate1 * np.exp(-decay_rate*epoch)
  return lrate

# learning schedule callback
lr_rate = LearningRateScheduler(exp_decay)

callbacks_list = [early_stop]

# %%
# Training the Model
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs =epochs ,callbacks=callbacks_list, batch_size=len(X_train), verbose = 2, shuffle = True)
# Out:
# Epoch 1/1000
# 1/1 - 1s - loss: 0.8761 - mean_absolute_error: 0.8761 - val_loss: 0.2187 - val_mean_absolute_error: 0.2187 - 1s/epoch - 1s/step
# Epoch 2/1000
# 1/1 - 0s - loss: 0.2507 - mean_absolute_error: 0.2507 - val_loss: 0.5572 - val_mean_absolute_error: 0.5572 - 278ms/epoch - 278ms/step
# Epoch 3/1000
# 1/1 - 0s - loss: 0.4711 - mean_absolute_error: 0.4711 - val_loss: 0.1011 - val_mean_absolute_error: 0.1011 - 248ms/epoch - 248ms/step
# Epoch 4/1000
# 1/1 - 0s - loss: 0.2135 - mean_absolute_error: 0.2135 - val_loss: 0.2279 - val_mean_absolute_error: 0.2279 - 239ms/epoch - 239ms/step
# Epoch 5/1000
# 1/1 - 0s - loss: 0.2486 - mean_absolute_error: 0.2486 - val_loss: 0.3000 - val_mean_absolute_error: 0.3000 - 246ms/epoch - 246ms/step
# Epoch 6/1000
# 1/1 - 0s - loss: 0.2676 - mean_absolute_error: 0.2676 - val_loss: 0.1133 - val_mean_absolute_error: 0.1133 - 243ms/epoch - 243ms/step
# Epoch 7/1000
# 1/1 - 0s - loss: 0.1523 - mean_absolute_error: 0.1523 - val_loss: 0.1884 - val_mean_absolute_error: 0.1884 - 245ms/epoch - 245ms/step
# Epoch 8/1000
# 1/1 - 0s - loss: 0.2029 - mean_absolute_error: 0.2029 - val_loss: 0.0921 - val_mean_absolute_error: 0.0921 - 243ms/epoch - 243ms/step
# Epoch 9/1000
# 1/1 - 0s - loss: 0.1337 - mean_absolute_error: 0.1337 - val_loss: 0.1567 - val_mean_absolute_error: 0.1567 - 238ms/epoch - 238ms/step
# Epoch 10/1000
# 1/1 - 0s - loss: 0.1535 - mean_absolute_error: 0.1535 - val_loss: 0.0728 - val_mean_absolute_error: 0.0728 - 242ms/epoch - 242ms/step
# Epoch 11/1000
# 1/1 - 0s - loss: 0.1067 - mean_absolute_error: 0.1067 - val_loss: 0.1235 - val_mean_absolute_error: 0.1235 - 246ms/epoch - 246ms/step
# Epoch 12/1000
# 1/1 - 0s - loss: 0.1294 - mean_absolute_error: 0.1294 - val_loss: 0.0559 - val_mean_absolute_error: 0.0559 - 240ms/epoch - 240ms/step
# Epoch 13/1000
# 1/1 - 0s - loss: 0.0823 - mean_absolute_error: 0.0823 - val_loss: 0.1574 - val_mean_absolute_error: 0.1574 - 239ms/epoch - 239ms/step
# Epoch 14/1000
# 1/1 - 0s - loss: 0.1317 - mean_absolute_error: 0.1317 - val_loss: 0.0792 - val_mean_absolute_error: 0.0792 - 233ms/epoch - 233ms/step
# Epoch 15/1000
# 1/1 - 0s - loss: 0.0909 - mean_absolute_error: 0.0909 - val_loss: 0.1151 - val_mean_absolute_error: 0.1151 - 247ms/epoch - 247ms/step
# Epoch 16/1000
# 1/1 - 0s - loss: 0.1260 - mean_absolute_error: 0.1260 - val_loss: 0.0938 - val_mean_absolute_error: 0.0938 - 242ms/epoch - 242ms/step
# Epoch 17/1000
# 1/1 - 0s - loss: 0.1130 - mean_absolute_error: 0.1130 - val_loss: 0.0919 - val_mean_absolute_error: 0.0919 - 239ms/epoch - 239ms/step
# Epoch 18/1000
# 1/1 - 0s - loss: 0.0926 - mean_absolute_error: 0.0926 - val_loss: 0.1287 - val_mean_absolute_error: 0.1287 - 234ms/epoch - 234ms/step
# Epoch 19/1000
# 1/1 - 0s - loss: 0.1075 - mean_absolute_error: 0.1075 - val_loss: 0.0564 - val_mean_absolute_error: 0.0564 - 245ms/epoch - 245ms/step
# Epoch 20/1000
# 1/1 - 0s - loss: 0.0722 - mean_absolute_error: 0.0722 - val_loss: 0.0840 - val_mean_absolute_error: 0.0840 - 238ms/epoch - 238ms/step
# Epoch 21/1000
# 1/1 - 0s - loss: 0.0984 - mean_absolute_error: 0.0984 - val_loss: 0.0585 - val_mean_absolute_error: 0.0585 - 236ms/epoch - 236ms/step
# Epoch 22/1000
# 1/1 - 0s - loss: 0.0803 - mean_absolute_error: 0.0803 - val_loss: 0.0894 - val_mean_absolute_error: 0.0894 - 234ms/epoch - 234ms/step
# Epoch 23/1000
# 1/1 - 0s - loss: 0.0768 - mean_absolute_error: 0.0768 - val_loss: 0.0997 - val_mean_absolute_error: 0.0997 - 246ms/epoch - 246ms/step
# Epoch 24/1000
# 1/1 - 0s - loss: 0.0907 - mean_absolute_error: 0.0907 - val_loss: 0.0578 - val_mean_absolute_error: 0.0578 - 239ms/epoch - 239ms/step
# Epoch 25/1000
# 1/1 - 0s - loss: 0.0691 - mean_absolute_error: 0.0691 - val_loss: 0.0717 - val_mean_absolute_error: 0.0717 - 246ms/epoch - 246ms/step
# Epoch 26/1000
# 1/1 - 0s - loss: 0.0876 - mean_absolute_error: 0.0876 - val_loss: 0.0542 - val_mean_absolute_error: 0.0542 - 242ms/epoch - 242ms/step
# Epoch 27/1000
# 1/1 - 0s - loss: 0.0677 - mean_absolute_error: 0.0677 - val_loss: 0.0816 - val_mean_absolute_error: 0.0816 - 229ms/epoch - 229ms/step
# Epoch 28/1000
# 1/1 - 0s - loss: 0.0732 - mean_absolute_error: 0.0732 - val_loss: 0.0820 - val_mean_absolute_error: 0.0820 - 240ms/epoch - 240ms/step
# Epoch 29/1000
# 1/1 - 0s - loss: 0.0720 - mean_absolute_error: 0.0720 - val_loss: 0.0542 - val_mean_absolute_error: 0.0542 - 245ms/epoch - 245ms/step
# Epoch 30/1000
# 1/1 - 0s - loss: 0.0663 - mean_absolute_error: 0.0663 - val_loss: 0.0590 - val_mean_absolute_error: 0.0590 - 240ms/epoch - 240ms/step
# Epoch 31/1000
# 1/1 - 0s - loss: 0.0737 - mean_absolute_error: 0.0737 - val_loss: 0.0654 - val_mean_absolute_error: 0.0654 - 233ms/epoch - 233ms/step
# Epoch 32/1000
# 1/1 - 0s - loss: 0.0657 - mean_absolute_error: 0.0657 - val_loss: 0.0885 - val_mean_absolute_error: 0.0885 - 244ms/epoch - 244ms/step
# Epoch 33/1000
# 1/1 - 0s - loss: 0.0803 - mean_absolute_error: 0.0803 - val_loss: 0.0552 - val_mean_absolute_error: 0.0552 - 230ms/epoch - 230ms/step
# Epoch 34/1000
# 1/1 - 0s - loss: 0.0653 - mean_absolute_error: 0.0653 - val_loss: 0.0609 - val_mean_absolute_error: 0.0609 - 236ms/epoch - 236ms/step
# Epoch 35/1000
# 1/1 - 0s - loss: 0.0726 - mean_absolute_error: 0.0726 - val_loss: 0.0655 - val_mean_absolute_error: 0.0655 - 234ms/epoch - 234ms/step
# Epoch 36/1000
# 1/1 - 0s - loss: 0.0634 - mean_absolute_error: 0.0634 - val_loss: 0.0814 - val_mean_absolute_error: 0.0814 - 245ms/epoch - 245ms/step
# Epoch 37/1000
# 1/1 - 0s - loss: 0.0719 - mean_absolute_error: 0.0719 - val_loss: 0.0544 - val_mean_absolute_error: 0.0544 - 238ms/epoch - 238ms/step
# Epoch 38/1000
# 1/1 - 0s - loss: 0.0624 - mean_absolute_error: 0.0624 - val_loss: 0.0544 - val_mean_absolute_error: 0.0544 - 232ms/epoch - 232ms/step
# Epoch 39/1000
# 1/1 - 0s - loss: 0.0609 - mean_absolute_error: 0.0609 - val_loss: 0.0639 - val_mean_absolute_error: 0.0639 - 234ms/epoch - 234ms/step
# Epoch 40/1000
# 1/1 - 0s - loss: 0.0615 - mean_absolute_error: 0.0615 - val_loss: 0.0693 - val_mean_absolute_error: 0.0693 - 236ms/epoch - 236ms/step
# Epoch 41/1000
# 1/1 - 0s - loss: 0.0629 - mean_absolute_error: 0.0629 - val_loss: 0.0544 - val_mean_absolute_error: 0.0544 - 234ms/epoch - 234ms/step
# Epoch 42/1000
# 1/1 - 0s - loss: 0.0621 - mean_absolute_error: 0.0621 - val_loss: 0.0538 - val_mean_absolute_error: 0.0538 - 230ms/epoch - 230ms/step
# Epoch 43/1000
# 1/1 - 0s - loss: 0.0597 - mean_absolute_error: 0.0597 - val_loss: 0.0693 - val_mean_absolute_error: 0.0693 - 233ms/epoch - 233ms/step
# Epoch 44/1000
# 1/1 - 0s - loss: 0.0607 - mean_absolute_error: 0.0607 - val_loss: 0.0578 - val_mean_absolute_error: 0.0578 - 236ms/epoch - 236ms/step
# Epoch 45/1000
# 1/1 - 0s - loss: 0.0576 - mean_absolute_error: 0.0576 - val_loss: 0.0553 - val_mean_absolute_error: 0.0553 - 233ms/epoch - 233ms/step
# Epoch 46/1000
# 1/1 - 0s - loss: 0.0631 - mean_absolute_error: 0.0631 - val_loss: 0.0645 - val_mean_absolute_error: 0.0645 - 229ms/epoch - 229ms/step
# Epoch 47/1000
# 1/1 - 0s - loss: 0.0618 - mean_absolute_error: 0.0618 - val_loss: 0.0605 - val_mean_absolute_error: 0.0605 - 229ms/epoch - 229ms/step
# Epoch 48/1000
# 1/1 - 0s - loss: 0.0597 - mean_absolute_error: 0.0597 - val_loss: 0.0541 - val_mean_absolute_error: 0.0541 - 233ms/epoch - 233ms/step
# Epoch 49/1000
# 1/1 - 0s - loss: 0.0612 - mean_absolute_error: 0.0612 - val_loss: 0.0669 - val_mean_absolute_error: 0.0669 - 248ms/epoch - 248ms/step
# Epoch 50/1000
# 1/1 - 0s - loss: 0.0587 - mean_absolute_error: 0.0587 - val_loss: 0.0584 - val_mean_absolute_error: 0.0584 - 238ms/epoch - 238ms/step
# Epoch 51/1000
# 1/1 - 0s - loss: 0.0590 - mean_absolute_error: 0.0590 - val_loss: 0.0542 - val_mean_absolute_error: 0.0542 - 235ms/epoch - 235ms/step
# Epoch 52/1000
# 1/1 - 0s - loss: 0.0608 - mean_absolute_error: 0.0608 - val_loss: 0.0679 - val_mean_absolute_error: 0.0679 - 229ms/epoch - 229ms/step
# Epoch 53/1000
# 1/1 - 0s - loss: 0.0622 - mean_absolute_error: 0.0622 - val_loss: 0.0589 - val_mean_absolute_error: 0.0589 - 249ms/epoch - 249ms/step
# Epoch 54/1000
# 1/1 - 0s - loss: 0.0584 - mean_absolute_error: 0.0584 - val_loss: 0.0537 - val_mean_absolute_error: 0.0537 - 248ms/epoch - 248ms/step
# Epoch 55/1000
# 1/1 - 0s - loss: 0.0590 - mean_absolute_error: 0.0590 - val_loss: 0.0684 - val_mean_absolute_error: 0.0684 - 233ms/epoch - 233ms/step
# Epoch 56/1000
# 1/1 - 0s - loss: 0.0594 - mean_absolute_error: 0.0594 - val_loss: 0.0566 - val_mean_absolute_error: 0.0566 - 231ms/epoch - 231ms/step
# Epoch 57/1000
# 1/1 - 0s - loss: 0.0584 - mean_absolute_error: 0.0584 - val_loss: 0.0548 - val_mean_absolute_error: 0.0548 - 246ms/epoch - 246ms/step
# Epoch 58/1000
# 1/1 - 0s - loss: 0.0620 - mean_absolute_error: 0.0620 - val_loss: 0.0723 - val_mean_absolute_error: 0.0723 - 236ms/epoch - 236ms/step
# Epoch 59/1000
# 1/1 - 0s - loss: 0.0617 - mean_absolute_error: 0.0617 - val_loss: 0.0544 - val_mean_absolute_error: 0.0544 - 241ms/epoch - 241ms/step
# Epoch 60/1000
# 1/1 - 0s - loss: 0.0551 - mean_absolute_error: 0.0551 - val_loss: 0.0561 - val_mean_absolute_error: 0.0561 - 236ms/epoch - 236ms/step
# Epoch 61/1000
# 1/1 - 0s - loss: 0.0655 - mean_absolute_error: 0.0655 - val_loss: 0.0764 - val_mean_absolute_error: 0.0764 - 252ms/epoch - 252ms/step
# Epoch 62/1000
# 1/1 - 0s - loss: 0.0653 - mean_absolute_error: 0.0653 - val_loss: 0.0551 - val_mean_absolute_error: 0.0551 - 228ms/epoch - 228ms/step
# Epoch 63/1000
# 1/1 - 0s - loss: 0.0552 - mean_absolute_error: 0.0552 - val_loss: 0.0629 - val_mean_absolute_error: 0.0629 - 238ms/epoch - 238ms/step
# Epoch 64/1000
# 1/1 - 0s - loss: 0.0705 - mean_absolute_error: 0.0705 - val_loss: 0.0720 - val_mean_absolute_error: 0.0720 - 235ms/epoch - 235ms/step
# Epoch 65/1000
# 1/1 - 0s - loss: 0.0648 - mean_absolute_error: 0.0648 - val_loss: 0.0657 - val_mean_absolute_error: 0.0657 - 252ms/epoch - 252ms/step
# Epoch 66/1000
# 1/1 - 0s - loss: 0.0620 - mean_absolute_error: 0.0620 - val_loss: 0.0620 - val_mean_absolute_error: 0.0620 - 238ms/epoch - 238ms/step
# Epoch 67/1000
# 1/1 - 0s - loss: 0.0731 - mean_absolute_error: 0.0731 - val_loss: 0.0567 - val_mean_absolute_error: 0.0567 - 243ms/epoch - 243ms/step
# Epoch 68/1000
# 1/1 - 0s - loss: 0.0566 - mean_absolute_error: 0.0566 - val_loss: 0.0802 - val_mean_absolute_error: 0.0802 - 256ms/epoch - 256ms/step
# Epoch 69/1000
# 1/1 - 0s - loss: 0.0705 - mean_absolute_error: 0.0705 - val_loss: 0.0529 - val_mean_absolute_error: 0.0529 - 253ms/epoch - 253ms/step
# Epoch 70/1000
# 1/1 - 0s - loss: 0.0584 - mean_absolute_error: 0.0584 - val_loss: 0.0583 - val_mean_absolute_error: 0.0583 - 248ms/epoch - 248ms/step
# Epoch 71/1000
# 1/1 - 0s - loss: 0.0663 - mean_absolute_error: 0.0663 - val_loss: 0.0648 - val_mean_absolute_error: 0.0648 - 236ms/epoch - 236ms/step
# Epoch 72/1000
# 1/1 - 0s - loss: 0.0609 - mean_absolute_error: 0.0609 - val_loss: 0.0644 - val_mean_absolute_error: 0.0644 - 243ms/epoch - 243ms/step
# Epoch 73/1000
# 1/1 - 0s - loss: 0.0584 - mean_absolute_error: 0.0584 - val_loss: 0.0552 - val_mean_absolute_error: 0.0552 - 232ms/epoch - 232ms/step
# Epoch 74/1000
# 1/1 - 0s - loss: 0.0586 - mean_absolute_error: 0.0586 - val_loss: 0.0529 - val_mean_absolute_error: 0.0529 - 244ms/epoch - 244ms/step
# Epoch 75/1000
# 1/1 - 0s - loss: 0.0554 - mean_absolute_error: 0.0554 - val_loss: 0.0711 - val_mean_absolute_error: 0.0711 - 238ms/epoch - 238ms/step
# Epoch 76/1000
# 1/1 - 0s - loss: 0.0641 - mean_absolute_error: 0.0641 - val_loss: 0.0537 - val_mean_absolute_error: 0.0537 - 237ms/epoch - 237ms/step
# Epoch 77/1000
# 1/1 - 0s - loss: 0.0568 - mean_absolute_error: 0.0568 - val_loss: 0.0572 - val_mean_absolute_error: 0.0572 - 232ms/epoch - 232ms/step
# Epoch 78/1000
# 1/1 - 0s - loss: 0.0606 - mean_absolute_error: 0.0606 - val_loss: 0.0610 - val_mean_absolute_error: 0.0610 - 249ms/epoch - 249ms/step
# Epoch 79/1000
# 1/1 - 0s - loss: 0.0567 - mean_absolute_error: 0.0567 - val_loss: 0.0604 - val_mean_absolute_error: 0.0604 - 236ms/epoch - 236ms/step
# Epoch 80/1000
# 1/1 - 0s - loss: 0.0561 - mean_absolute_error: 0.0561 - val_loss: 0.0533 - val_mean_absolute_error: 0.0533 - 234ms/epoch - 234ms/step
# Epoch 81/1000
# 1/1 - 0s - loss: 0.0586 - mean_absolute_error: 0.0586 - val_loss: 0.0533 - val_mean_absolute_error: 0.0533 - 238ms/epoch - 238ms/step
# Epoch 82/1000
# 1/1 - 0s - loss: 0.0558 - mean_absolute_error: 0.0558 - val_loss: 0.0592 - val_mean_absolute_error: 0.0592 - 237ms/epoch - 237ms/step
# Epoch 83/1000
# 1/1 - 0s - loss: 0.0550 - mean_absolute_error: 0.0550 - val_loss: 0.0541 - val_mean_absolute_error: 0.0541 - 244ms/epoch - 244ms/step
# Epoch 84/1000
# 1/1 - 0s - loss: 0.0548 - mean_absolute_error: 0.0548 - val_loss: 0.0546 - val_mean_absolute_error: 0.0546 - 233ms/epoch - 233ms/step
# Epoch 85/1000
# 1/1 - 0s - loss: 0.0552 - mean_absolute_error: 0.0552 - val_loss: 0.0536 - val_mean_absolute_error: 0.0536 - 247ms/epoch - 247ms/step
# Epoch 86/1000
# 1/1 - 0s - loss: 0.0549 - mean_absolute_error: 0.0549 - val_loss: 0.0583 - val_mean_absolute_error: 0.0583 - 239ms/epoch - 239ms/step
# Epoch 87/1000
# 1/1 - 0s - loss: 0.0584 - mean_absolute_error: 0.0584 - val_loss: 0.0530 - val_mean_absolute_error: 0.0530 - 228ms/epoch - 228ms/step
# Epoch 88/1000
# 1/1 - 0s - loss: 0.0553 - mean_absolute_error: 0.0553 - val_loss: 0.0559 - val_mean_absolute_error: 0.0559 - 245ms/epoch - 245ms/step
# Epoch 89/1000
# 1/1 - 0s - loss: 0.0545 - mean_absolute_error: 0.0545 - val_loss: 0.0558 - val_mean_absolute_error: 0.0558 - 226ms/epoch - 226ms/step
# Epoch 90/1000
# 1/1 - 0s - loss: 0.0549 - mean_absolute_error: 0.0549 - val_loss: 0.0529 - val_mean_absolute_error: 0.0529 - 245ms/epoch - 245ms/step
# Epoch 91/1000
# 1/1 - 0s - loss: 0.0555 - mean_absolute_error: 0.0555 - val_loss: 0.0562 - val_mean_absolute_error: 0.0562 - 239ms/epoch - 239ms/step
# Epoch 92/1000
# 1/1 - 0s - loss: 0.0553 - mean_absolute_error: 0.0553 - val_loss: 0.0551 - val_mean_absolute_error: 0.0551 - 243ms/epoch - 243ms/step
# Epoch 93/1000
# 1/1 - 0s - loss: 0.0540 - mean_absolute_error: 0.0540 - val_loss: 0.0544 - val_mean_absolute_error: 0.0544 - 234ms/epoch - 234ms/step
# Epoch 94/1000
# 1/1 - 0s - loss: 0.0534 - mean_absolute_error: 0.0534 - val_loss: 0.0537 - val_mean_absolute_error: 0.0537 - 246ms/epoch - 246ms/step
# Epoch 95/1000
# 1/1 - 0s - loss: 0.0544 - mean_absolute_error: 0.0544 - val_loss: 0.0667 - val_mean_absolute_error: 0.0667 - 235ms/epoch - 235ms/step
# Epoch 96/1000
# 1/1 - 0s - loss: 0.0576 - mean_absolute_error: 0.0576 - val_loss: 0.0562 - val_mean_absolute_error: 0.0562 - 243ms/epoch - 243ms/step
# Epoch 97/1000
# 1/1 - 0s - loss: 0.0585 - mean_absolute_error: 0.0585 - val_loss: 0.0605 - val_mean_absolute_error: 0.0605 - 231ms/epoch - 231ms/step
# Epoch 98/1000
# 1/1 - 0s - loss: 0.0581 - mean_absolute_error: 0.0581 - val_loss: 0.0590 - val_mean_absolute_error: 0.0590 - 243ms/epoch - 243ms/step
# Epoch 99/1000
# 1/1 - 0s - loss: 0.0566 - mean_absolute_error: 0.0566 - val_loss: 0.0617 - val_mean_absolute_error: 0.0617 - 246ms/epoch - 246ms/step
# Epoch 100/1000
# 1/1 - 0s - loss: 0.0621 - mean_absolute_error: 0.0621 - val_loss: 0.0659 - val_mean_absolute_error: 0.0659 - 238ms/epoch - 238ms/step
# Epoch 101/1000
# 1/1 - 0s - loss: 0.0603 - mean_absolute_error: 0.0603 - val_loss: 0.0541 - val_mean_absolute_error: 0.0541 - 237ms/epoch - 237ms/step
# Epoch 102/1000
# 1/1 - 0s - loss: 0.0548 - mean_absolute_error: 0.0548 - val_loss: 0.0530 - val_mean_absolute_error: 0.0530 - 241ms/epoch - 241ms/step
# Epoch 103/1000
# 1/1 - 0s - loss: 0.0538 - mean_absolute_error: 0.0538 - val_loss: 0.0629 - val_mean_absolute_error: 0.0629 - 256ms/epoch - 256ms/step
# Epoch 104/1000
# 1/1 - 0s - loss: 0.0589 - mean_absolute_error: 0.0589 - val_loss: 0.0574 - val_mean_absolute_error: 0.0574 - 234ms/epoch - 234ms/step
# Epoch 105/1000
# 1/1 - 0s - loss: 0.0563 - mean_absolute_error: 0.0563 - val_loss: 0.0606 - val_mean_absolute_error: 0.0606 - 232ms/epoch - 232ms/step
# Epoch 106/1000
# 1/1 - 0s - loss: 0.0547 - mean_absolute_error: 0.0547 - val_loss: 0.0568 - val_mean_absolute_error: 0.0568 - 230ms/epoch - 230ms/step
# Epoch 107/1000
# 1/1 - 0s - loss: 0.0559 - mean_absolute_error: 0.0559 - val_loss: 0.0633 - val_mean_absolute_error: 0.0633 - 245ms/epoch - 245ms/step
# Epoch 108/1000
# 1/1 - 0s - loss: 0.0589 - mean_absolute_error: 0.0589 - val_loss: 0.0533 - val_mean_absolute_error: 0.0533 - 239ms/epoch - 239ms/step
# Epoch 109/1000
# 1/1 - 0s - loss: 0.0515 - mean_absolute_error: 0.0515 - val_loss: 0.0565 - val_mean_absolute_error: 0.0565 - 233ms/epoch - 233ms/step
# Epoch 110/1000
# 1/1 - 0s - loss: 0.0568 - mean_absolute_error: 0.0568 - val_loss: 0.0963 - val_mean_absolute_error: 0.0963 - 248ms/epoch - 248ms/step
# Epoch 111/1000
# 1/1 - 0s - loss: 0.0712 - mean_absolute_error: 0.0712 - val_loss: 0.0686 - val_mean_absolute_error: 0.0686 - 402ms/epoch - 402ms/step
# Epoch 112/1000
# 1/1 - 0s - loss: 0.0708 - mean_absolute_error: 0.0708 - val_loss: 0.0670 - val_mean_absolute_error: 0.0670 - 234ms/epoch - 234ms/step
# Epoch 113/1000
# 1/1 - 0s - loss: 0.0668 - mean_absolute_error: 0.0668 - val_loss: 0.0794 - val_mean_absolute_error: 0.0794 - 230ms/epoch - 230ms/step
# Epoch 114/1000
# 1/1 - 0s - loss: 0.0761 - mean_absolute_error: 0.0761 - val_loss: 0.0570 - val_mean_absolute_error: 0.0570 - 233ms/epoch - 233ms/step
# Epoch 115/1000
# 1/1 - 0s - loss: 0.0587 - mean_absolute_error: 0.0587 - val_loss: 0.0683 - val_mean_absolute_error: 0.0683 - 248ms/epoch - 248ms/step
# Epoch 116/1000
# 1/1 - 0s - loss: 0.0708 - mean_absolute_error: 0.0708 - val_loss: 0.0606 - val_mean_absolute_error: 0.0606 - 230ms/epoch - 230ms/step
# Epoch 117/1000
# 1/1 - 0s - loss: 0.0598 - mean_absolute_error: 0.0598 - val_loss: 0.0751 - val_mean_absolute_error: 0.0751 - 233ms/epoch - 233ms/step
# Epoch 118/1000
# 1/1 - 0s - loss: 0.0648 - mean_absolute_error: 0.0648 - val_loss: 0.0545 - val_mean_absolute_error: 0.0545 - 239ms/epoch - 239ms/step
# Epoch 119/1000
# 1/1 - 0s - loss: 0.0575 - mean_absolute_error: 0.0575 - val_loss: 0.0551 - val_mean_absolute_error: 0.0551 - 244ms/epoch - 244ms/step
# Epoch 120/1000
# 1/1 - 0s - loss: 0.0568 - mean_absolute_error: 0.0568 - val_loss: 0.0627 - val_mean_absolute_error: 0.0627 - 237ms/epoch - 237ms/step
# Epoch 121/1000
# 1/1 - 0s - loss: 0.0565 - mean_absolute_error: 0.0565 - val_loss: 0.0534 - val_mean_absolute_error: 0.0534 - 244ms/epoch - 244ms/step
# Epoch 122/1000
# 1/1 - 0s - loss: 0.0542 - mean_absolute_error: 0.0542 - val_loss: 0.0533 - val_mean_absolute_error: 0.0533 - 233ms/epoch - 233ms/step
# Epoch 123/1000
# 1/1 - 0s - loss: 0.0577 - mean_absolute_error: 0.0577 - val_loss: 0.0572 - val_mean_absolute_error: 0.0572 - 268ms/epoch - 268ms/step
# Epoch 124/1000
# 1/1 - 0s - loss: 0.0556 - mean_absolute_error: 0.0556 - val_loss: 0.0612 - val_mean_absolute_error: 0.0612 - 241ms/epoch - 241ms/step
# Epoch 125/1000
# 1/1 - 0s - loss: 0.0558 - mean_absolute_error: 0.0558 - val_loss: 0.0532 - val_mean_absolute_error: 0.0532 - 240ms/epoch - 240ms/step
# Epoch 126/1000
# 1/1 - 0s - loss: 0.0550 - mean_absolute_error: 0.0550 - val_loss: 0.0530 - val_mean_absolute_error: 0.0530 - 240ms/epoch - 240ms/step
# Epoch 127/1000
# 1/1 - 0s - loss: 0.0557 - mean_absolute_error: 0.0557 - val_loss: 0.0647 - val_mean_absolute_error: 0.0647 - 245ms/epoch - 245ms/step
# Epoch 128/1000
# 1/1 - 0s - loss: 0.0599 - mean_absolute_error: 0.0599 - val_loss: 0.0544 - val_mean_absolute_error: 0.0544 - 246ms/epoch - 246ms/step
# Epoch 129/1000
# 1/1 - 0s - loss: 0.0551 - mean_absolute_error: 0.0551 - val_loss: 0.0543 - val_mean_absolute_error: 0.0543 - 246ms/epoch - 246ms/step
# Epoch 130/1000
# 1/1 - 0s - loss: 0.0571 - mean_absolute_error: 0.0571 - val_loss: 0.0634 - val_mean_absolute_error: 0.0634 - 238ms/epoch - 238ms/step
# Epoch 131/1000
# 1/1 - 0s - loss: 0.0570 - mean_absolute_error: 0.0570 - val_loss: 0.0590 - val_mean_absolute_error: 0.0590 - 406ms/epoch - 406ms/step
# Epoch 132/1000
# 1/1 - 0s - loss: 0.0548 - mean_absolute_error: 0.0548 - val_loss: 0.0538 - val_mean_absolute_error: 0.0538 - 227ms/epoch - 227ms/step
# Epoch 133/1000
# 1/1 - 0s - loss: 0.0561 - mean_absolute_error: 0.0561 - val_loss: 0.0541 - val_mean_absolute_error: 0.0541 - 237ms/epoch - 237ms/step
# Epoch 134/1000
# 1/1 - 0s - loss: 0.0530 - mean_absolute_error: 0.0530 - val_loss: 0.0687 - val_mean_absolute_error: 0.0687 - 239ms/epoch - 239ms/step
# Epoch 135/1000
# 1/1 - 0s - loss: 0.0591 - mean_absolute_error: 0.0591 - val_loss: 0.0548 - val_mean_absolute_error: 0.0548 - 253ms/epoch - 253ms/step
# Epoch 136/1000
# 1/1 - 0s - loss: 0.0539 - mean_absolute_error: 0.0539 - val_loss: 0.0560 - val_mean_absolute_error: 0.0560 - 247ms/epoch - 247ms/step
# Epoch 137/1000
# 1/1 - 0s - loss: 0.0576 - mean_absolute_error: 0.0576 - val_loss: 0.0651 - val_mean_absolute_error: 0.0651 - 243ms/epoch - 243ms/step
# Epoch 138/1000
# 1/1 - 0s - loss: 0.0597 - mean_absolute_error: 0.0597 - val_loss: 0.0584 - val_mean_absolute_error: 0.0584 - 251ms/epoch - 251ms/step
# Epoch 139/1000
# 1/1 - 0s - loss: 0.0545 - mean_absolute_error: 0.0545 - val_loss: 0.0570 - val_mean_absolute_error: 0.0570 - 413ms/epoch - 413ms/step
# Epoch 140/1000
# 1/1 - 0s - loss: 0.0587 - mean_absolute_error: 0.0587 - val_loss: 0.0536 - val_mean_absolute_error: 0.0536 - 237ms/epoch - 237ms/step
# Epoch 141/1000
# 1/1 - 0s - loss: 0.0520 - mean_absolute_error: 0.0520 - val_loss: 0.0620 - val_mean_absolute_error: 0.0620 - 245ms/epoch - 245ms/step
# Epoch 142/1000
# 1/1 - 0s - loss: 0.0565 - mean_absolute_error: 0.0565 - val_loss: 0.0530 - val_mean_absolute_error: 0.0530 - 250ms/epoch - 250ms/step
# Epoch 143/1000
# 1/1 - 0s - loss: 0.0521 - mean_absolute_error: 0.0521 - val_loss: 0.0528 - val_mean_absolute_error: 0.0528 - 241ms/epoch - 241ms/step
# Epoch 144/1000
# 1/1 - 0s - loss: 0.0509 - mean_absolute_error: 0.0509 - val_loss: 0.0597 - val_mean_absolute_error: 0.0597 - 252ms/epoch - 252ms/step
# Epoch 145/1000
# 1/1 - 0s - loss: 0.0550 - mean_absolute_error: 0.0550 - val_loss: 0.0528 - val_mean_absolute_error: 0.0528 - 235ms/epoch - 235ms/step
# Epoch 146/1000
# 1/1 - 0s - loss: 0.0536 - mean_absolute_error: 0.0536 - val_loss: 0.0569 - val_mean_absolute_error: 0.0569 - 245ms/epoch - 245ms/step
# Epoch 147/1000
# 1/1 - 0s - loss: 0.0544 - mean_absolute_error: 0.0544 - val_loss: 0.0583 - val_mean_absolute_error: 0.0583 - 232ms/epoch - 232ms/step
# Epoch 148/1000
# 1/1 - 0s - loss: 0.0518 - mean_absolute_error: 0.0518 - val_loss: 0.0581 - val_mean_absolute_error: 0.0581 - 231ms/epoch - 231ms/step
# Epoch 149/1000
# 1/1 - 0s - loss: 0.0533 - mean_absolute_error: 0.0533 - val_loss: 0.0646 - val_mean_absolute_error: 0.0646 - 238ms/epoch - 238ms/step
# Epoch 150/1000
# 1/1 - 0s - loss: 0.0602 - mean_absolute_error: 0.0602 - val_loss: 0.0550 - val_mean_absolute_error: 0.0550 - 242ms/epoch - 242ms/step
# Epoch 151/1000
# 1/1 - 0s - loss: 0.0502 - mean_absolute_error: 0.0502 - val_loss: 0.0613 - val_mean_absolute_error: 0.0613 - 234ms/epoch - 234ms/step
# Epoch 152/1000
# 1/1 - 0s - loss: 0.0500 - mean_absolute_error: 0.0500 - val_loss: 0.0528 - val_mean_absolute_error: 0.0528 - 232ms/epoch - 232ms/step
# Epoch 153/1000
# 1/1 - 0s - loss: 0.0509 - mean_absolute_error: 0.0509 - val_loss: 0.0526 - val_mean_absolute_error: 0.0526 - 237ms/epoch - 237ms/step
# Epoch 154/1000
# 1/1 - 0s - loss: 0.0490 - mean_absolute_error: 0.0490 - val_loss: 0.0624 - val_mean_absolute_error: 0.0624 - 242ms/epoch - 242ms/step
# Epoch 155/1000
# 1/1 - 0s - loss: 0.0517 - mean_absolute_error: 0.0517 - val_loss: 0.0528 - val_mean_absolute_error: 0.0528 - 240ms/epoch - 240ms/step
# Epoch 156/1000
# 1/1 - 0s - loss: 0.0502 - mean_absolute_error: 0.0502 - val_loss: 0.0525 - val_mean_absolute_error: 0.0525 - 233ms/epoch - 233ms/step
# Epoch 157/1000
# 1/1 - 0s - loss: 0.0468 - mean_absolute_error: 0.0468 - val_loss: 0.0571 - val_mean_absolute_error: 0.0571 - 227ms/epoch - 227ms/step
# Epoch 158/1000
# 1/1 - 0s - loss: 0.0475 - mean_absolute_error: 0.0475 - val_loss: 0.0529 - val_mean_absolute_error: 0.0529 - 237ms/epoch - 237ms/step
# Epoch 159/1000
# 1/1 - 0s - loss: 0.0464 - mean_absolute_error: 0.0464 - val_loss: 0.0627 - val_mean_absolute_error: 0.0627 - 246ms/epoch - 246ms/step
# Epoch 160/1000
# 1/1 - 0s - loss: 0.0506 - mean_absolute_error: 0.0506 - val_loss: 0.0603 - val_mean_absolute_error: 0.0603 - 230ms/epoch - 230ms/step
# Epoch 161/1000
# 1/1 - 0s - loss: 0.0535 - mean_absolute_error: 0.0535 - val_loss: 0.0615 - val_mean_absolute_error: 0.0615 - 240ms/epoch - 240ms/step
# Epoch 162/1000
# 1/1 - 0s - loss: 0.0538 - mean_absolute_error: 0.0538 - val_loss: 0.0732 - val_mean_absolute_error: 0.0732 - 244ms/epoch - 244ms/step
# Epoch 163/1000
# 1/1 - 0s - loss: 0.0670 - mean_absolute_error: 0.0670 - val_loss: 0.0821 - val_mean_absolute_error: 0.0821 - 241ms/epoch - 241ms/step
# Epoch 164/1000
# 1/1 - 0s - loss: 0.0644 - mean_absolute_error: 0.0644 - val_loss: 0.0792 - val_mean_absolute_error: 0.0792 - 234ms/epoch - 234ms/step
# Epoch 165/1000
# 1/1 - 0s - loss: 0.0754 - mean_absolute_error: 0.0754 - val_loss: 0.0691 - val_mean_absolute_error: 0.0691 - 231ms/epoch - 231ms/step
# Epoch 166/1000
# 1/1 - 0s - loss: 0.0631 - mean_absolute_error: 0.0631 - val_loss: 0.0672 - val_mean_absolute_error: 0.0672 - 240ms/epoch - 240ms/step
# Epoch 167/1000
# 1/1 - 0s - loss: 0.0613 - mean_absolute_error: 0.0613 - val_loss: 0.0717 - val_mean_absolute_error: 0.0717 - 241ms/epoch - 241ms/step
# Epoch 168/1000
# 1/1 - 0s - loss: 0.0687 - mean_absolute_error: 0.0687 - val_loss: 0.0792 - val_mean_absolute_error: 0.0792 - 236ms/epoch - 236ms/step
# Epoch 169/1000
# 1/1 - 0s - loss: 0.0721 - mean_absolute_error: 0.0721 - val_loss: 0.0547 - val_mean_absolute_error: 0.0547 - 233ms/epoch - 233ms/step
# Epoch 170/1000
# 1/1 - 0s - loss: 0.0547 - mean_absolute_error: 0.0547 - val_loss: 0.0547 - val_mean_absolute_error: 0.0547 - 234ms/epoch - 234ms/step
# Epoch 171/1000
# 1/1 - 0s - loss: 0.0545 - mean_absolute_error: 0.0545 - val_loss: 0.0684 - val_mean_absolute_error: 0.0684 - 247ms/epoch - 247ms/step
# Epoch 172/1000
# 1/1 - 0s - loss: 0.0637 - mean_absolute_error: 0.0637 - val_loss: 0.0561 - val_mean_absolute_error: 0.0561 - 232ms/epoch - 232ms/step
# Epoch 173/1000
# 1/1 - 0s - loss: 0.0579 - mean_absolute_error: 0.0579 - val_loss: 0.0533 - val_mean_absolute_error: 0.0533 - 241ms/epoch - 241ms/step
# Epoch 174/1000
# 1/1 - 0s - loss: 0.0550 - mean_absolute_error: 0.0550 - val_loss: 0.0571 - val_mean_absolute_error: 0.0571 - 242ms/epoch - 242ms/step
# Epoch 175/1000
# 1/1 - 0s - loss: 0.0567 - mean_absolute_error: 0.0567 - val_loss: 0.0530 - val_mean_absolute_error: 0.0530 - 247ms/epoch - 247ms/step
# Epoch 176/1000
# 1/1 - 0s - loss: 0.0510 - mean_absolute_error: 0.0510 - val_loss: 0.0563 - val_mean_absolute_error: 0.0563 - 241ms/epoch - 241ms/step
# Epoch 177/1000
# 1/1 - 0s - loss: 0.0549 - mean_absolute_error: 0.0549 - val_loss: 0.0634 - val_mean_absolute_error: 0.0634 - 240ms/epoch - 240ms/step
# Epoch 178/1000
# 1/1 - 0s - loss: 0.0518 - mean_absolute_error: 0.0518 - val_loss: 0.0564 - val_mean_absolute_error: 0.0564 - 241ms/epoch - 241ms/step
# Epoch 179/1000
# 1/1 - 0s - loss: 0.0510 - mean_absolute_error: 0.0510 - val_loss: 0.0539 - val_mean_absolute_error: 0.0539 - 233ms/epoch - 233ms/step
# Epoch 180/1000
# 1/1 - 0s - loss: 0.0550 - mean_absolute_error: 0.0550 - val_loss: 0.0536 - val_mean_absolute_error: 0.0536 - 243ms/epoch - 243ms/step
# Epoch 181/1000
# 1/1 - 0s - loss: 0.0557 - mean_absolute_error: 0.0557 - val_loss: 0.0556 - val_mean_absolute_error: 0.0556 - 231ms/epoch - 231ms/step
# Epoch 182/1000
# 1/1 - 0s - loss: 0.0511 - mean_absolute_error: 0.0511 - val_loss: 0.0562 - val_mean_absolute_error: 0.0562 - 242ms/epoch - 242ms/step
# Epoch 183/1000
# 1/1 - 0s - loss: 0.0523 - mean_absolute_error: 0.0523 - val_loss: 0.0559 - val_mean_absolute_error: 0.0559 - 240ms/epoch - 240ms/step
# Epoch 184/1000
# 1/1 - 0s - loss: 0.0533 - mean_absolute_error: 0.0533 - val_loss: 0.0541 - val_mean_absolute_error: 0.0541 - 246ms/epoch - 246ms/step
# Epoch 185/1000
# 1/1 - 0s - loss: 0.0503 - mean_absolute_error: 0.0503 - val_loss: 0.0530 - val_mean_absolute_error: 0.0530 - 230ms/epoch - 230ms/step
# Epoch 186/1000
# 1/1 - 0s - loss: 0.0537 - mean_absolute_error: 0.0537 - val_loss: 0.0535 - val_mean_absolute_error: 0.0535 - 227ms/epoch - 227ms/step
# Epoch 187/1000
# 1/1 - 0s - loss: 0.0524 - mean_absolute_error: 0.0524 - val_loss: 0.0541 - val_mean_absolute_error: 0.0541 - 262ms/epoch - 262ms/step
# Epoch 188/1000
# 1/1 - 0s - loss: 0.0486 - mean_absolute_error: 0.0486 - val_loss: 0.0568 - val_mean_absolute_error: 0.0568 - 259ms/epoch - 259ms/step
# Epoch 189/1000
# 1/1 - 0s - loss: 0.0509 - mean_absolute_error: 0.0509 - val_loss: 0.0566 - val_mean_absolute_error: 0.0566 - 250ms/epoch - 250ms/step
# Epoch 190/1000
# 1/1 - 0s - loss: 0.0547 - mean_absolute_error: 0.0547 - val_loss: 0.0634 - val_mean_absolute_error: 0.0634 - 235ms/epoch - 235ms/step
# Epoch 191/1000
# 1/1 - 0s - loss: 0.0537 - mean_absolute_error: 0.0537 - val_loss: 0.0530 - val_mean_absolute_error: 0.0530 - 238ms/epoch - 238ms/step
# Epoch 192/1000
# 1/1 - 0s - loss: 0.0499 - mean_absolute_error: 0.0499 - val_loss: 0.0553 - val_mean_absolute_error: 0.0553 - 243ms/epoch - 243ms/step
# Epoch 193/1000
# 1/1 - 0s - loss: 0.0540 - mean_absolute_error: 0.0540 - val_loss: 0.0588 - val_mean_absolute_error: 0.0588 - 244ms/epoch - 244ms/step
# Epoch 194/1000
# 1/1 - 0s - loss: 0.0515 - mean_absolute_error: 0.0515 - val_loss: 0.0579 - val_mean_absolute_error: 0.0579 - 232ms/epoch - 232ms/step
# Epoch 195/1000
# 1/1 - 0s - loss: 0.0477 - mean_absolute_error: 0.0477 - val_loss: 0.0673 - val_mean_absolute_error: 0.0673 - 244ms/epoch - 244ms/step
# Epoch 196/1000
# 1/1 - 0s - loss: 0.0603 - mean_absolute_error: 0.0603 - val_loss: 0.0721 - val_mean_absolute_error: 0.0721 - 245ms/epoch - 245ms/step
# Epoch 197/1000
# 1/1 - 0s - loss: 0.0563 - mean_absolute_error: 0.0563 - val_loss: 0.0526 - val_mean_absolute_error: 0.0526 - 238ms/epoch - 238ms/step
# Epoch 198/1000
# 1/1 - 0s - loss: 0.0494 - mean_absolute_error: 0.0494 - val_loss: 0.0552 - val_mean_absolute_error: 0.0552 - 233ms/epoch - 233ms/step
# Epoch 199/1000
# 1/1 - 0s - loss: 0.0584 - mean_absolute_error: 0.0584 - val_loss: 0.0540 - val_mean_absolute_error: 0.0540 - 248ms/epoch - 248ms/step
# Epoch 200/1000
# 1/1 - 0s - loss: 0.0507 - mean_absolute_error: 0.0507 - val_loss: 0.0573 - val_mean_absolute_error: 0.0573 - 253ms/epoch - 253ms/step
# Epoch 201/1000
# 1/1 - 0s - loss: 0.0491 - mean_absolute_error: 0.0491 - val_loss: 0.0579 - val_mean_absolute_error: 0.0579 - 238ms/epoch - 238ms/step
# Epoch 202/1000
# 1/1 - 0s - loss: 0.0539 - mean_absolute_error: 0.0539 - val_loss: 0.0568 - val_mean_absolute_error: 0.0568 - 238ms/epoch - 238ms/step
# Epoch 203/1000
# 1/1 - 0s - loss: 0.0504 - mean_absolute_error: 0.0504 - val_loss: 0.0559 - val_mean_absolute_error: 0.0559 - 386ms/epoch - 386ms/step
# Epoch 204/1000
# 1/1 - 0s - loss: 0.0490 - mean_absolute_error: 0.0490 - val_loss: 0.0523 - val_mean_absolute_error: 0.0523 - 374ms/epoch - 374ms/step
# Epoch 205/1000
# 1/1 - 0s - loss: 0.0471 - mean_absolute_error: 0.0471 - val_loss: 0.0525 - val_mean_absolute_error: 0.0525 - 371ms/epoch - 371ms/step
# Epoch 206/1000
# 1/1 - 0s - loss: 0.0502 - mean_absolute_error: 0.0502 - val_loss: 0.0530 - val_mean_absolute_error: 0.0530 - 371ms/epoch - 371ms/step
# Epoch 207/1000
# 1/1 - 0s - loss: 0.0502 - mean_absolute_error: 0.0502 - val_loss: 0.0560 - val_mean_absolute_error: 0.0560 - 361ms/epoch - 361ms/step
# Epoch 208/1000
# 1/1 - 0s - loss: 0.0483 - mean_absolute_error: 0.0483 - val_loss: 0.0625 - val_mean_absolute_error: 0.0625 - 361ms/epoch - 361ms/step
# Epoch 209/1000
# 1/1 - 0s - loss: 0.0497 - mean_absolute_error: 0.0497 - val_loss: 0.0561 - val_mean_absolute_error: 0.0561 - 379ms/epoch - 379ms/step
# Epoch 210/1000
# 1/1 - 0s - loss: 0.0475 - mean_absolute_error: 0.0475 - val_loss: 0.0543 - val_mean_absolute_error: 0.0543 - 369ms/epoch - 369ms/step
# Epoch 211/1000
# 1/1 - 0s - loss: 0.0519 - mean_absolute_error: 0.0519 - val_loss: 0.0537 - val_mean_absolute_error: 0.0537 - 342ms/epoch - 342ms/step
# Epoch 212/1000
# 1/1 - 0s - loss: 0.0468 - mean_absolute_error: 0.0468 - val_loss: 0.0550 - val_mean_absolute_error: 0.0550 - 243ms/epoch - 243ms/step
# Epoch 213/1000
# 1/1 - 0s - loss: 0.0478 - mean_absolute_error: 0.0478 - val_loss: 0.0542 - val_mean_absolute_error: 0.0542 - 235ms/epoch - 235ms/step
# Epoch 214/1000
# 1/1 - 0s - loss: 0.0481 - mean_absolute_error: 0.0481 - val_loss: 0.0534 - val_mean_absolute_error: 0.0534 - 235ms/epoch - 235ms/step
# Epoch 215/1000
# 1/1 - 0s - loss: 0.0456 - mean_absolute_error: 0.0456 - val_loss: 0.0527 - val_mean_absolute_error: 0.0527 - 253ms/epoch - 253ms/step
# Epoch 216/1000
# 1/1 - 0s - loss: 0.0464 - mean_absolute_error: 0.0464 - val_loss: 0.0520 - val_mean_absolute_error: 0.0520 - 253ms/epoch - 253ms/step
# Epoch 217/1000
# 1/1 - 0s - loss: 0.0459 - mean_absolute_error: 0.0459 - val_loss: 0.0518 - val_mean_absolute_error: 0.0518 - 236ms/epoch - 236ms/step
# Epoch 218/1000
# 1/1 - 0s - loss: 0.0461 - mean_absolute_error: 0.0461 - val_loss: 0.0526 - val_mean_absolute_error: 0.0526 - 243ms/epoch - 243ms/step
# Epoch 219/1000
# 1/1 - 0s - loss: 0.0479 - mean_absolute_error: 0.0479 - val_loss: 0.0514 - val_mean_absolute_error: 0.0514 - 244ms/epoch - 244ms/step
# Epoch 220/1000
# 1/1 - 0s - loss: 0.0448 - mean_absolute_error: 0.0448 - val_loss: 0.0515 - val_mean_absolute_error: 0.0515 - 241ms/epoch - 241ms/step
# Epoch 221/1000
# 1/1 - 0s - loss: 0.0438 - mean_absolute_error: 0.0438 - val_loss: 0.0523 - val_mean_absolute_error: 0.0523 - 247ms/epoch - 247ms/step
# Epoch 222/1000
# 1/1 - 0s - loss: 0.0478 - mean_absolute_error: 0.0478 - val_loss: 0.0564 - val_mean_absolute_error: 0.0564 - 243ms/epoch - 243ms/step
# Epoch 223/1000
# 1/1 - 0s - loss: 0.0457 - mean_absolute_error: 0.0457 - val_loss: 0.0565 - val_mean_absolute_error: 0.0565 - 249ms/epoch - 249ms/step
# Epoch 224/1000
# 1/1 - 0s - loss: 0.0472 - mean_absolute_error: 0.0472 - val_loss: 0.0546 - val_mean_absolute_error: 0.0546 - 244ms/epoch - 244ms/step
# Epoch 225/1000
# 1/1 - 0s - loss: 0.0453 - mean_absolute_error: 0.0453 - val_loss: 0.0507 - val_mean_absolute_error: 0.0507 - 241ms/epoch - 241ms/step
# Epoch 226/1000
# 1/1 - 0s - loss: 0.0495 - mean_absolute_error: 0.0495 - val_loss: 0.0531 - val_mean_absolute_error: 0.0531 - 230ms/epoch - 230ms/step
# Epoch 227/1000
# 1/1 - 0s - loss: 0.0478 - mean_absolute_error: 0.0478 - val_loss: 0.0514 - val_mean_absolute_error: 0.0514 - 238ms/epoch - 238ms/step
# Epoch 228/1000
# 1/1 - 0s - loss: 0.0470 - mean_absolute_error: 0.0470 - val_loss: 0.0608 - val_mean_absolute_error: 0.0608 - 230ms/epoch - 230ms/step
# Epoch 229/1000
# 1/1 - 0s - loss: 0.0516 - mean_absolute_error: 0.0516 - val_loss: 0.0666 - val_mean_absolute_error: 0.0666 - 240ms/epoch - 240ms/step
# Epoch 230/1000
# 1/1 - 0s - loss: 0.0591 - mean_absolute_error: 0.0591 - val_loss: 0.0714 - val_mean_absolute_error: 0.0714 - 239ms/epoch - 239ms/step
# Epoch 231/1000
# 1/1 - 0s - loss: 0.0590 - mean_absolute_error: 0.0590 - val_loss: 0.0703 - val_mean_absolute_error: 0.0703 - 237ms/epoch - 237ms/step
# Epoch 232/1000
# 1/1 - 0s - loss: 0.0613 - mean_absolute_error: 0.0613 - val_loss: 0.0632 - val_mean_absolute_error: 0.0632 - 239ms/epoch - 239ms/step
# Epoch 233/1000
# 1/1 - 0s - loss: 0.0575 - mean_absolute_error: 0.0575 - val_loss: 0.0537 - val_mean_absolute_error: 0.0537 - 239ms/epoch - 239ms/step
# Epoch 234/1000
# 1/1 - 0s - loss: 0.0471 - mean_absolute_error: 0.0471 - val_loss: 0.0571 - val_mean_absolute_error: 0.0571 - 238ms/epoch - 238ms/step
# Epoch 235/1000
# 1/1 - 0s - loss: 0.0544 - mean_absolute_error: 0.0544 - val_loss: 0.0673 - val_mean_absolute_error: 0.0673 - 247ms/epoch - 247ms/step
# Epoch 236/1000
# 1/1 - 0s - loss: 0.0546 - mean_absolute_error: 0.0546 - val_loss: 0.0631 - val_mean_absolute_error: 0.0631 - 239ms/epoch - 239ms/step
# Epoch 237/1000
# 1/1 - 0s - loss: 0.0609 - mean_absolute_error: 0.0609 - val_loss: 0.0762 - val_mean_absolute_error: 0.0762 - 248ms/epoch - 248ms/step
# Epoch 238/1000
# 1/1 - 0s - loss: 0.0638 - mean_absolute_error: 0.0638 - val_loss: 0.0532 - val_mean_absolute_error: 0.0532 - 236ms/epoch - 236ms/step
# Epoch 239/1000
# 1/1 - 0s - loss: 0.0501 - mean_absolute_error: 0.0501 - val_loss: 0.0538 - val_mean_absolute_error: 0.0538 - 235ms/epoch - 235ms/step
# Epoch 240/1000
# 1/1 - 0s - loss: 0.0533 - mean_absolute_error: 0.0533 - val_loss: 0.0595 - val_mean_absolute_error: 0.0595 - 244ms/epoch - 244ms/step
# Epoch 241/1000
# 1/1 - 0s - loss: 0.0518 - mean_absolute_error: 0.0518 - val_loss: 0.0613 - val_mean_absolute_error: 0.0613 - 241ms/epoch - 241ms/step
# Epoch 242/1000
# 1/1 - 0s - loss: 0.0491 - mean_absolute_error: 0.0491 - val_loss: 0.0559 - val_mean_absolute_error: 0.0559 - 233ms/epoch - 233ms/step
# Epoch 243/1000
# 1/1 - 0s - loss: 0.0501 - mean_absolute_error: 0.0501 - val_loss: 0.0545 - val_mean_absolute_error: 0.0545 - 242ms/epoch - 242ms/step
# Epoch 244/1000
# 1/1 - 0s - loss: 0.0494 - mean_absolute_error: 0.0494 - val_loss: 0.0548 - val_mean_absolute_error: 0.0548 - 238ms/epoch - 238ms/step
# Epoch 245/1000
# 1/1 - 0s - loss: 0.0498 - mean_absolute_error: 0.0498 - val_loss: 0.0512 - val_mean_absolute_error: 0.0512 - 242ms/epoch - 242ms/step
# Epoch 246/1000
# 1/1 - 0s - loss: 0.0477 - mean_absolute_error: 0.0477 - val_loss: 0.0508 - val_mean_absolute_error: 0.0508 - 231ms/epoch - 231ms/step
# Epoch 247/1000
# 1/1 - 0s - loss: 0.0499 - mean_absolute_error: 0.0499 - val_loss: 0.0503 - val_mean_absolute_error: 0.0503 - 245ms/epoch - 245ms/step
# Epoch 248/1000
# 1/1 - 0s - loss: 0.0484 - mean_absolute_error: 0.0484 - val_loss: 0.0506 - val_mean_absolute_error: 0.0506 - 235ms/epoch - 235ms/step
# Epoch 249/1000
# 1/1 - 0s - loss: 0.0439 - mean_absolute_error: 0.0439 - val_loss: 0.0554 - val_mean_absolute_error: 0.0554 - 245ms/epoch - 245ms/step
# Epoch 250/1000
# 1/1 - 0s - loss: 0.0457 - mean_absolute_error: 0.0457 - val_loss: 0.0556 - val_mean_absolute_error: 0.0556 - 234ms/epoch - 234ms/step
# Epoch 251/1000
# 1/1 - 0s - loss: 0.0477 - mean_absolute_error: 0.0477 - val_loss: 0.0540 - val_mean_absolute_error: 0.0540 - 239ms/epoch - 239ms/step
# Epoch 252/1000
# 1/1 - 0s - loss: 0.0439 - mean_absolute_error: 0.0439 - val_loss: 0.0644 - val_mean_absolute_error: 0.0644 - 234ms/epoch - 234ms/step
# Epoch 253/1000
# 1/1 - 0s - loss: 0.0473 - mean_absolute_error: 0.0473 - val_loss: 0.0542 - val_mean_absolute_error: 0.0542 - 244ms/epoch - 244ms/step
# Epoch 254/1000
# 1/1 - 0s - loss: 0.0459 - mean_absolute_error: 0.0459 - val_loss: 0.0537 - val_mean_absolute_error: 0.0537 - 248ms/epoch - 248ms/step
# Epoch 255/1000
# 1/1 - 0s - loss: 0.0491 - mean_absolute_error: 0.0491 - val_loss: 0.0530 - val_mean_absolute_error: 0.0530 - 243ms/epoch - 243ms/step
# Epoch 256/1000
# 1/1 - 0s - loss: 0.0422 - mean_absolute_error: 0.0422 - val_loss: 0.0601 - val_mean_absolute_error: 0.0601 - 244ms/epoch - 244ms/step
# Epoch 257/1000
# 1/1 - 0s - loss: 0.0451 - mean_absolute_error: 0.0451 - val_loss: 0.0539 - val_mean_absolute_error: 0.0539 - 230ms/epoch - 230ms/step
# Epoch 258/1000
# 1/1 - 0s - loss: 0.0473 - mean_absolute_error: 0.0473 - val_loss: 0.0583 - val_mean_absolute_error: 0.0583 - 244ms/epoch - 244ms/step
# Epoch 259/1000
# 1/1 - 0s - loss: 0.0460 - mean_absolute_error: 0.0460 - val_loss: 0.0535 - val_mean_absolute_error: 0.0535 - 234ms/epoch - 234ms/step
# Epoch 260/1000
# 1/1 - 0s - loss: 0.0461 - mean_absolute_error: 0.0461 - val_loss: 0.0555 - val_mean_absolute_error: 0.0555 - 246ms/epoch - 246ms/step
# Epoch 261/1000
# 1/1 - 0s - loss: 0.0446 - mean_absolute_error: 0.0446 - val_loss: 0.0492 - val_mean_absolute_error: 0.0492 - 229ms/epoch - 229ms/step
# Epoch 262/1000
# 1/1 - 0s - loss: 0.0422 - mean_absolute_error: 0.0422 - val_loss: 0.0495 - val_mean_absolute_error: 0.0495 - 398ms/epoch - 398ms/step
# Epoch 263/1000
# 1/1 - 0s - loss: 0.0413 - mean_absolute_error: 0.0413 - val_loss: 0.0602 - val_mean_absolute_error: 0.0602 - 243ms/epoch - 243ms/step
# Epoch 264/1000
# 1/1 - 0s - loss: 0.0458 - mean_absolute_error: 0.0458 - val_loss: 0.0540 - val_mean_absolute_error: 0.0540 - 243ms/epoch - 243ms/step
# Epoch 265/1000
# 1/1 - 0s - loss: 0.0454 - mean_absolute_error: 0.0454 - val_loss: 0.0613 - val_mean_absolute_error: 0.0613 - 242ms/epoch - 242ms/step
# Epoch 266/1000
# 1/1 - 0s - loss: 0.0470 - mean_absolute_error: 0.0470 - val_loss: 0.0546 - val_mean_absolute_error: 0.0546 - 238ms/epoch - 238ms/step
# Epoch 267/1000
# 1/1 - 0s - loss: 0.0438 - mean_absolute_error: 0.0438 - val_loss: 0.0580 - val_mean_absolute_error: 0.0580 - 241ms/epoch - 241ms/step
# Epoch 268/1000
# 1/1 - 0s - loss: 0.0474 - mean_absolute_error: 0.0474 - val_loss: 0.0774 - val_mean_absolute_error: 0.0774 - 236ms/epoch - 236ms/step
# Epoch 269/1000
# 1/1 - 0s - loss: 0.0566 - mean_absolute_error: 0.0566 - val_loss: 0.0538 - val_mean_absolute_error: 0.0538 - 234ms/epoch - 234ms/step
# Epoch 270/1000
# 1/1 - 0s - loss: 0.0446 - mean_absolute_error: 0.0446 - val_loss: 0.0517 - val_mean_absolute_error: 0.0517 - 245ms/epoch - 245ms/step
# Epoch 271/1000
# 1/1 - 0s - loss: 0.0415 - mean_absolute_error: 0.0415 - val_loss: 0.0715 - val_mean_absolute_error: 0.0715 - 240ms/epoch - 240ms/step
# Epoch 272/1000
# 1/1 - 0s - loss: 0.0529 - mean_absolute_error: 0.0529 - val_loss: 0.0564 - val_mean_absolute_error: 0.0564 - 233ms/epoch - 233ms/step
# Epoch 273/1000
# 1/1 - 0s - loss: 0.0517 - mean_absolute_error: 0.0517 - val_loss: 0.0502 - val_mean_absolute_error: 0.0502 - 234ms/epoch - 234ms/step
# Epoch 274/1000
# 1/1 - 0s - loss: 0.0439 - mean_absolute_error: 0.0439 - val_loss: 0.0590 - val_mean_absolute_error: 0.0590 - 242ms/epoch - 242ms/step
# Epoch 275/1000
# 1/1 - 0s - loss: 0.0449 - mean_absolute_error: 0.0449 - val_loss: 0.0495 - val_mean_absolute_error: 0.0495 - 243ms/epoch - 243ms/step
# Epoch 276/1000
# 1/1 - 0s - loss: 0.0405 - mean_absolute_error: 0.0405 - val_loss: 0.0514 - val_mean_absolute_error: 0.0514 - 231ms/epoch - 231ms/step
# Epoch 277/1000
# 1/1 - 0s - loss: 0.0452 - mean_absolute_error: 0.0452 - val_loss: 0.0655 - val_mean_absolute_error: 0.0655 - 228ms/epoch - 228ms/step
# Epoch 278/1000
# 1/1 - 0s - loss: 0.0536 - mean_absolute_error: 0.0536 - val_loss: 0.0510 - val_mean_absolute_error: 0.0510 - 237ms/epoch - 237ms/step
# Epoch 279/1000
# 1/1 - 0s - loss: 0.0420 - mean_absolute_error: 0.0420 - val_loss: 0.0513 - val_mean_absolute_error: 0.0513 - 236ms/epoch - 236ms/step
# Epoch 280/1000
# 1/1 - 0s - loss: 0.0415 - mean_absolute_error: 0.0415 - val_loss: 0.0637 - val_mean_absolute_error: 0.0637 - 246ms/epoch - 246ms/step
# Epoch 281/1000
# 1/1 - 0s - loss: 0.0447 - mean_absolute_error: 0.0447 - val_loss: 0.0514 - val_mean_absolute_error: 0.0514 - 234ms/epoch - 234ms/step
# Epoch 282/1000
# 1/1 - 0s - loss: 0.0432 - mean_absolute_error: 0.0432 - val_loss: 0.0530 - val_mean_absolute_error: 0.0530 - 252ms/epoch - 252ms/step
# Epoch 283/1000
# 1/1 - 0s - loss: 0.0444 - mean_absolute_error: 0.0444 - val_loss: 0.0691 - val_mean_absolute_error: 0.0691 - 245ms/epoch - 245ms/step
# Epoch 284/1000
# 1/1 - 0s - loss: 0.0485 - mean_absolute_error: 0.0485 - val_loss: 0.0608 - val_mean_absolute_error: 0.0608 - 244ms/epoch - 244ms/step
# Epoch 285/1000
# 1/1 - 0s - loss: 0.0472 - mean_absolute_error: 0.0472 - val_loss: 0.0601 - val_mean_absolute_error: 0.0601 - 237ms/epoch - 237ms/step
# Epoch 286/1000
# 1/1 - 0s - loss: 0.0507 - mean_absolute_error: 0.0507 - val_loss: 0.0522 - val_mean_absolute_error: 0.0522 - 245ms/epoch - 245ms/step
# Epoch 287/1000
# 1/1 - 0s - loss: 0.0415 - mean_absolute_error: 0.0415 - val_loss: 0.0597 - val_mean_absolute_error: 0.0597 - 236ms/epoch - 236ms/step
# Epoch 288/1000
# 1/1 - 0s - loss: 0.0463 - mean_absolute_error: 0.0463 - val_loss: 0.0537 - val_mean_absolute_error: 0.0537 - 240ms/epoch - 240ms/step
# Epoch 289/1000
# 1/1 - 0s - loss: 0.0447 - mean_absolute_error: 0.0447 - val_loss: 0.0516 - val_mean_absolute_error: 0.0516 - 226ms/epoch - 226ms/step
# Epoch 290/1000
# 1/1 - 0s - loss: 0.0436 - mean_absolute_error: 0.0436 - val_loss: 0.0590 - val_mean_absolute_error: 0.0590 - 254ms/epoch - 254ms/step
# Epoch 291/1000
# 1/1 - 0s - loss: 0.0460 - mean_absolute_error: 0.0460 - val_loss: 0.0500 - val_mean_absolute_error: 0.0500 - 232ms/epoch - 232ms/step
# Epoch 292/1000
# 1/1 - 0s - loss: 0.0385 - mean_absolute_error: 0.0385 - val_loss: 0.0523 - val_mean_absolute_error: 0.0523 - 246ms/epoch - 246ms/step
# Epoch 293/1000
# 1/1 - 0s - loss: 0.0409 - mean_absolute_error: 0.0409 - val_loss: 0.0609 - val_mean_absolute_error: 0.0609 - 231ms/epoch - 231ms/step
# Epoch 294/1000
# 1/1 - 0s - loss: 0.0433 - mean_absolute_error: 0.0433 - val_loss: 0.0508 - val_mean_absolute_error: 0.0508 - 232ms/epoch - 232ms/step
# Epoch 295/1000
# 1/1 - 0s - loss: 0.0387 - mean_absolute_error: 0.0387 - val_loss: 0.0516 - val_mean_absolute_error: 0.0516 - 251ms/epoch - 251ms/step
# Epoch 296/1000
# 1/1 - 0s - loss: 0.0396 - mean_absolute_error: 0.0396 - val_loss: 0.0501 - val_mean_absolute_error: 0.0501 - 232ms/epoch - 232ms/step
# Epoch 297/1000
# 1/1 - 0s - loss: 0.0393 - mean_absolute_error: 0.0393 - val_loss: 0.0534 - val_mean_absolute_error: 0.0534 - 237ms/epoch - 237ms/step
# Epoch 298/1000
# 1/1 - 0s - loss: 0.0444 - mean_absolute_error: 0.0444 - val_loss: 0.0594 - val_mean_absolute_error: 0.0594 - 231ms/epoch - 231ms/step
# Epoch 299/1000
# 1/1 - 0s - loss: 0.0452 - mean_absolute_error: 0.0452 - val_loss: 0.0500 - val_mean_absolute_error: 0.0500 - 254ms/epoch - 254ms/step
# Epoch 300/1000
# 1/1 - 0s - loss: 0.0369 - mean_absolute_error: 0.0369 - val_loss: 0.0525 - val_mean_absolute_error: 0.0525 - 245ms/epoch - 245ms/step
# Epoch 301/1000
# 1/1 - 0s - loss: 0.0418 - mean_absolute_error: 0.0418 - val_loss: 0.0613 - val_mean_absolute_error: 0.0613 - 236ms/epoch - 236ms/step
# Epoch 302/1000
# 1/1 - 0s - loss: 0.0467 - mean_absolute_error: 0.0467 - val_loss: 0.0516 - val_mean_absolute_error: 0.0516 - 236ms/epoch - 236ms/step
# Epoch 303/1000
# 1/1 - 0s - loss: 0.0389 - mean_absolute_error: 0.0389 - val_loss: 0.0623 - val_mean_absolute_error: 0.0623 - 238ms/epoch - 238ms/step
# Epoch 304/1000
# 1/1 - 0s - loss: 0.0529 - mean_absolute_error: 0.0529 - val_loss: 0.0517 - val_mean_absolute_error: 0.0517 - 242ms/epoch - 242ms/step
# Epoch 305/1000
# 1/1 - 0s - loss: 0.0375 - mean_absolute_error: 0.0375 - val_loss: 0.0621 - val_mean_absolute_error: 0.0621 - 241ms/epoch - 241ms/step
# Epoch 306/1000
# 1/1 - 0s - loss: 0.0430 - mean_absolute_error: 0.0430 - val_loss: 0.0499 - val_mean_absolute_error: 0.0499 - 249ms/epoch - 249ms/step
# Epoch 307/1000
# 1/1 - 0s - loss: 0.0404 - mean_absolute_error: 0.0404 - val_loss: 0.0523 - val_mean_absolute_error: 0.0523 - 265ms/epoch - 265ms/step
# Epoch 308/1000
# 1/1 - 0s - loss: 0.0428 - mean_absolute_error: 0.0428 - val_loss: 0.0521 - val_mean_absolute_error: 0.0521 - 255ms/epoch - 255ms/step
# Epoch 309/1000
# 1/1 - 0s - loss: 0.0386 - mean_absolute_error: 0.0386 - val_loss: 0.0490 - val_mean_absolute_error: 0.0490 - 235ms/epoch - 235ms/step
# Epoch 310/1000
# 1/1 - 0s - loss: 0.0381 - mean_absolute_error: 0.0381 - val_loss: 0.0513 - val_mean_absolute_error: 0.0513 - 255ms/epoch - 255ms/step
# Epoch 311/1000
# 1/1 - 0s - loss: 0.0411 - mean_absolute_error: 0.0411 - val_loss: 0.0529 - val_mean_absolute_error: 0.0529 - 411ms/epoch - 411ms/step
# Epoch 312/1000
# 1/1 - 0s - loss: 0.0381 - mean_absolute_error: 0.0381 - val_loss: 0.0527 - val_mean_absolute_error: 0.0527 - 234ms/epoch - 234ms/step
# Epoch 313/1000
# 1/1 - 0s - loss: 0.0404 - mean_absolute_error: 0.0404 - val_loss: 0.0531 - val_mean_absolute_error: 0.0531 - 240ms/epoch - 240ms/step
# Epoch 314/1000
# 1/1 - 0s - loss: 0.0413 - mean_absolute_error: 0.0413 - val_loss: 0.0568 - val_mean_absolute_error: 0.0568 - 244ms/epoch - 244ms/step
# Epoch 315/1000
# 1/1 - 0s - loss: 0.0372 - mean_absolute_error: 0.0372 - val_loss: 0.0526 - val_mean_absolute_error: 0.0526 - 247ms/epoch - 247ms/step
# Epoch 316/1000
# 1/1 - 0s - loss: 0.0381 - mean_absolute_error: 0.0381 - val_loss: 0.0519 - val_mean_absolute_error: 0.0519 - 239ms/epoch - 239ms/step
# Epoch 317/1000
# 1/1 - 0s - loss: 0.0376 - mean_absolute_error: 0.0376 - val_loss: 0.0500 - val_mean_absolute_error: 0.0500 - 231ms/epoch - 231ms/step
# Epoch 318/1000
# 1/1 - 0s - loss: 0.0405 - mean_absolute_error: 0.0405 - val_loss: 0.0512 - val_mean_absolute_error: 0.0512 - 240ms/epoch - 240ms/step
# Epoch 319/1000
# 1/1 - 0s - loss: 0.0375 - mean_absolute_error: 0.0375 - val_loss: 0.0535 - val_mean_absolute_error: 0.0535 - 251ms/epoch - 251ms/step
# Epoch 320/1000
# 1/1 - 0s - loss: 0.0427 - mean_absolute_error: 0.0427 - val_loss: 0.0566 - val_mean_absolute_error: 0.0566 - 240ms/epoch - 240ms/step
# Epoch 321/1000
# 1/1 - 0s - loss: 0.0406 - mean_absolute_error: 0.0406 - val_loss: 0.0529 - val_mean_absolute_error: 0.0529 - 247ms/epoch - 247ms/step
# Epoch 322/1000
# 1/1 - 0s - loss: 0.0380 - mean_absolute_error: 0.0380 - val_loss: 0.0502 - val_mean_absolute_error: 0.0502 - 239ms/epoch - 239ms/step
# Epoch 323/1000
# ...
# Epoch 416/1000
# 1/1 - 0s - loss: 0.0465 - mean_absolute_error: 0.0465 - val_loss: 0.0499 - val_mean_absolute_error: 0.0499 - 242ms/epoch - 242ms/step
# Epoch 417/1000
# 1/1 - 0s - loss: 0.0365 - mean_absolute_error: 0.0365 - val_loss: 0.0615 - val_mean_absolute_error: 0.0615 - 245ms/epoch - 245ms/step
# Epoch 418/1000
# 1/1 - 0s - loss: 0.0441 - mean_absolute_error: 0.0441 - val_loss: 0.0503 - val_mean_absolute_error: 0.0503 - 237ms/epoch - 237ms/step
# Epoch 419/1000
# 1/1 - 0s - loss: 0.0406 - mean_absolute_error: 0.0406 - val_loss: 0.0491 - val_mean_absolute_error: 0.0491 - 233ms/epoch - 233ms/step
# Epoch 420/1000
# 1/1 - 0s - loss: 0.0360 - mean_absolute_error: 0.0360 - val_loss: 0.0554 - val_mean_absolute_error: 0.0554 - 238ms/epoch - 238ms/step
# Epoch 421/1000
# 1/1 - 0s - loss: 0.0396 - mean_absolute_error: 0.0396 - val_loss: 0.0479 - val_mean_absolute_error: 0.0479 - 240ms/epoch - 240ms/step
# Epoch 422/1000
# 1/1 - 0s - loss: 0.0379 - mean_absolute_error: 0.0379 - val_loss: 0.0512 - val_mean_absolute_error: 0.0512 - 230ms/epoch - 230ms/step
# Epoch 423/1000
# 1/1 - 0s - loss: 0.0367 - mean_absolute_error: 0.0367 - val_loss: 0.0499 - val_mean_absolute_error: 0.0499 - 235ms/epoch - 235ms/step
# Epoch 424/1000
# 1/1 - 0s - loss: 0.0346 - mean_absolute_error: 0.0346 - val_loss: 0.0510 - val_mean_absolute_error: 0.0510 - 257ms/epoch - 257ms/step
# Epoch 425/1000
# 1/1 - 0s - loss: 0.0373 - mean_absolute_error: 0.0373 - val_loss: 0.0489 - val_mean_absolute_error: 0.0489 - 242ms/epoch - 242ms/step
# Epoch 426/1000
# 1/1 - 0s - loss: 0.0335 - mean_absolute_error: 0.0335 - val_loss: 0.0497 - val_mean_absolute_error: 0.0497 - 244ms/epoch - 244ms/step
# Epoch 427/1000
# 1/1 - 0s - loss: 0.0371 - mean_absolute_error: 0.0371 - val_loss: 0.0522 - val_mean_absolute_error: 0.0522 - 240ms/epoch - 240ms/step
# Epoch 428/1000
# 1/1 - 0s - loss: 0.0370 - mean_absolute_error: 0.0370 - val_loss: 0.0486 - val_mean_absolute_error: 0.0486 - 256ms/epoch - 256ms/step
# Epoch 429/1000
# 1/1 - 0s - loss: 0.0359 - mean_absolute_error: 0.0359 - val_loss: 0.0525 - val_mean_absolute_error: 0.0525 - 255ms/epoch - 255ms/step
# Epoch 430/1000
# 1/1 - 0s - loss: 0.0388 - mean_absolute_error: 0.0388 - val_loss: 0.0522 - val_mean_absolute_error: 0.0522 - 235ms/epoch - 235ms/step
# Epoch 431/1000
# 1/1 - 0s - loss: 0.0382 - mean_absolute_error: 0.0382 - val_loss: 0.0492 - val_mean_absolute_error: 0.0492 - 249ms/epoch - 249ms/step
# Epoch 432/1000
# 1/1 - 0s - loss: 0.0371 - mean_absolute_error: 0.0371 - val_loss: 0.0509 - val_mean_absolute_error: 0.0509 - 249ms/epoch - 249ms/step
# Epoch 433/1000
# 1/1 - 0s - loss: 0.0349 - mean_absolute_error: 0.0349 - val_loss: 0.0509 - val_mean_absolute_error: 0.0509 - 240ms/epoch - 240ms/step
# Epoch 434/1000
# 1/1 - 0s - loss: 0.0383 - mean_absolute_error: 0.0383 - val_loss: 0.0498 - val_mean_absolute_error: 0.0498 - 228ms/epoch - 228ms/step
# Epoch 435/1000
# 1/1 - 0s - loss: 0.0361 - mean_absolute_error: 0.0361 - val_loss: 0.0532 - val_mean_absolute_error: 0.0532 - 235ms/epoch - 235ms/step
# Epoch 436/1000
# 1/1 - 0s - loss: 0.0358 - mean_absolute_error: 0.0358 - val_loss: 0.0518 - val_mean_absolute_error: 0.0518 - 236ms/epoch - 236ms/step
# Epoch 437/1000
# 1/1 - 0s - loss: 0.0382 - mean_absolute_error: 0.0382 - val_loss: 0.0502 - val_mean_absolute_error: 0.0502 - 235ms/epoch - 235ms/step
# Epoch 438/1000
# 1/1 - 0s - loss: 0.0346 - mean_absolute_error: 0.0346 - val_loss: 0.0547 - val_mean_absolute_error: 0.0547 - 240ms/epoch - 240ms/step
# Epoch 439/1000
# 1/1 - 0s - loss: 0.0425 - mean_absolute_error: 0.0425 - val_loss: 0.0518 - val_mean_absolute_error: 0.0518 - 237ms/epoch - 237ms/step
# Epoch 440/1000
# 1/1 - 0s - loss: 0.0370 - mean_absolute_error: 0.0370 - val_loss: 0.0521 - val_mean_absolute_error: 0.0521 - 235ms/epoch - 235ms/step
# Epoch 441/1000
# 1/1 - 0s - loss: 0.0362 - mean_absolute_error: 0.0362 - val_loss: 0.0541 - val_mean_absolute_error: 0.0541 - 235ms/epoch - 235ms/step
# Epoch 442/1000
# 1/1 - 0s - loss: 0.0392 - mean_absolute_error: 0.0392 - val_loss: 0.0539 - val_mean_absolute_error: 0.0539 - 248ms/epoch - 248ms/step
# Epoch 443/1000
# 1/1 - 0s - loss: 0.0356 - mean_absolute_error: 0.0356 - val_loss: 0.0505 - val_mean_absolute_error: 0.0505 - 228ms/epoch - 228ms/step
# Epoch 444/1000
# 1/1 - 0s - loss: 0.0336 - mean_absolute_error: 0.0336 - val_loss: 0.0515 - val_mean_absolute_error: 0.0515 - 240ms/epoch - 240ms/step
# Epoch 445/1000
# 1/1 - 0s - loss: 0.0353 - mean_absolute_error: 0.0353 - val_loss: 0.0519 - val_mean_absolute_error: 0.0519 - 229ms/epoch - 229ms/step
# Epoch 446/1000
# 1/1 - 0s - loss: 0.0394 - mean_absolute_error: 0.0394 - val_loss: 0.0510 - val_mean_absolute_error: 0.0510 - 251ms/epoch - 251ms/step
# Epoch 447/1000
# 1/1 - 0s - loss: 0.0344 - mean_absolute_error: 0.0344 - val_loss: 0.0499 - val_mean_absolute_error: 0.0499 - 234ms/epoch - 234ms/step
# Epoch 448/1000
# 1/1 - 0s - loss: 0.0361 - mean_absolute_error: 0.0361 - val_loss: 0.0502 - val_mean_absolute_error: 0.0502 - 239ms/epoch - 239ms/step
# Epoch 449/1000
# 1/1 - 0s - loss: 0.0365 - mean_absolute_error: 0.0365 - val_loss: 0.0494 - val_mean_absolute_error: 0.0494 - 231ms/epoch - 231ms/step
# Epoch 450/1000
# 1/1 - 0s - loss: 0.0339 - mean_absolute_error: 0.0339 - val_loss: 0.0508 - val_mean_absolute_error: 0.0508 - 240ms/epoch - 240ms/step
# Epoch 451/1000
# 1/1 - 0s - loss: 0.0348 - mean_absolute_error: 0.0348 - val_loss: 0.0498 - val_mean_absolute_error: 0.0498 - 228ms/epoch - 228ms/step
# Epoch 452/1000
# 1/1 - 0s - loss: 0.0342 - mean_absolute_error: 0.0342 - val_loss: 0.0505 - val_mean_absolute_error: 0.0505 - 234ms/epoch - 234ms/step
# Epoch 453/1000
# 1/1 - 0s - loss: 0.0343 - mean_absolute_error: 0.0343 - val_loss: 0.0509 - val_mean_absolute_error: 0.0509 - 237ms/epoch - 237ms/step
# Epoch 454/1000
# 1/1 - 0s - loss: 0.0346 - mean_absolute_error: 0.0346 - val_loss: 0.0545 - val_mean_absolute_error: 0.0545 - 243ms/epoch - 243ms/step
# Epoch 455/1000
# 1/1 - 0s - loss: 0.0346 - mean_absolute_error: 0.0346 - val_loss: 0.0536 - val_mean_absolute_error: 0.0536 - 235ms/epoch - 235ms/step
# Epoch 456/1000
# 1/1 - 0s - loss: 0.0353 - mean_absolute_error: 0.0353 - val_loss: 0.0524 - val_mean_absolute_error: 0.0524 - 236ms/epoch - 236ms/step
# Epoch 457/1000
# 1/1 - 0s - loss: 0.0392 - mean_absolute_error: 0.0392 - val_loss: 0.0538 - val_mean_absolute_error: 0.0538 - 241ms/epoch - 241ms/step
# Epoch 458/1000
# 1/1 - 0s - loss: 0.0369 - mean_absolute_error: 0.0369 - val_loss: 0.0525 - val_mean_absolute_error: 0.0525 - 242ms/epoch - 242ms/step
# Epoch 459/1000
# 1/1 - 0s - loss: 0.0382 - mean_absolute_error: 0.0382 - val_loss: 0.0512 - val_mean_absolute_error: 0.0512 - 248ms/epoch - 248ms/step
# Epoch 460/1000
# 1/1 - 0s - loss: 0.0353 - mean_absolute_error: 0.0353 - val_loss: 0.0582 - val_mean_absolute_error: 0.0582 - 239ms/epoch - 239ms/step
# Epoch 461/1000
# 1/1 - 0s - loss: 0.0419 - mean_absolute_error: 0.0419 - val_loss: 0.0513 - val_mean_absolute_error: 0.0513 - 245ms/epoch - 245ms/step
# Epoch 462/1000
# 1/1 - 0s - loss: 0.0352 - mean_absolute_error: 0.0352 - val_loss: 0.0537 - val_mean_absolute_error: 0.0537 - 237ms/epoch - 237ms/step
# Epoch 463/1000
# 1/1 - 0s - loss: 0.0374 - mean_absolute_error: 0.0374 - val_loss: 0.0501 - val_mean_absolute_error: 0.0501 - 238ms/epoch - 238ms/step
# Epoch 464/1000
# 1/1 - 0s - loss: 0.0346 - mean_absolute_error: 0.0346 - val_loss: 0.0545 - val_mean_absolute_error: 0.0545 - 229ms/epoch - 229ms/step
# Epoch 465/1000
# 1/1 - 0s - loss: 0.0411 - mean_absolute_error: 0.0411 - val_loss: 0.0579 - val_mean_absolute_error: 0.0579 - 232ms/epoch - 232ms/step
# Epoch 466/1000
# 1/1 - 0s - loss: 0.0379 - mean_absolute_error: 0.0379 - val_loss: 0.0534 - val_mean_absolute_error: 0.0534 - 235ms/epoch - 235ms/step
# Epoch 467/1000
# 1/1 - 0s - loss: 0.0366 - mean_absolute_error: 0.0366 - val_loss: 0.0517 - val_mean_absolute_error: 0.0517 - 242ms/epoch - 242ms/step
# Epoch 468/1000
# 1/1 - 0s - loss: 0.0357 - mean_absolute_error: 0.0357 - val_loss: 0.0514 - val_mean_absolute_error: 0.0514 - 234ms/epoch - 234ms/step
# Epoch 469/1000
# 1/1 - 0s - loss: 0.0347 - mean_absolute_error: 0.0347 - val_loss: 0.0540 - val_mean_absolute_error: 0.0540 - 236ms/epoch - 236ms/step
# Epoch 470/1000
# 1/1 - 0s - loss: 0.0395 - mean_absolute_error: 0.0395 - val_loss: 0.0681 - val_mean_absolute_error: 0.0681 - 236ms/epoch - 236ms/step
# Epoch 471/1000
# 1/1 - 0s - loss: 0.0426 - mean_absolute_error: 0.0426 - val_loss: 0.0555 - val_mean_absolute_error: 0.0555 - 237ms/epoch - 237ms/step
# Epoch 472/1000
# 1/1 - 0s - loss: 0.0416 - mean_absolute_error: 0.0416 - val_loss: 0.0566 - val_mean_absolute_error: 0.0566 - 246ms/epoch - 246ms/step
# Epoch 473/1000
# 1/1 - 0s - loss: 0.0410 - mean_absolute_error: 0.0410 - val_loss: 0.0527 - val_mean_absolute_error: 0.0527 - 236ms/epoch - 236ms/step
# Epoch 474/1000
# 1/1 - 0s - loss: 0.0382 - mean_absolute_error: 0.0382 - val_loss: 0.0526 - val_mean_absolute_error: 0.0526 - 235ms/epoch - 235ms/step
# Epoch 475/1000
# 1/1 - 0s - loss: 0.0400 - mean_absolute_error: 0.0400 - val_loss: 0.0542 - val_mean_absolute_error: 0.0542 - 247ms/epoch - 247ms/step
# Epoch 476/1000
# 1/1 - 0s - loss: 0.0377 - mean_absolute_error: 0.0377 - val_loss: 0.0528 - val_mean_absolute_error: 0.0528 - 236ms/epoch - 236ms/step
# Epoch 477/1000
# 1/1 - 0s - loss: 0.0386 - mean_absolute_error: 0.0386 - val_loss: 0.0532 - val_mean_absolute_error: 0.0532 - 233ms/epoch - 233ms/step
# Epoch 478/1000
# 1/1 - 0s - loss: 0.0408 - mean_absolute_error: 0.0408 - val_loss: 0.0549 - val_mean_absolute_error: 0.0549 - 227ms/epoch - 227ms/step
# Epoch 479/1000
# 1/1 - 0s - loss: 0.0386 - mean_absolute_error: 0.0386 - val_loss: 0.0523 - val_mean_absolute_error: 0.0523 - 238ms/epoch - 238ms/step
# Epoch 480/1000
# 1/1 - 0s - loss: 0.0359 - mean_absolute_error: 0.0359 - val_loss: 0.0517 - val_mean_absolute_error: 0.0517 - 242ms/epoch - 242ms/step
# Epoch 481/1000
# 1/1 - 0s - loss: 0.0387 - mean_absolute_error: 0.0387 - val_loss: 0.0506 - val_mean_absolute_error: 0.0506 - 243ms/epoch - 243ms/step
# Epoch 482/1000
# 1/1 - 0s - loss: 0.0352 - mean_absolute_error: 0.0352 - val_loss: 0.0521 - val_mean_absolute_error: 0.0521 - 236ms/epoch - 236ms/step
# Epoch 483/1000
# 1/1 - 0s - loss: 0.0368 - mean_absolute_error: 0.0368 - val_loss: 0.0514 - val_mean_absolute_error: 0.0514 - 236ms/epoch - 236ms/step
# Epoch 484/1000
# 1/1 - 0s - loss: 0.0392 - mean_absolute_error: 0.0392 - val_loss: 0.0498 - val_mean_absolute_error: 0.0498 - 246ms/epoch - 246ms/step
# Epoch 485/1000
# 1/1 - 0s - loss: 0.0336 - mean_absolute_error: 0.0336 - val_loss: 0.0520 - val_mean_absolute_error: 0.0520 - 243ms/epoch - 243ms/step
# Epoch 486/1000
# 1/1 - 0s - loss: 0.0393 - mean_absolute_error: 0.0393 - val_loss: 0.0528 - val_mean_absolute_error: 0.0528 - 229ms/epoch - 229ms/step
# Epoch 487/1000
# 1/1 - 0s - loss: 0.0385 - mean_absolute_error: 0.0385 - val_loss: 0.0514 - val_mean_absolute_error: 0.0514 - 233ms/epoch - 233ms/step
# Epoch 488/1000
# 1/1 - 0s - loss: 0.0371 - mean_absolute_error: 0.0371 - val_loss: 0.0538 - val_mean_absolute_error: 0.0538 - 242ms/epoch - 242ms/step
# Epoch 489/1000
# 1/1 - 0s - loss: 0.0398 - mean_absolute_error: 0.0398 - val_loss: 0.0560 - val_mean_absolute_error: 0.0560 - 235ms/epoch - 235ms/step
# Epoch 490/1000
# 1/1 - 0s - loss: 0.0379 - mean_absolute_error: 0.0379 - val_loss: 0.0518 - val_mean_absolute_error: 0.0518 - 228ms/epoch - 228ms/step
# Epoch 491/1000
# 1/1 - 0s - loss: 0.0392 - mean_absolute_error: 0.0392 - val_loss: 0.0523 - val_mean_absolute_error: 0.0523 - 238ms/epoch - 238ms/step
# Epoch 492/1000
# 1/1 - 0s - loss: 0.0363 - mean_absolute_error: 0.0363 - val_loss: 0.0606 - val_mean_absolute_error: 0.0606 - 245ms/epoch - 245ms/step
# Epoch 493/1000
# 1/1 - 0s - loss: 0.0404 - mean_absolute_error: 0.0404 - val_loss: 0.0533 - val_mean_absolute_error: 0.0533 - 241ms/epoch - 241ms/step
# Epoch 494/1000
# 1/1 - 0s - loss: 0.0369 - mean_absolute_error: 0.0369 - val_loss: 0.0523 - val_mean_absolute_error: 0.0523 - 244ms/epoch - 244ms/step
# Epoch 495/1000
# 1/1 - 0s - loss: 0.0391 - mean_absolute_error: 0.0391 - val_loss: 0.0574 - val_mean_absolute_error: 0.0574 - 232ms/epoch - 232ms/step
# Epoch 496/1000
# 1/1 - 0s - loss: 0.0375 - mean_absolute_error: 0.0375 - val_loss: 0.0526 - val_mean_absolute_error: 0.0526 - 253ms/epoch - 253ms/step
# Epoch 497/1000
# 1/1 - 0s - loss: 0.0352 - mean_absolute_error: 0.0352 - val_loss: 0.0535 - val_mean_absolute_error: 0.0535 - 243ms/epoch - 243ms/step
# Epoch 498/1000
# 1/1 - 0s - loss: 0.0358 - mean_absolute_error: 0.0358 - val_loss: 0.0569 - val_mean_absolute_error: 0.0569 - 231ms/epoch - 231ms/step
# Epoch 499/1000
# 1/1 - 0s - loss: 0.0361 - mean_absolute_error: 0.0361 - val_loss: 0.0518 - val_mean_absolute_error: 0.0518 - 237ms/epoch - 237ms/step
# Epoch 500/1000
# 1/1 - 0s - loss: 0.0346 - mean_absolute_error: 0.0346 - val_loss: 0.0500 - val_mean_absolute_error: 0.0500 - 237ms/epoch - 237ms/step
# Epoch 501/1000
# 1/1 - 0s - loss: 0.0352 - mean_absolute_error: 0.0352 - val_loss: 0.0522 - val_mean_absolute_error: 0.0522 - 239ms/epoch - 239ms/step
# Epoch 502/1000
# 1/1 - 0s - loss: 0.0364 - mean_absolute_error: 0.0364 - val_loss: 0.0513 - val_mean_absolute_error: 0.0513 - 237ms/epoch - 237ms/step
# Epoch 503/1000
# 1/1 - 0s - loss: 0.0364 - mean_absolute_error: 0.0364 - val_loss: 0.0518 - val_mean_absolute_error: 0.0518 - 232ms/epoch - 232ms/step
# Epoch 504/1000
# 1/1 - 0s - loss: 0.0372 - mean_absolute_error: 0.0372 - val_loss: 0.0523 - val_mean_absolute_error: 0.0523 - 231ms/epoch - 231ms/step
# Epoch 505/1000
# 1/1 - 0s - loss: 0.0391 - mean_absolute_error: 0.0391 - val_loss: 0.0505 - val_mean_absolute_error: 0.0505 - 248ms/epoch - 248ms/step
# Epoch 506/1000
# 1/1 - 0s - loss: 0.0352 - mean_absolute_error: 0.0352 - val_loss: 0.0503 - val_mean_absolute_error: 0.0503 - 237ms/epoch - 237ms/step
# Epoch 507/1000
# 1/1 - 0s - loss: 0.0334 - mean_absolute_error: 0.0334 - val_loss: 0.0510 - val_mean_absolute_error: 0.0510 - 225ms/epoch - 225ms/step
# Epoch 508/1000
# 1/1 - 0s - loss: 0.0340 - mean_absolute_error: 0.0340 - val_loss: 0.0515 - val_mean_absolute_error: 0.0515 - 245ms/epoch - 245ms/step
# Epoch 509/1000
# 1/1 - 0s - loss: 0.0356 - mean_absolute_error: 0.0356 - val_loss: 0.0532 - val_mean_absolute_error: 0.0532 - 240ms/epoch - 240ms/step
# Epoch 510/1000
# 1/1 - 0s - loss: 0.0351 - mean_absolute_error: 0.0351 - val_loss: 0.0542 - val_mean_absolute_error: 0.0542 - 243ms/epoch - 243ms/step
# Epoch 511/1000
# 1/1 - 0s - loss: 0.0360 - mean_absolute_error: 0.0360 - val_loss: 0.0543 - val_mean_absolute_error: 0.0543 - 233ms/epoch - 233ms/step
# Epoch 512/1000
# 1/1 - 0s - loss: 0.0368 - mean_absolute_error: 0.0368 - val_loss: 0.0523 - val_mean_absolute_error: 0.0523 - 241ms/epoch - 241ms/step
# Epoch 513/1000
# 1/1 - 0s - loss: 0.0364 - mean_absolute_error: 0.0364 - val_loss: 0.0519 - val_mean_absolute_error: 0.0519 - 247ms/epoch - 247ms/step
# Epoch 514/1000
# 1/1 - 0s - loss: 0.0364 - mean_absolute_error: 0.0364 - val_loss: 0.0556 - val_mean_absolute_error: 0.0556 - 248ms/epoch - 248ms/step
# Epoch 515/1000
# 1/1 - 0s - loss: 0.0381 - mean_absolute_error: 0.0381 - val_loss: 0.0512 - val_mean_absolute_error: 0.0512 - 229ms/epoch - 229ms/step
# Epoch 516/1000
# 1/1 - 0s - loss: 0.0347 - mean_absolute_error: 0.0347 - val_loss: 0.0504 - val_mean_absolute_error: 0.0504 - 243ms/epoch - 243ms/step
# Epoch 517/1000
# 1/1 - 0s - loss: 0.0343 - mean_absolute_error: 0.0343 - val_loss: 0.0513 - val_mean_absolute_error: 0.0513 - 242ms/epoch - 242ms/step
# Epoch 518/1000
# 1/1 - 0s - loss: 0.0373 - mean_absolute_error: 0.0373 - val_loss: 0.0512 - val_mean_absolute_error: 0.0512 - 247ms/epoch - 247ms/step
# Epoch 519/1000
# 1/1 - 0s - loss: 0.0345 - mean_absolute_error: 0.0345 - val_loss: 0.0516 - val_mean_absolute_error: 0.0516 - 230ms/epoch - 230ms/step
# Epoch 520/1000
# 1/1 - 0s - loss: 0.0371 - mean_absolute_error: 0.0371 - val_loss: 0.0501 - val_mean_absolute_error: 0.0501 - 240ms/epoch - 240ms/step
# Epoch 521/1000
# Restoring model weights from the end of the best epoch: 421.
# 1/1 - 0s - loss: 0.0342 - mean_absolute_error: 0.0342 - val_loss: 0.0512 - val_mean_absolute_error: 0.0512 - 254ms/epoch - 254ms/step
# Epoch 521: early stopping

# %%
# Loss Curve
import matplotlib.pyplot as plt
from matplotlib import pyplot
pyplot.plot(history.history['loss'][:], label='train')
pyplot.plot(history.history['val_loss'][:], label='test')
pyplot.legend()
pyplot.show()

# %%
# prediction
yhat_test = model.predict(X_test)
yhat_train = model.predict(X_train)
# Out:
# 58/58 [==============================] - 2s 28ms/step
# 12/12 [==============================] - 0s 28ms/step

# %%
# Evaluating the residual error using Nash-Sutcliffe and denormalization
def nse(predictions, targets):
    return (1-(np.sum((predictions-targets)**2)/np.sum((targets-np.mean(targets))**2)))
inv_yhat_train = inv_yhat(yhat_train)
inv_yhat_test = inv_yhat(yhat_test)
inv_y_train = inv_y(y_train)
inv_y_test = inv_y(y_test)
print("train",nse(np.array(inv_yhat_train),np.array(inv_y_train)))
print("test",nse(np.array(inv_yhat_test),np.array(inv_y_test)))

# %%
# Adding Simulated residual error in the data frame
df= pd.read_csv("/content/drive/MyDrive/Data/OneYearResidualErrorModelling.csv",index_col=0)
df=df[365:].reset_index(drop=True)
df.loc[:,"SimulatedResidualError"]=df.loc[:,"Residual Error"]
df.loc[365:,"SimulatedResidualError"]=inv_yhat_train+inv_yhat_test

# %%
#Train Plot
import matplotlib.pyplot as plt
plt.plot(inv_y_train[:])
plt.plot(inv_yhat_train[:])

# %%
# Test Plot
import matplotlib.pyplot as plt
plt.plot(inv_y_test[:])
plt.plot(inv_yhat_test[:])
