# %% [markdown]
# <a href="https://colab.research.google.com/github/DineshJoshi2/Hydrological-Residual-Error-Modelling/blob/main/LSTM_ONLY_for_3_Year_Training_and_3_year_testing_Data_(HYDROLOGICAL_RESIDUAL_ERROR_MODELLING).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## LSTM ONLY for 3 Year Training and 3 year testing Data

# %%
# for reproducibility of the code
import os
os.environ["PYTHONHASHSEED"] = "0"
import numpy as np
import random as rn
import tensorflow as tf
# setting the seed for numpy generated random numbers
np.random.seed(73)
# setting the seed for python random number
rn.seed(723)
# setting the seed for tensorflow random number
tf.random.set_seed(1)

# %%
# importing necessary libraries
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras import optimizers
from tensorflow.keras.layers import Dropout
from tensorflow.keras.constraints import MaxNorm
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error

# %%
# loading data set
df= pd.read_csv("/content/drive/MyDrive/Data/FourYearResidualErrorModelling.csv")
# using one year of data from the data set
df=df[365:].reset_index(drop=True)

# %%
# Retriving the necessary columns from the datasets.
 df=df[['Temperature (Deg C)', 'Precipitation (mm)',
       'Precipitation0816 (mm)', 'Temperature0816 (Deg C)', 'Observed Discharge (m3/s)']]

# %%
# extrating the vaules from the data frame
values = df.values
# change all datatype to float
values = values.astype('float32')

# %%
# normalization all features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)

# %%
#converting the data into 3D array
l=[]
for i in range(len(scaled)-365):
    l.append(scaled[i:366+i,:])
Data=np.array(l)

# %%
# checking the shape of the data
Data.shape
# Out:
# (2192, 366, 5)

# %%
## test and train data
X=Data[:,:,:-1]
y=Data[:,-1,-1]
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.50, shuffle =False)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1096, 366, 4)
# (1096, 366, 4)
# (1096,)
# (1096,)

# %%
# Useful functions to undo normalization later
def inv_yhat(yhat):
  yhat=[i[0] for i in yhat]
  A=np.zeros((len(yhat),5))
  A[:,0]=yhat
  A[:,1]=yhat
  A[:,2]=yhat
  A[:,3]=yhat
  A[:,4]=yhat
  inv_yhat= scaler.inverse_transform(A)
  inv_yhat = [i[-1] for i in inv_yhat]
  return inv_yhat
def inv_y(y):
  A=np.zeros((len(y),5))
  A[:,0]=y
  A[:,1]=y
  A[:,2]=y
  A[:,3]=y
  A[:,4]=y
  inv_y= scaler.inverse_transform(A)
  inv_y = [i[-1] for i in inv_y]
  return inv_y

# %%
# Defining Some model parameters
epochs=1000
learning_rate1 = 0.01
decay_rate = (learning_rate1*16)/epochs

# %%
# for reproducibility of the code
import os
os.environ["PYTHONHASHSEED"] = "0"
import numpy as np
import random as rn
import tensorflow as tf
np.random.seed(73)
rn.seed(723)
tf.random.set_seed(1)

# %%
# Building The Main MODEL
model = Sequential()
model.add(LSTM(128,kernel_initializer="GlorotUniform",return_sequences=False,input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dense(1))
Adam=tf.keras.optimizers.Adam(learning_rate = learning_rate1, beta_1 = 0.9, beta_2 = 0.999, amsgrad = False)
model.compile(loss="mae", optimizer=Adam, metrics=[tf.keras.metrics.MeanAbsoluteError()])

# %%
#Add Callbacks, e.g. ModelCheckpoints, earlystopping, csvlogger.
from keras.callbacks import ModelCheckpoint, EarlyStopping, CSVLogger,LearningRateScheduler

#ModelCheckpoint callback saves a model at some interval.
filepath="saved_models/weights-improvement-{epoch:02d}-{val_acc:.2f}.hdf5" #File name includes epoch and validation accuracy.
#Use Mode = max for accuracy and min for loss.
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

#https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/EarlyStopping
early_stop = EarlyStopping(monitor='val_loss',min_delta=0.0001, patience= 100,verbose=1,restore_best_weights=True)
#This callback will stop the training when there is no improvement in
# the validation loss for three consecutive epochs.

#CSVLogger logs epoch, acc, loss, val_acc, val_loss
log_csv = CSVLogger("/content/drive/MyDrive/Data/LSTMlogs.csv", separator=',', append=False)

#learning rate decay
def exp_decay(epoch):
  lrate = learning_rate1 * np.exp(-decay_rate*epoch)
  return lrate

# learning schedule callback
lr_rate = LearningRateScheduler(exp_decay)

callbacks_list = [early_stop,lr_rate]

# %%
# Training The Model
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs =epochs ,callbacks=callbacks_list, batch_size=len(X_train), verbose = 2, shuffle = True)
# Out:
# Epoch 1/1000
# 1/1 - 2s - loss: 0.1093 - mean_absolute_error: 0.1093 - val_loss: 1.1470 - val_mean_absolute_error: 1.1470 - lr: 0.0100 - 2s/epoch - 2s/step
# Epoch 2/1000
# 1/1 - 0s - loss: 1.2433 - mean_absolute_error: 1.2433 - val_loss: 0.1493 - val_mean_absolute_error: 0.1493 - lr: 0.0100 - 201ms/epoch - 201ms/step
# Epoch 3/1000
# 1/1 - 0s - loss: 0.1455 - mean_absolute_error: 0.1455 - val_loss: 0.2116 - val_mean_absolute_error: 0.2116 - lr: 0.0100 - 189ms/epoch - 189ms/step
# Epoch 4/1000
# 1/1 - 0s - loss: 0.1748 - mean_absolute_error: 0.1748 - val_loss: 0.1699 - val_mean_absolute_error: 0.1699 - lr: 0.0100 - 178ms/epoch - 178ms/step
# Epoch 5/1000
# 1/1 - 0s - loss: 0.1315 - mean_absolute_error: 0.1315 - val_loss: 0.1219 - val_mean_absolute_error: 0.1219 - lr: 0.0100 - 179ms/epoch - 179ms/step
# Epoch 6/1000
# 1/1 - 0s - loss: 0.0996 - mean_absolute_error: 0.0996 - val_loss: 0.1333 - val_mean_absolute_error: 0.1333 - lr: 0.0100 - 176ms/epoch - 176ms/step
# Epoch 7/1000
# 1/1 - 0s - loss: 0.1198 - mean_absolute_error: 0.1198 - val_loss: 0.1332 - val_mean_absolute_error: 0.1332 - lr: 0.0100 - 158ms/epoch - 158ms/step
# Epoch 8/1000
# 1/1 - 0s - loss: 0.1202 - mean_absolute_error: 0.1202 - val_loss: 0.1216 - val_mean_absolute_error: 0.1216 - lr: 0.0100 - 157ms/epoch - 157ms/step
# Epoch 9/1000
# 1/1 - 0s - loss: 0.1041 - mean_absolute_error: 0.1041 - val_loss: 0.1184 - val_mean_absolute_error: 0.1184 - lr: 0.0100 - 162ms/epoch - 162ms/step
# Epoch 10/1000
# 1/1 - 0s - loss: 0.0899 - mean_absolute_error: 0.0899 - val_loss: 0.1315 - val_mean_absolute_error: 0.1315 - lr: 0.0100 - 182ms/epoch - 182ms/step
# Epoch 11/1000
# 1/1 - 0s - loss: 0.0972 - mean_absolute_error: 0.0972 - val_loss: 0.1384 - val_mean_absolute_error: 0.1384 - lr: 0.0100 - 156ms/epoch - 156ms/step
# Epoch 12/1000
# 1/1 - 0s - loss: 0.1017 - mean_absolute_error: 0.1017 - val_loss: 0.1325 - val_mean_absolute_error: 0.1325 - lr: 0.0100 - 180ms/epoch - 180ms/step
# Epoch 13/1000
# 1/1 - 0s - loss: 0.0962 - mean_absolute_error: 0.0962 - val_loss: 0.1201 - val_mean_absolute_error: 0.1201 - lr: 0.0100 - 156ms/epoch - 156ms/step
# Epoch 14/1000
# 1/1 - 0s - loss: 0.0857 - mean_absolute_error: 0.0857 - val_loss: 0.1080 - val_mean_absolute_error: 0.1080 - lr: 0.0100 - 181ms/epoch - 181ms/step
# Epoch 15/1000
# 1/1 - 0s - loss: 0.0780 - mean_absolute_error: 0.0780 - val_loss: 0.1048 - val_mean_absolute_error: 0.1048 - lr: 0.0100 - 179ms/epoch - 179ms/step
# Epoch 16/1000
# 1/1 - 0s - loss: 0.0823 - mean_absolute_error: 0.0823 - val_loss: 0.1026 - val_mean_absolute_error: 0.1026 - lr: 0.0100 - 179ms/epoch - 179ms/step
# Epoch 17/1000
# 1/1 - 0s - loss: 0.0817 - mean_absolute_error: 0.0817 - val_loss: 0.0996 - val_mean_absolute_error: 0.0996 - lr: 0.0100 - 176ms/epoch - 176ms/step
# Epoch 18/1000
# 1/1 - 0s - loss: 0.0697 - mean_absolute_error: 0.0697 - val_loss: 0.1053 - val_mean_absolute_error: 0.1053 - lr: 0.0100 - 167ms/epoch - 167ms/step
# Epoch 19/1000
# 1/1 - 0s - loss: 0.0687 - mean_absolute_error: 0.0687 - val_loss: 0.1087 - val_mean_absolute_error: 0.1087 - lr: 0.0100 - 188ms/epoch - 188ms/step
# Epoch 20/1000
# 1/1 - 0s - loss: 0.0674 - mean_absolute_error: 0.0674 - val_loss: 0.0922 - val_mean_absolute_error: 0.0922 - lr: 0.0100 - 163ms/epoch - 163ms/step
# Epoch 21/1000
# 1/1 - 0s - loss: 0.0690 - mean_absolute_error: 0.0690 - val_loss: 0.1129 - val_mean_absolute_error: 0.1129 - lr: 0.0100 - 183ms/epoch - 183ms/step
# Epoch 22/1000
# 1/1 - 0s - loss: 0.0693 - mean_absolute_error: 0.0693 - val_loss: 0.1058 - val_mean_absolute_error: 0.1058 - lr: 0.0100 - 169ms/epoch - 169ms/step
# Epoch 23/1000
# 1/1 - 0s - loss: 0.0648 - mean_absolute_error: 0.0648 - val_loss: 0.0904 - val_mean_absolute_error: 0.0904 - lr: 0.0100 - 187ms/epoch - 187ms/step
# Epoch 24/1000
# 1/1 - 0s - loss: 0.0628 - mean_absolute_error: 0.0628 - val_loss: 0.0894 - val_mean_absolute_error: 0.0894 - lr: 0.0100 - 167ms/epoch - 167ms/step
# Epoch 25/1000
# 1/1 - 0s - loss: 0.0612 - mean_absolute_error: 0.0612 - val_loss: 0.0941 - val_mean_absolute_error: 0.0941 - lr: 0.0100 - 186ms/epoch - 186ms/step
# Epoch 26/1000
# 1/1 - 0s - loss: 0.0596 - mean_absolute_error: 0.0596 - val_loss: 0.0950 - val_mean_absolute_error: 0.0950 - lr: 0.0100 - 166ms/epoch - 166ms/step
# Epoch 27/1000
# 1/1 - 0s - loss: 0.0600 - mean_absolute_error: 0.0600 - val_loss: 0.0909 - val_mean_absolute_error: 0.0909 - lr: 0.0100 - 190ms/epoch - 190ms/step
# Epoch 28/1000
# 1/1 - 0s - loss: 0.0576 - mean_absolute_error: 0.0576 - val_loss: 0.0823 - val_mean_absolute_error: 0.0823 - lr: 0.0100 - 188ms/epoch - 188ms/step
# Epoch 29/1000
# 1/1 - 0s - loss: 0.0557 - mean_absolute_error: 0.0557 - val_loss: 0.0791 - val_mean_absolute_error: 0.0791 - lr: 0.0100 - 186ms/epoch - 186ms/step
# Epoch 30/1000
# 1/1 - 0s - loss: 0.0528 - mean_absolute_error: 0.0528 - val_loss: 0.0845 - val_mean_absolute_error: 0.0845 - lr: 0.0100 - 193ms/epoch - 193ms/step
# Epoch 31/1000
# 1/1 - 0s - loss: 0.0502 - mean_absolute_error: 0.0502 - val_loss: 0.0735 - val_mean_absolute_error: 0.0735 - lr: 0.0100 - 185ms/epoch - 185ms/step
# Epoch 32/1000
# 1/1 - 0s - loss: 0.0471 - mean_absolute_error: 0.0471 - val_loss: 0.0685 - val_mean_absolute_error: 0.0685 - lr: 0.0100 - 167ms/epoch - 167ms/step
# Epoch 33/1000
# 1/1 - 0s - loss: 0.0484 - mean_absolute_error: 0.0484 - val_loss: 0.0828 - val_mean_absolute_error: 0.0828 - lr: 0.0099 - 187ms/epoch - 187ms/step
# Epoch 34/1000
# 1/1 - 0s - loss: 0.0510 - mean_absolute_error: 0.0510 - val_loss: 0.0668 - val_mean_absolute_error: 0.0668 - lr: 0.0099 - 189ms/epoch - 189ms/step
# Epoch 35/1000
# 1/1 - 0s - loss: 0.0574 - mean_absolute_error: 0.0574 - val_loss: 0.0882 - val_mean_absolute_error: 0.0882 - lr: 0.0099 - 170ms/epoch - 170ms/step
# Epoch 36/1000
# 1/1 - 0s - loss: 0.0558 - mean_absolute_error: 0.0558 - val_loss: 0.0836 - val_mean_absolute_error: 0.0836 - lr: 0.0099 - 158ms/epoch - 158ms/step
# Epoch 37/1000
# 1/1 - 0s - loss: 0.0514 - mean_absolute_error: 0.0514 - val_loss: 0.0726 - val_mean_absolute_error: 0.0726 - lr: 0.0099 - 178ms/epoch - 178ms/step
# Epoch 38/1000
# 1/1 - 0s - loss: 0.0579 - mean_absolute_error: 0.0579 - val_loss: 0.0715 - val_mean_absolute_error: 0.0715 - lr: 0.0099 - 177ms/epoch - 177ms/step
# Epoch 39/1000
# 1/1 - 0s - loss: 0.0441 - mean_absolute_error: 0.0441 - val_loss: 0.0811 - val_mean_absolute_error: 0.0811 - lr: 0.0099 - 177ms/epoch - 177ms/step
# Epoch 40/1000
# 1/1 - 0s - loss: 0.0490 - mean_absolute_error: 0.0490 - val_loss: 0.0707 - val_mean_absolute_error: 0.0707 - lr: 0.0099 - 155ms/epoch - 155ms/step
# Epoch 41/1000
# 1/1 - 0s - loss: 0.0431 - mean_absolute_error: 0.0431 - val_loss: 0.0565 - val_mean_absolute_error: 0.0565 - lr: 0.0099 - 160ms/epoch - 160ms/step
# Epoch 42/1000
# 1/1 - 0s - loss: 0.0475 - mean_absolute_error: 0.0475 - val_loss: 0.0589 - val_mean_absolute_error: 0.0589 - lr: 0.0099 - 180ms/epoch - 180ms/step
# Epoch 43/1000
# 1/1 - 0s - loss: 0.0449 - mean_absolute_error: 0.0449 - val_loss: 0.0746 - val_mean_absolute_error: 0.0746 - lr: 0.0099 - 158ms/epoch - 158ms/step
# Epoch 44/1000
# 1/1 - 0s - loss: 0.0445 - mean_absolute_error: 0.0445 - val_loss: 0.0729 - val_mean_absolute_error: 0.0729 - lr: 0.0099 - 180ms/epoch - 180ms/step
# Epoch 45/1000
# 1/1 - 0s - loss: 0.0430 - mean_absolute_error: 0.0430 - val_loss: 0.0622 - val_mean_absolute_error: 0.0622 - lr: 0.0099 - 159ms/epoch - 159ms/step
# Epoch 46/1000
# 1/1 - 0s - loss: 0.0420 - mean_absolute_error: 0.0420 - val_loss: 0.0609 - val_mean_absolute_error: 0.0609 - lr: 0.0099 - 159ms/epoch - 159ms/step
# Epoch 47/1000
# 1/1 - 0s - loss: 0.0436 - mean_absolute_error: 0.0436 - val_loss: 0.0658 - val_mean_absolute_error: 0.0658 - lr: 0.0099 - 158ms/epoch - 158ms/step
# Epoch 48/1000
# 1/1 - 0s - loss: 0.0398 - mean_absolute_error: 0.0398 - val_loss: 0.0708 - val_mean_absolute_error: 0.0708 - lr: 0.0099 - 181ms/epoch - 181ms/step
# Epoch 49/1000
# 1/1 - 0s - loss: 0.0417 - mean_absolute_error: 0.0417 - val_loss: 0.0622 - val_mean_absolute_error: 0.0622 - lr: 0.0099 - 180ms/epoch - 180ms/step
# Epoch 50/1000
# 1/1 - 0s - loss: 0.0387 - mean_absolute_error: 0.0387 - val_loss: 0.0540 - val_mean_absolute_error: 0.0540 - lr: 0.0099 - 159ms/epoch - 159ms/step
# Epoch 51/1000
# 1/1 - 0s - loss: 0.0395 - mean_absolute_error: 0.0395 - val_loss: 0.0534 - val_mean_absolute_error: 0.0534 - lr: 0.0099 - 181ms/epoch - 181ms/step
# Epoch 52/1000
# 1/1 - 0s - loss: 0.0388 - mean_absolute_error: 0.0388 - val_loss: 0.0589 - val_mean_absolute_error: 0.0589 - lr: 0.0099 - 178ms/epoch - 178ms/step
# Epoch 53/1000
# 1/1 - 0s - loss: 0.0368 - mean_absolute_error: 0.0368 - val_loss: 0.0630 - val_mean_absolute_error: 0.0630 - lr: 0.0099 - 178ms/epoch - 178ms/step
# Epoch 54/1000
# 1/1 - 0s - loss: 0.0370 - mean_absolute_error: 0.0370 - val_loss: 0.0597 - val_mean_absolute_error: 0.0597 - lr: 0.0099 - 184ms/epoch - 184ms/step
# Epoch 55/1000
# 1/1 - 0s - loss: 0.0364 - mean_absolute_error: 0.0364 - val_loss: 0.0565 - val_mean_absolute_error: 0.0565 - lr: 0.0099 - 176ms/epoch - 176ms/step
# Epoch 56/1000
# 1/1 - 0s - loss: 0.0349 - mean_absolute_error: 0.0349 - val_loss: 0.0558 - val_mean_absolute_error: 0.0558 - lr: 0.0099 - 155ms/epoch - 155ms/step
# Epoch 57/1000
# 1/1 - 0s - loss: 0.0348 - mean_absolute_error: 0.0348 - val_loss: 0.0531 - val_mean_absolute_error: 0.0531 - lr: 0.0099 - 159ms/epoch - 159ms/step
# Epoch 58/1000
# 1/1 - 0s - loss: 0.0335 - mean_absolute_error: 0.0335 - val_loss: 0.0534 - val_mean_absolute_error: 0.0534 - lr: 0.0099 - 181ms/epoch - 181ms/step
# Epoch 59/1000
# 1/1 - 0s - loss: 0.0329 - mean_absolute_error: 0.0329 - val_loss: 0.0586 - val_mean_absolute_error: 0.0586 - lr: 0.0099 - 156ms/epoch - 156ms/step
# Epoch 60/1000
# 1/1 - 0s - loss: 0.0320 - mean_absolute_error: 0.0320 - val_loss: 0.0562 - val_mean_absolute_error: 0.0562 - lr: 0.0099 - 162ms/epoch - 162ms/step
# Epoch 61/1000
# 1/1 - 0s - loss: 0.0307 - mean_absolute_error: 0.0307 - val_loss: 0.0510 - val_mean_absolute_error: 0.0510 - lr: 0.0099 - 159ms/epoch - 159ms/step
# Epoch 62/1000
# 1/1 - 0s - loss: 0.0312 - mean_absolute_error: 0.0312 - val_loss: 0.0683 - val_mean_absolute_error: 0.0683 - lr: 0.0099 - 178ms/epoch - 178ms/step
# Epoch 63/1000
# 1/1 - 0s - loss: 0.0409 - mean_absolute_error: 0.0409 - val_loss: 0.0544 - val_mean_absolute_error: 0.0544 - lr: 0.0099 - 179ms/epoch - 179ms/step
# Epoch 64/1000
# 1/1 - 0s - loss: 0.0326 - mean_absolute_error: 0.0326 - val_loss: 0.0579 - val_mean_absolute_error: 0.0579 - lr: 0.0099 - 180ms/epoch - 180ms/step
# Epoch 65/1000
# 1/1 - 0s - loss: 0.0321 - mean_absolute_error: 0.0321 - val_loss: 0.0558 - val_mean_absolute_error: 0.0558 - lr: 0.0099 - 157ms/epoch - 157ms/step
# Epoch 66/1000
# 1/1 - 0s - loss: 0.0317 - mean_absolute_error: 0.0317 - val_loss: 0.0546 - val_mean_absolute_error: 0.0546 - lr: 0.0099 - 161ms/epoch - 161ms/step
# Epoch 67/1000
# 1/1 - 0s - loss: 0.0322 - mean_absolute_error: 0.0322 - val_loss: 0.0599 - val_mean_absolute_error: 0.0599 - lr: 0.0099 - 185ms/epoch - 185ms/step
# Epoch 68/1000
# 1/1 - 0s - loss: 0.0309 - mean_absolute_error: 0.0309 - val_loss: 0.0508 - val_mean_absolute_error: 0.0508 - lr: 0.0099 - 158ms/epoch - 158ms/step
# Epoch 69/1000
# 1/1 - 0s - loss: 0.0345 - mean_absolute_error: 0.0345 - val_loss: 0.0660 - val_mean_absolute_error: 0.0660 - lr: 0.0099 - 159ms/epoch - 159ms/step
# Epoch 70/1000
# 1/1 - 0s - loss: 0.0345 - mean_absolute_error: 0.0345 - val_loss: 0.0517 - val_mean_absolute_error: 0.0517 - lr: 0.0099 - 178ms/epoch - 178ms/step
# Epoch 71/1000
# 1/1 - 0s - loss: 0.0284 - mean_absolute_error: 0.0284 - val_loss: 0.0453 - val_mean_absolute_error: 0.0453 - lr: 0.0099 - 159ms/epoch - 159ms/step
# Epoch 72/1000
# 1/1 - 0s - loss: 0.0321 - mean_absolute_error: 0.0321 - val_loss: 0.0704 - val_mean_absolute_error: 0.0704 - lr: 0.0099 - 180ms/epoch - 180ms/step
# Epoch 73/1000
# 1/1 - 0s - loss: 0.0371 - mean_absolute_error: 0.0371 - val_loss: 0.0559 - val_mean_absolute_error: 0.0559 - lr: 0.0099 - 158ms/epoch - 158ms/step
# Epoch 74/1000
# 1/1 - 0s - loss: 0.0280 - mean_absolute_error: 0.0280 - val_loss: 0.0470 - val_mean_absolute_error: 0.0470 - lr: 0.0099 - 161ms/epoch - 161ms/step
# Epoch 75/1000
# 1/1 - 0s - loss: 0.0377 - mean_absolute_error: 0.0377 - val_loss: 0.0605 - val_mean_absolute_error: 0.0605 - lr: 0.0099 - 180ms/epoch - 180ms/step
# Epoch 76/1000
# 1/1 - 0s - loss: 0.0303 - mean_absolute_error: 0.0303 - val_loss: 0.0629 - val_mean_absolute_error: 0.0629 - lr: 0.0099 - 179ms/epoch - 179ms/step
# Epoch 77/1000
# 1/1 - 0s - loss: 0.0320 - mean_absolute_error: 0.0320 - val_loss: 0.0489 - val_mean_absolute_error: 0.0489 - lr: 0.0099 - 178ms/epoch - 178ms/step
# Epoch 78/1000
# 1/1 - 0s - loss: 0.0304 - mean_absolute_error: 0.0304 - val_loss: 0.0468 - val_mean_absolute_error: 0.0468 - lr: 0.0099 - 183ms/epoch - 183ms/step
# Epoch 79/1000
# 1/1 - 0s - loss: 0.0304 - mean_absolute_error: 0.0304 - val_loss: 0.0599 - val_mean_absolute_error: 0.0599 - lr: 0.0099 - 160ms/epoch - 160ms/step
# Epoch 80/1000
# 1/1 - 0s - loss: 0.0297 - mean_absolute_error: 0.0297 - val_loss: 0.0605 - val_mean_absolute_error: 0.0605 - lr: 0.0099 - 158ms/epoch - 158ms/step
# Epoch 81/1000
# 1/1 - 0s - loss: 0.0291 - mean_absolute_error: 0.0291 - val_loss: 0.0548 - val_mean_absolute_error: 0.0548 - lr: 0.0099 - 182ms/epoch - 182ms/step
# Epoch 82/1000
# 1/1 - 0s - loss: 0.0291 - mean_absolute_error: 0.0291 - val_loss: 0.0515 - val_mean_absolute_error: 0.0515 - lr: 0.0099 - 179ms/epoch - 179ms/step
# Epoch 83/1000
# 1/1 - 0s - loss: 0.0275 - mean_absolute_error: 0.0275 - val_loss: 0.0558 - val_mean_absolute_error: 0.0558 - lr: 0.0099 - 179ms/epoch - 179ms/step
# Epoch 84/1000
# 1/1 - 0s - loss: 0.0270 - mean_absolute_error: 0.0270 - val_loss: 0.0573 - val_mean_absolute_error: 0.0573 - lr: 0.0099 - 179ms/epoch - 179ms/step
# Epoch 85/1000
# 1/1 - 0s - loss: 0.0264 - mean_absolute_error: 0.0264 - val_loss: 0.0584 - val_mean_absolute_error: 0.0584 - lr: 0.0099 - 159ms/epoch - 159ms/step
# Epoch 86/1000
# 1/1 - 0s - loss: 0.0270 - mean_absolute_error: 0.0270 - val_loss: 0.0575 - val_mean_absolute_error: 0.0575 - lr: 0.0099 - 166ms/epoch - 166ms/step
# Epoch 87/1000
# 1/1 - 0s - loss: 0.0262 - mean_absolute_error: 0.0262 - val_loss: 0.0555 - val_mean_absolute_error: 0.0555 - lr: 0.0099 - 181ms/epoch - 181ms/step
# Epoch 88/1000
# 1/1 - 0s - loss: 0.0268 - mean_absolute_error: 0.0268 - val_loss: 0.0550 - val_mean_absolute_error: 0.0550 - lr: 0.0099 - 162ms/epoch - 162ms/step
# Epoch 89/1000
# 1/1 - 0s - loss: 0.0259 - mean_absolute_error: 0.0259 - val_loss: 0.0580 - val_mean_absolute_error: 0.0580 - lr: 0.0099 - 180ms/epoch - 180ms/step
# Epoch 90/1000
# 1/1 - 0s - loss: 0.0260 - mean_absolute_error: 0.0260 - val_loss: 0.0560 - val_mean_absolute_error: 0.0560 - lr: 0.0099 - 181ms/epoch - 181ms/step
# Epoch 91/1000
# 1/1 - 0s - loss: 0.0259 - mean_absolute_error: 0.0259 - val_loss: 0.0542 - val_mean_absolute_error: 0.0542 - lr: 0.0099 - 160ms/epoch - 160ms/step
# Epoch 92/1000
# 1/1 - 0s - loss: 0.0254 - mean_absolute_error: 0.0254 - val_loss: 0.0551 - val_mean_absolute_error: 0.0551 - lr: 0.0099 - 168ms/epoch - 168ms/step
# Epoch 93/1000
# 1/1 - 0s - loss: 0.0257 - mean_absolute_error: 0.0257 - val_loss: 0.0555 - val_mean_absolute_error: 0.0555 - lr: 0.0099 - 169ms/epoch - 169ms/step
# Epoch 94/1000
# 1/1 - 0s - loss: 0.0252 - mean_absolute_error: 0.0252 - val_loss: 0.0550 - val_mean_absolute_error: 0.0550 - lr: 0.0099 - 191ms/epoch - 191ms/step
# Epoch 95/1000
# 1/1 - 0s - loss: 0.0254 - mean_absolute_error: 0.0254 - val_loss: 0.0556 - val_mean_absolute_error: 0.0556 - lr: 0.0099 - 168ms/epoch - 168ms/step
# Epoch 96/1000
# 1/1 - 0s - loss: 0.0249 - mean_absolute_error: 0.0249 - val_loss: 0.0545 - val_mean_absolute_error: 0.0545 - lr: 0.0098 - 189ms/epoch - 189ms/step
# Epoch 97/1000
# 1/1 - 0s - loss: 0.0252 - mean_absolute_error: 0.0252 - val_loss: 0.0562 - val_mean_absolute_error: 0.0562 - lr: 0.0098 - 190ms/epoch - 190ms/step
# Epoch 98/1000
# 1/1 - 0s - loss: 0.0247 - mean_absolute_error: 0.0247 - val_loss: 0.0543 - val_mean_absolute_error: 0.0543 - lr: 0.0098 - 190ms/epoch - 190ms/step
# Epoch 99/1000
# 1/1 - 0s - loss: 0.0250 - mean_absolute_error: 0.0250 - val_loss: 0.0585 - val_mean_absolute_error: 0.0585 - lr: 0.0098 - 187ms/epoch - 187ms/step
# Epoch 100/1000
# 1/1 - 0s - loss: 0.0249 - mean_absolute_error: 0.0249 - val_loss: 0.0530 - val_mean_absolute_error: 0.0530 - lr: 0.0098 - 195ms/epoch - 195ms/step
# Epoch 101/1000
# 1/1 - 0s - loss: 0.0252 - mean_absolute_error: 0.0252 - val_loss: 0.0580 - val_mean_absolute_error: 0.0580 - lr: 0.0098 - 194ms/epoch - 194ms/step
# Epoch 102/1000
# 1/1 - 0s - loss: 0.0246 - mean_absolute_error: 0.0246 - val_loss: 0.0526 - val_mean_absolute_error: 0.0526 - lr: 0.0098 - 188ms/epoch - 188ms/step
# Epoch 103/1000
# 1/1 - 0s - loss: 0.0257 - mean_absolute_error: 0.0257 - val_loss: 0.0658 - val_mean_absolute_error: 0.0658 - lr: 0.0098 - 188ms/epoch - 188ms/step
# Epoch 104/1000
# 1/1 - 0s - loss: 0.0291 - mean_absolute_error: 0.0291 - val_loss: 0.0464 - val_mean_absolute_error: 0.0464 - lr: 0.0098 - 167ms/epoch - 167ms/step
# Epoch 105/1000
# 1/1 - 0s - loss: 0.0329 - mean_absolute_error: 0.0329 - val_loss: 0.0678 - val_mean_absolute_error: 0.0678 - lr: 0.0098 - 182ms/epoch - 182ms/step
# Epoch 106/1000
# 1/1 - 0s - loss: 0.0312 - mean_absolute_error: 0.0312 - val_loss: 0.0578 - val_mean_absolute_error: 0.0578 - lr: 0.0098 - 190ms/epoch - 190ms/step
# Epoch 107/1000
# 1/1 - 0s - loss: 0.0269 - mean_absolute_error: 0.0269 - val_loss: 0.0468 - val_mean_absolute_error: 0.0468 - lr: 0.0098 - 189ms/epoch - 189ms/step
# Epoch 108/1000
# 1/1 - 0s - loss: 0.0357 - mean_absolute_error: 0.0357 - val_loss: 0.0616 - val_mean_absolute_error: 0.0616 - lr: 0.0098 - 189ms/epoch - 189ms/step
# Epoch 109/1000
# 1/1 - 0s - loss: 0.0284 - mean_absolute_error: 0.0284 - val_loss: 0.0663 - val_mean_absolute_error: 0.0663 - lr: 0.0098 - 185ms/epoch - 185ms/step
# Epoch 110/1000
# 1/1 - 0s - loss: 0.0317 - mean_absolute_error: 0.0317 - val_loss: 0.0463 - val_mean_absolute_error: 0.0463 - lr: 0.0098 - 183ms/epoch - 183ms/step
# Epoch 111/1000
# 1/1 - 0s - loss: 0.0280 - mean_absolute_error: 0.0280 - val_loss: 0.0469 - val_mean_absolute_error: 0.0469 - lr: 0.0098 - 181ms/epoch - 181ms/step
# Epoch 112/1000
# 1/1 - 0s - loss: 0.0296 - mean_absolute_error: 0.0296 - val_loss: 0.0604 - val_mean_absolute_error: 0.0604 - lr: 0.0098 - 160ms/epoch - 160ms/step
# Epoch 113/1000
# 1/1 - 0s - loss: 0.0277 - mean_absolute_error: 0.0277 - val_loss: 0.0615 - val_mean_absolute_error: 0.0615 - lr: 0.0098 - 180ms/epoch - 180ms/step
# Epoch 114/1000
# 1/1 - 0s - loss: 0.0280 - mean_absolute_error: 0.0280 - val_loss: 0.0511 - val_mean_absolute_error: 0.0511 - lr: 0.0098 - 180ms/epoch - 180ms/step
# Epoch 115/1000
# 1/1 - 0s - loss: 0.0282 - mean_absolute_error: 0.0282 - val_loss: 0.0494 - val_mean_absolute_error: 0.0494 - lr: 0.0098 - 181ms/epoch - 181ms/step
# Epoch 116/1000
# 1/1 - 0s - loss: 0.0260 - mean_absolute_error: 0.0260 - val_loss: 0.0564 - val_mean_absolute_error: 0.0564 - lr: 0.0098 - 182ms/epoch - 182ms/step
# Epoch 117/1000
# 1/1 - 0s - loss: 0.0272 - mean_absolute_error: 0.0272 - val_loss: 0.0591 - val_mean_absolute_error: 0.0591 - lr: 0.0098 - 160ms/epoch - 160ms/step
# Epoch 118/1000
# 1/1 - 0s - loss: 0.0269 - mean_absolute_error: 0.0269 - val_loss: 0.0539 - val_mean_absolute_error: 0.0539 - lr: 0.0098 - 183ms/epoch - 183ms/step
# Epoch 119/1000
# 1/1 - 0s - loss: 0.0273 - mean_absolute_error: 0.0273 - val_loss: 0.0545 - val_mean_absolute_error: 0.0545 - lr: 0.0098 - 182ms/epoch - 182ms/step
# Epoch 120/1000
# 1/1 - 0s - loss: 0.0268 - mean_absolute_error: 0.0268 - val_loss: 0.0586 - val_mean_absolute_error: 0.0586 - lr: 0.0098 - 182ms/epoch - 182ms/step
# Epoch 121/1000
# 1/1 - 0s - loss: 0.0268 - mean_absolute_error: 0.0268 - val_loss: 0.0533 - val_mean_absolute_error: 0.0533 - lr: 0.0098 - 160ms/epoch - 160ms/step
# Epoch 122/1000
# 1/1 - 0s - loss: 0.0263 - mean_absolute_error: 0.0263 - val_loss: 0.0507 - val_mean_absolute_error: 0.0507 - lr: 0.0098 - 182ms/epoch - 182ms/step
# Epoch 123/1000
# 1/1 - 0s - loss: 0.0259 - mean_absolute_error: 0.0259 - val_loss: 0.0565 - val_mean_absolute_error: 0.0565 - lr: 0.0098 - 183ms/epoch - 183ms/step
# Epoch 124/1000
# 1/1 - 0s - loss: 0.0257 - mean_absolute_error: 0.0257 - val_loss: 0.0569 - val_mean_absolute_error: 0.0569 - lr: 0.0098 - 180ms/epoch - 180ms/step
# Epoch 125/1000
# 1/1 - 0s - loss: 0.0251 - mean_absolute_error: 0.0251 - val_loss: 0.0517 - val_mean_absolute_error: 0.0517 - lr: 0.0098 - 180ms/epoch - 180ms/step
# Epoch 126/1000
# 1/1 - 0s - loss: 0.0251 - mean_absolute_error: 0.0251 - val_loss: 0.0498 - val_mean_absolute_error: 0.0498 - lr: 0.0098 - 160ms/epoch - 160ms/step
# Epoch 127/1000
# 1/1 - 0s - loss: 0.0262 - mean_absolute_error: 0.0262 - val_loss: 0.0553 - val_mean_absolute_error: 0.0553 - lr: 0.0098 - 164ms/epoch - 164ms/step
# Epoch 128/1000
# 1/1 - 0s - loss: 0.0250 - mean_absolute_error: 0.0250 - val_loss: 0.0574 - val_mean_absolute_error: 0.0574 - lr: 0.0098 - 183ms/epoch - 183ms/step
# Epoch 129/1000
# 1/1 - 0s - loss: 0.0263 - mean_absolute_error: 0.0263 - val_loss: 0.0539 - val_mean_absolute_error: 0.0539 - lr: 0.0098 - 160ms/epoch - 160ms/step
# Epoch 130/1000
# 1/1 - 0s - loss: 0.0249 - mean_absolute_error: 0.0249 - val_loss: 0.0499 - val_mean_absolute_error: 0.0499 - lr: 0.0098 - 161ms/epoch - 161ms/step
# Epoch 131/1000
# 1/1 - 0s - loss: 0.0250 - mean_absolute_error: 0.0250 - val_loss: 0.0573 - val_mean_absolute_error: 0.0573 - lr: 0.0098 - 162ms/epoch - 162ms/step
# Epoch 132/1000
# 1/1 - 0s - loss: 0.0262 - mean_absolute_error: 0.0262 - val_loss: 0.0536 - val_mean_absolute_error: 0.0536 - lr: 0.0098 - 161ms/epoch - 161ms/step
# Epoch 133/1000
# 1/1 - 0s - loss: 0.0243 - mean_absolute_error: 0.0243 - val_loss: 0.0516 - val_mean_absolute_error: 0.0516 - lr: 0.0098 - 185ms/epoch - 185ms/step
# Epoch 134/1000
# 1/1 - 0s - loss: 0.0245 - mean_absolute_error: 0.0245 - val_loss: 0.0574 - val_mean_absolute_error: 0.0574 - lr: 0.0098 - 160ms/epoch - 160ms/step
# Epoch 135/1000
# 1/1 - 0s - loss: 0.0247 - mean_absolute_error: 0.0247 - val_loss: 0.0554 - val_mean_absolute_error: 0.0554 - lr: 0.0098 - 162ms/epoch - 162ms/step
# Epoch 136/1000
# 1/1 - 0s - loss: 0.0241 - mean_absolute_error: 0.0241 - val_loss: 0.0491 - val_mean_absolute_error: 0.0491 - lr: 0.0098 - 163ms/epoch - 163ms/step
# Epoch 137/1000
# 1/1 - 0s - loss: 0.0255 - mean_absolute_error: 0.0255 - val_loss: 0.0565 - val_mean_absolute_error: 0.0565 - lr: 0.0098 - 181ms/epoch - 181ms/step
# Epoch 138/1000
# 1/1 - 0s - loss: 0.0242 - mean_absolute_error: 0.0242 - val_loss: 0.0568 - val_mean_absolute_error: 0.0568 - lr: 0.0098 - 161ms/epoch - 161ms/step
# Epoch 139/1000
# 1/1 - 0s - loss: 0.0243 - mean_absolute_error: 0.0243 - val_loss: 0.0489 - val_mean_absolute_error: 0.0489 - lr: 0.0098 - 181ms/epoch - 181ms/step
# Epoch 140/1000
# 1/1 - 0s - loss: 0.0254 - mean_absolute_error: 0.0254 - val_loss: 0.0585 - val_mean_absolute_error: 0.0585 - lr: 0.0098 - 161ms/epoch - 161ms/step
# Epoch 141/1000
# 1/1 - 0s - loss: 0.0249 - mean_absolute_error: 0.0249 - val_loss: 0.0545 - val_mean_absolute_error: 0.0545 - lr: 0.0098 - 184ms/epoch - 184ms/step
# Epoch 142/1000
# 1/1 - 0s - loss: 0.0246 - mean_absolute_error: 0.0246 - val_loss: 0.0496 - val_mean_absolute_error: 0.0496 - lr: 0.0098 - 180ms/epoch - 180ms/step
# Epoch 143/1000
# 1/1 - 0s - loss: 0.0254 - mean_absolute_error: 0.0254 - val_loss: 0.0579 - val_mean_absolute_error: 0.0579 - lr: 0.0098 - 165ms/epoch - 165ms/step
# Epoch 144/1000
# 1/1 - 0s - loss: 0.0252 - mean_absolute_error: 0.0252 - val_loss: 0.0581 - val_mean_absolute_error: 0.0581 - lr: 0.0098 - 186ms/epoch - 186ms/step
# Epoch 145/1000
# 1/1 - 0s - loss: 0.0247 - mean_absolute_error: 0.0247 - val_loss: 0.0468 - val_mean_absolute_error: 0.0468 - lr: 0.0098 - 180ms/epoch - 180ms/step
# Epoch 146/1000
# 1/1 - 0s - loss: 0.0268 - mean_absolute_error: 0.0268 - val_loss: 0.0621 - val_mean_absolute_error: 0.0621 - lr: 0.0098 - 180ms/epoch - 180ms/step
# Epoch 147/1000
# 1/1 - 0s - loss: 0.0270 - mean_absolute_error: 0.0270 - val_loss: 0.0563 - val_mean_absolute_error: 0.0563 - lr: 0.0098 - 180ms/epoch - 180ms/step
# Epoch 148/1000
# 1/1 - 0s - loss: 0.0255 - mean_absolute_error: 0.0255 - val_loss: 0.0467 - val_mean_absolute_error: 0.0467 - lr: 0.0098 - 159ms/epoch - 159ms/step
# Epoch 149/1000
# 1/1 - 0s - loss: 0.0268 - mean_absolute_error: 0.0268 - val_loss: 0.0659 - val_mean_absolute_error: 0.0659 - lr: 0.0098 - 164ms/epoch - 164ms/step
# Epoch 150/1000
# 1/1 - 0s - loss: 0.0306 - mean_absolute_error: 0.0306 - val_loss: 0.0581 - val_mean_absolute_error: 0.0581 - lr: 0.0098 - 184ms/epoch - 184ms/step
# Epoch 151/1000
# 1/1 - 0s - loss: 0.0258 - mean_absolute_error: 0.0258 - val_loss: 0.0491 - val_mean_absolute_error: 0.0491 - lr: 0.0098 - 179ms/epoch - 179ms/step
# Epoch 152/1000
# 1/1 - 0s - loss: 0.0307 - mean_absolute_error: 0.0307 - val_loss: 0.0582 - val_mean_absolute_error: 0.0582 - lr: 0.0098 - 158ms/epoch - 158ms/step
# Epoch 153/1000
# 1/1 - 0s - loss: 0.0256 - mean_absolute_error: 0.0256 - val_loss: 0.0594 - val_mean_absolute_error: 0.0594 - lr: 0.0098 - 165ms/epoch - 165ms/step
# Epoch 154/1000
# 1/1 - 0s - loss: 0.0279 - mean_absolute_error: 0.0279 - val_loss: 0.0494 - val_mean_absolute_error: 0.0494 - lr: 0.0098 - 184ms/epoch - 184ms/step
# Epoch 155/1000
# 1/1 - 0s - loss: 0.0255 - mean_absolute_error: 0.0255 - val_loss: 0.0519 - val_mean_absolute_error: 0.0519 - lr: 0.0098 - 181ms/epoch - 181ms/step
# Epoch 156/1000
# 1/1 - 0s - loss: 0.0265 - mean_absolute_error: 0.0265 - val_loss: 0.0621 - val_mean_absolute_error: 0.0621 - lr: 0.0098 - 179ms/epoch - 179ms/step
# Epoch 157/1000
# 1/1 - 0s - loss: 0.0270 - mean_absolute_error: 0.0270 - val_loss: 0.0571 - val_mean_absolute_error: 0.0571 - lr: 0.0098 - 161ms/epoch - 161ms/step
# Epoch 158/1000
# 1/1 - 0s - loss: 0.0253 - mean_absolute_error: 0.0253 - val_loss: 0.0470 - val_mean_absolute_error: 0.0470 - lr: 0.0098 - 163ms/epoch - 163ms/step
# Epoch 159/1000
# 1/1 - 0s - loss: 0.0275 - mean_absolute_error: 0.0275 - val_loss: 0.0572 - val_mean_absolute_error: 0.0572 - lr: 0.0098 - 186ms/epoch - 186ms/step
# Epoch 160/1000
# 1/1 - 0s - loss: 0.0251 - mean_absolute_error: 0.0251 - val_loss: 0.0597 - val_mean_absolute_error: 0.0597 - lr: 0.0097 - 180ms/epoch - 180ms/step
# Epoch 161/1000
# 1/1 - 0s - loss: 0.0256 - mean_absolute_error: 0.0256 - val_loss: 0.0500 - val_mean_absolute_error: 0.0500 - lr: 0.0097 - 161ms/epoch - 161ms/step
# Epoch 162/1000
# 1/1 - 0s - loss: 0.0268 - mean_absolute_error: 0.0268 - val_loss: 0.0568 - val_mean_absolute_error: 0.0568 - lr: 0.0097 - 182ms/epoch - 182ms/step
# Epoch 163/1000
# 1/1 - 0s - loss: 0.0246 - mean_absolute_error: 0.0246 - val_loss: 0.0579 - val_mean_absolute_error: 0.0579 - lr: 0.0097 - 179ms/epoch - 179ms/step
# Epoch 164/1000
# 1/1 - 0s - loss: 0.0248 - mean_absolute_error: 0.0248 - val_loss: 0.0488 - val_mean_absolute_error: 0.0488 - lr: 0.0097 - 181ms/epoch - 181ms/step
# Epoch 165/1000
# 1/1 - 0s - loss: 0.0265 - mean_absolute_error: 0.0265 - val_loss: 0.0574 - val_mean_absolute_error: 0.0574 - lr: 0.0097 - 193ms/epoch - 193ms/step
# Epoch 166/1000
# 1/1 - 0s - loss: 0.0252 - mean_absolute_error: 0.0252 - val_loss: 0.0580 - val_mean_absolute_error: 0.0580 - lr: 0.0097 - 185ms/epoch - 185ms/step
# Epoch 167/1000
# 1/1 - 0s - loss: 0.0247 - mean_absolute_error: 0.0247 - val_loss: 0.0523 - val_mean_absolute_error: 0.0523 - lr: 0.0097 - 189ms/epoch - 189ms/step
# Epoch 168/1000
# 1/1 - 0s - loss: 0.0257 - mean_absolute_error: 0.0257 - val_loss: 0.0545 - val_mean_absolute_error: 0.0545 - lr: 0.0097 - 191ms/epoch - 191ms/step
# Epoch 169/1000
# 1/1 - 0s - loss: 0.0239 - mean_absolute_error: 0.0239 - val_loss: 0.0575 - val_mean_absolute_error: 0.0575 - lr: 0.0097 - 170ms/epoch - 170ms/step
# Epoch 170/1000
# 1/1 - 0s - loss: 0.0240 - mean_absolute_error: 0.0240 - val_loss: 0.0514 - val_mean_absolute_error: 0.0514 - lr: 0.0097 - 190ms/epoch - 190ms/step
# Epoch 171/1000
# Restoring model weights from the end of the best epoch: 71.
# 1/1 - 0s - loss: 0.0254 - mean_absolute_error: 0.0254 - val_loss: 0.0597 - val_mean_absolute_error: 0.0597 - lr: 0.0097 - 203ms/epoch - 203ms/step
# Epoch 171: early stopping

# %%
# Loss Curve
import matplotlib.pyplot as plt
from matplotlib import pyplot
pyplot.plot(history.history['loss'][:], label='train')
pyplot.plot(history.history['val_loss'][:], label='test')
pyplot.legend()
pyplot.show()

# %%
# prediction
yhat_test = model.predict(X_test)
yhat_train = model.predict(X_train)
# Out:
# 35/35 [==============================] - 1s 9ms/step
# 35/35 [==============================] - 0s 6ms/step

# %%
#Evaluating the perfomance of the model for Training data set and Testing data set using Nash-Sutcliffe
def nse(predictions, targets):
    return (1-(np.sum((predictions-targets)**2)/np.sum((targets-np.mean(targets))**2)))
inv_yhat_train = inv_yhat(yhat_train)
inv_yhat_test = inv_yhat(yhat_test)
inv_y_train = inv_y(y_train)
inv_y_test = inv_y(y_test)
print("train",nse(np.array(inv_yhat_train),np.array(inv_y_train)))
print("test",nse(np.array(inv_yhat_test),np.array(inv_y_test)))
# Out:
# train 0.8949297242758092
# test 0.8332764624978158

# %%
#Training Plot
import matplotlib.pyplot as plt
plt.plot(inv_y_train[:])
plt.plot(inv_yhat_train[:])

# %%
#Testing plot
import matplotlib.pyplot as plt
plt.plot(inv_y_test[:])
plt.plot(inv_yhat_test[:])

# %%
import plotly.express as px
def reg_test_discharge_fig(inv_yhat_test,inv_y_test):
    reg_test_discharge_fig = px.scatter( x=inv_yhat_test, y=inv_y_test,
                                        trendline="ols",
                                        template = 'plotly_dark',
                                        title='Regression Plot between Observed and Simulated River Discharge')
    #reg_test_discharge_fig.update_layout(autosize=False,width=500,height=500)
    return reg_test_discharge_fig
reg_test_discharge_fig(inv_yhat_test,inv_y_test)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="e6325977-38e1-44a3-adad-0f5064eb5ef7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e6325977-38e1-44a3-adad-0f5064eb5ef7")) {                    Plotly.newPlot(                        "e6325977-38e1-44a3-adad-0f5064eb5ef7",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","showlegend":false,"x":[59.50031225942471,58.74874698424988,58.93355161687015,59.31163462422624,59.51415277998194,61.77467951340195,60.151769768133825,60.148610984181154,59.49955973885396,58.92927306428376,59.43769533816041,61.028638730560886,62.31959678190436,62.1780823596026,61.87047718450287,62.49682664159391,60.53902721789737,60.49675989482173,65.60365287904598,64.25800640909829,63.01058415113384,65.2458045640429,64.73439473843925,64.03901391078773,61.278166891432434,56.4648357867466,56.30575879603468,57.48923708298581,60.724838966371316,70.81955094630447,71.93478643215549,60.59218130563727,57.00873692717293,53.48958574334007,50.3005364947834,47.79301628804302,46.378572765317365,45.95797797835292,46.88156066908429,51.17747079582289,53.27305808785706,51.76422280072554,51.839472604744905,52.29615345674352,55.704722418621394,54.38086975550263,51.22787840878512,51.795200062184335,52.884606518624956,66.48780371717562,54.6237716798515,51.08484317395265,49.42255902900063,44.22298434957172,38.198754708006106,34.24482913178362,35.38613134441095,38.54305370988839,40.402262800066524,38.768610485692605,39.28997262114997,32.4198625438941,35.54387903231825,49.496761162165505,44.47851014445325,41.02547037112191,36.39194042583033,34.79653373028418,35.00280322361563,35.799611545051185,37.80988857654341,36.757965079609605,38.24644006653836,39.23918818463847,42.81038833243892,38.911507157605605,50.00876128833662,42.86411244324588,116.39149826366862,80.09446611524069,64.39648821856103,58.919422705195984,54.1216940105474,47.88083814231623,43.98290099777975,41.822791825970604,40.901591741537345,37.66199800689069,45.90690008134939,49.03025248163513,40.72133152206438,33.72008713129273,39.200014306903064,46.07588375753911,44.001750060938114,46.05199573552901,64.95708450099113,47.956844973017546,43.968048855257656,44.10258781741857,44.70008239142701,41.76194918599214,52.949967661611325,53.693144810783465,53.23673883156818,57.528507842112056,59.217301439266,58.22179107499901,48.32184899260955,37.890316465597884,36.93469532421963,37.53500847078498,35.93216443869978,33.914429511536134,36.24838755147352,39.53957963896755,54.08534997064691,51.260392254163825,65.98300210364985,57.90963923369636,66.44875601055388,63.789758369643906,67.18062507366436,60.811047632834175,61.69251958785417,56.24853568987929,52.8879432939701,85.85342042707514,73.80157367484775,66.65902693063278,69.55067058679566,63.68180771663094,58.88835757456875,54.56490159005175,56.681735196403785,59.574216989250246,47.45847358017716,48.690428611440424,52.916138031761605,65.08245127380019,71.6193000685633,74.8745012826223,63.62001991982783,59.50564974814359,61.570469312889855,68.67343437630562,73.19471765481696,74.31944301085959,65.75639878351896,77.80101773337819,69.00451188465708,55.10493648706669,62.63034496956755,66.72690248366992,56.9608887853735,58.94876650134402,53.417598363831026,50.35328277945951,90.7023024960899,124.82088222053274,169.16416171475555,192.336117593731,232.24501416397484,372.63474715858007,325.5494539367711,327.096492034674,534.9704313207397,520.0953256559525,504.0435121362952,596.9651847991408,618.3471871375309,591.5582839433035,562.5938663095949,620.860299428273,635.3692925701126,626.8714157229766,626.7326274979522,685.8758777587785,684.7707629986875,752.8947289341766,721.6980198598402,675 ...
