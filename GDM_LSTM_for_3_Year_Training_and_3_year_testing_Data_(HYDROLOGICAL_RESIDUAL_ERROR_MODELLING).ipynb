# %% [markdown]
# <a href="https://colab.research.google.com/github/DineshJoshi2/Hydrological-Residual-Error-Modelling/blob/main/GDM_LSTM_for_3_Year_Training_and_3_year_testing_Data_(HYDROLOGICAL_RESIDUAL_ERROR_MODELLING).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#For reproducibility of the code
import os
os.environ["PYTHONHASHSEED"] = "0"
import numpy as np
import random as rn
import tensorflow as tf
# setting the seed for numpy generated random numbers
np.random.seed(73)
# setting the seed for python random number
rn.seed(723)
# setting the seed for tensorflow random number
tf.random.set_seed(1)

# %%
# importing necessary libraries
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras import optimizers
from tensorflow.keras.layers import Dropout
from tensorflow.keras.constraints import MaxNorm
from sklearn.model_selection import GridSearchCV

# %%
# importing data sets
df= pd.read_csv("/content/drive/MyDrive/Data/FourYearResidualErrorModelling.csv")
df=df[365:].reset_index(drop=True)

# %%
# Retriving the necessary columns from the datasets.
 df=df[['Temperature (Deg C)', 'Precipitation (mm)',
       'Precipitation0816 (mm)', 'Temperature0816 (Deg C)', 'Residual Error']]

# %%
# Importing necessary libraries
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error

# %%
# extrating the vaules from the data frame
values = df.values
values
# change all datatype to float
values = values.astype('float32')

# %%
# normalization all features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)

# %%
#converting the data into 3D array
l=[]
for i in range(len(df)-365):
    l.append(scaled[i:366+i,:])
Data=np.array(l)

# %%
# checking the shape of the data
Data.shape
# Out:
# (2192, 366, 5)

# %%
# Test and Train data
X=Data[:,:,:-1]
y=Data[:,-1,-1]
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.50, shuffle =False)

# %%
# Checking Shape of test and Training Data
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1096, 366, 4)
# (1096, 366, 4)
# (1096,)
# (1096,)

# %%
# Useful functions to undo normalization later
def inv_yhat(yhat):
  yhat=[i[0] for i in yhat]
  A=np.zeros((len(yhat),5))
  A[:,0]=yhat
  A[:,1]=yhat
  A[:,2]=yhat
  A[:,3]=yhat
  A[:,4]=yhat
  inv_yhat= scaler.inverse_transform(A)
  inv_yhat = [i[-1] for i in inv_yhat]
  return inv_yhat
def inv_y(y):
  A=np.zeros((len(y),5))
  A[:,0]=y
  A[:,1]=y
  A[:,2]=y
  A[:,3]=y
  A[:,4]=y
  inv_y= scaler.inverse_transform(A)
  inv_y = [i[-1] for i in inv_y]
  return inv_y

# %%
# Import necessary libraries
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import GRU
from keras import optimizers
from tensorflow.keras.layers import Dropout
from tensorflow.keras.constraints import MaxNorm
from sklearn.model_selection import GridSearchCV

# %%
# Defining model parameters
epochs=1000
learning_rate1 = 0.01
decay_rate = (learning_rate1*128)/epochs

# %%
# For reproducibility of the code
import os
os.environ["PYTHONHASHSEED"] = "0"
import numpy as np
import random as rn
import tensorflow as tf
# setting the seed for numpy generated random numbers
np.random.seed(73)
# setting the seed for python random number
rn.seed(723)
# setting the seed for tensorflow random number
tf.random.set_seed(1)

# %%
# Building the Main model
model = Sequential()
model.add(LSTM(128,kernel_initializer="GlorotUniform",dropout=0.4,return_sequences=False,input_shape=(X_train.shape[1], X_train.shape[2]))) # main model
model.add(Dense(1))
Adam=tf.keras.optimizers.Adam(learning_rate = learning_rate1, beta_1 = 0.9, beta_2 = 0.999, amsgrad = False)
model.compile(loss="mae", optimizer=Adam, metrics=[tf.keras.metrics.MeanAbsoluteError()])

# %%
#Add Callbacks, e.g. ModelCheckpoints, earlystopping, csvlogger.
from keras.callbacks import ModelCheckpoint, EarlyStopping, CSVLogger,LearningRateScheduler

#ModelCheckpoint callback saves a model at some interval.
filepath="saved_models/weights-improvement-{epoch:02d}-{val_acc:.2f}.hdf5" #File name includes epoch and validation accuracy.
#Use Mode = max for accuracy and min for loss.
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

#https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/EarlyStopping
early_stop = EarlyStopping(monitor='val_loss',min_delta=0.0001, patience= 100,verbose=1,restore_best_weights=True)
#This callback will stop the training when there is no improvement in
# the validation loss for three consecutive epochs.

#CSVLogger logs epoch, acc, loss, val_acc, val_loss
log_csv = CSVLogger("/content/drive/MyDrive/Data/LSTMlogs.csv", separator=',', append=False)

#learning rate decay
def exp_decay(epoch):
  lrate = learning_rate1 * np.exp(-decay_rate*epoch)
  return lrate

# learning schedule callback
lr_rate = LearningRateScheduler(exp_decay)

callbacks_list = [early_stop]

# %%
# Training the model
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs =epochs ,callbacks=callbacks_list, batch_size=len(X_train), verbose = 2, shuffle = True)
# Out:
# Epoch 1/1000
# 1/1 - 2s - loss: 0.2714 - mean_absolute_error: 0.2714 - val_loss: 1.2178 - val_mean_absolute_error: 1.2178 - 2s/epoch - 2s/step
# Epoch 2/1000
# 1/1 - 0s - loss: 1.2944 - mean_absolute_error: 1.2944 - val_loss: 0.1228 - val_mean_absolute_error: 0.1228 - 206ms/epoch - 206ms/step
# Epoch 3/1000
# 1/1 - 0s - loss: 0.1388 - mean_absolute_error: 0.1388 - val_loss: 0.2210 - val_mean_absolute_error: 0.2210 - 144ms/epoch - 144ms/step
# Epoch 4/1000
# 1/1 - 0s - loss: 0.1970 - mean_absolute_error: 0.1970 - val_loss: 0.1942 - val_mean_absolute_error: 0.1942 - 168ms/epoch - 168ms/step
# Epoch 5/1000
# 1/1 - 0s - loss: 0.1697 - mean_absolute_error: 0.1697 - val_loss: 0.1165 - val_mean_absolute_error: 0.1165 - 162ms/epoch - 162ms/step
# Epoch 6/1000
# 1/1 - 0s - loss: 0.1123 - mean_absolute_error: 0.1123 - val_loss: 0.1174 - val_mean_absolute_error: 0.1174 - 139ms/epoch - 139ms/step
# Epoch 7/1000
# 1/1 - 0s - loss: 0.1321 - mean_absolute_error: 0.1321 - val_loss: 0.1243 - val_mean_absolute_error: 0.1243 - 139ms/epoch - 139ms/step
# Epoch 8/1000
# 1/1 - 0s - loss: 0.1394 - mean_absolute_error: 0.1394 - val_loss: 0.1042 - val_mean_absolute_error: 0.1042 - 166ms/epoch - 166ms/step
# Epoch 9/1000
# 1/1 - 0s - loss: 0.1116 - mean_absolute_error: 0.1116 - val_loss: 0.0961 - val_mean_absolute_error: 0.0961 - 164ms/epoch - 164ms/step
# Epoch 10/1000
# 1/1 - 0s - loss: 0.0973 - mean_absolute_error: 0.0973 - val_loss: 0.1090 - val_mean_absolute_error: 0.1090 - 164ms/epoch - 164ms/step
# Epoch 11/1000
# 1/1 - 0s - loss: 0.0960 - mean_absolute_error: 0.0960 - val_loss: 0.1194 - val_mean_absolute_error: 0.1194 - 163ms/epoch - 163ms/step
# Epoch 12/1000
# 1/1 - 0s - loss: 0.1007 - mean_absolute_error: 0.1007 - val_loss: 0.1161 - val_mean_absolute_error: 0.1161 - 178ms/epoch - 178ms/step
# Epoch 13/1000
# 1/1 - 0s - loss: 0.0974 - mean_absolute_error: 0.0974 - val_loss: 0.1019 - val_mean_absolute_error: 0.1019 - 141ms/epoch - 141ms/step
# Epoch 14/1000
# 1/1 - 0s - loss: 0.0837 - mean_absolute_error: 0.0837 - val_loss: 0.0861 - val_mean_absolute_error: 0.0861 - 144ms/epoch - 144ms/step
# Epoch 15/1000
# 1/1 - 0s - loss: 0.0747 - mean_absolute_error: 0.0747 - val_loss: 0.0780 - val_mean_absolute_error: 0.0780 - 165ms/epoch - 165ms/step
# Epoch 16/1000
# 1/1 - 0s - loss: 0.0713 - mean_absolute_error: 0.0713 - val_loss: 0.0757 - val_mean_absolute_error: 0.0757 - 169ms/epoch - 169ms/step
# Epoch 17/1000
# 1/1 - 0s - loss: 0.0760 - mean_absolute_error: 0.0760 - val_loss: 0.0738 - val_mean_absolute_error: 0.0738 - 164ms/epoch - 164ms/step
# Epoch 18/1000
# 1/1 - 0s - loss: 0.0745 - mean_absolute_error: 0.0745 - val_loss: 0.0700 - val_mean_absolute_error: 0.0700 - 169ms/epoch - 169ms/step
# Epoch 19/1000
# 1/1 - 0s - loss: 0.0670 - mean_absolute_error: 0.0670 - val_loss: 0.0683 - val_mean_absolute_error: 0.0683 - 165ms/epoch - 165ms/step
# Epoch 20/1000
# 1/1 - 0s - loss: 0.0588 - mean_absolute_error: 0.0588 - val_loss: 0.0714 - val_mean_absolute_error: 0.0714 - 166ms/epoch - 166ms/step
# Epoch 21/1000
# 1/1 - 0s - loss: 0.0555 - mean_absolute_error: 0.0555 - val_loss: 0.0755 - val_mean_absolute_error: 0.0755 - 161ms/epoch - 161ms/step
# Epoch 22/1000
# 1/1 - 0s - loss: 0.0552 - mean_absolute_error: 0.0552 - val_loss: 0.0753 - val_mean_absolute_error: 0.0753 - 143ms/epoch - 143ms/step
# Epoch 23/1000
# 1/1 - 0s - loss: 0.0543 - mean_absolute_error: 0.0543 - val_loss: 0.0686 - val_mean_absolute_error: 0.0686 - 137ms/epoch - 137ms/step
# Epoch 24/1000
# 1/1 - 0s - loss: 0.0500 - mean_absolute_error: 0.0500 - val_loss: 0.0601 - val_mean_absolute_error: 0.0601 - 142ms/epoch - 142ms/step
# Epoch 25/1000
# 1/1 - 0s - loss: 0.0458 - mean_absolute_error: 0.0458 - val_loss: 0.0587 - val_mean_absolute_error: 0.0587 - 140ms/epoch - 140ms/step
# Epoch 26/1000
# 1/1 - 0s - loss: 0.0490 - mean_absolute_error: 0.0490 - val_loss: 0.0593 - val_mean_absolute_error: 0.0593 - 142ms/epoch - 142ms/step
# Epoch 27/1000
# 1/1 - 0s - loss: 0.0486 - mean_absolute_error: 0.0486 - val_loss: 0.0579 - val_mean_absolute_error: 0.0579 - 167ms/epoch - 167ms/step
# Epoch 28/1000
# 1/1 - 0s - loss: 0.0444 - mean_absolute_error: 0.0444 - val_loss: 0.0632 - val_mean_absolute_error: 0.0632 - 141ms/epoch - 141ms/step
# Epoch 29/1000
# 1/1 - 0s - loss: 0.0462 - mean_absolute_error: 0.0462 - val_loss: 0.0659 - val_mean_absolute_error: 0.0659 - 162ms/epoch - 162ms/step
# Epoch 30/1000
# 1/1 - 0s - loss: 0.0486 - mean_absolute_error: 0.0486 - val_loss: 0.0615 - val_mean_absolute_error: 0.0615 - 165ms/epoch - 165ms/step
# Epoch 31/1000
# 1/1 - 0s - loss: 0.0453 - mean_absolute_error: 0.0453 - val_loss: 0.0598 - val_mean_absolute_error: 0.0598 - 165ms/epoch - 165ms/step
# Epoch 32/1000
# 1/1 - 0s - loss: 0.0468 - mean_absolute_error: 0.0468 - val_loss: 0.0612 - val_mean_absolute_error: 0.0612 - 164ms/epoch - 164ms/step
# Epoch 33/1000
# 1/1 - 0s - loss: 0.0480 - mean_absolute_error: 0.0480 - val_loss: 0.0604 - val_mean_absolute_error: 0.0604 - 141ms/epoch - 141ms/step
# Epoch 34/1000
# 1/1 - 0s - loss: 0.0458 - mean_absolute_error: 0.0458 - val_loss: 0.0600 - val_mean_absolute_error: 0.0600 - 165ms/epoch - 165ms/step
# Epoch 35/1000
# 1/1 - 0s - loss: 0.0439 - mean_absolute_error: 0.0439 - val_loss: 0.0618 - val_mean_absolute_error: 0.0618 - 162ms/epoch - 162ms/step
# Epoch 36/1000
# 1/1 - 0s - loss: 0.0458 - mean_absolute_error: 0.0458 - val_loss: 0.0614 - val_mean_absolute_error: 0.0614 - 140ms/epoch - 140ms/step
# Epoch 37/1000
# 1/1 - 0s - loss: 0.0458 - mean_absolute_error: 0.0458 - val_loss: 0.0589 - val_mean_absolute_error: 0.0589 - 142ms/epoch - 142ms/step
# Epoch 38/1000
# 1/1 - 0s - loss: 0.0440 - mean_absolute_error: 0.0440 - val_loss: 0.0584 - val_mean_absolute_error: 0.0584 - 165ms/epoch - 165ms/step
# Epoch 39/1000
# 1/1 - 0s - loss: 0.0440 - mean_absolute_error: 0.0440 - val_loss: 0.0582 - val_mean_absolute_error: 0.0582 - 140ms/epoch - 140ms/step
# Epoch 40/1000
# 1/1 - 0s - loss: 0.0437 - mean_absolute_error: 0.0437 - val_loss: 0.0577 - val_mean_absolute_error: 0.0577 - 167ms/epoch - 167ms/step
# Epoch 41/1000
# 1/1 - 0s - loss: 0.0422 - mean_absolute_error: 0.0422 - val_loss: 0.0592 - val_mean_absolute_error: 0.0592 - 143ms/epoch - 143ms/step
# Epoch 42/1000
# 1/1 - 0s - loss: 0.0436 - mean_absolute_error: 0.0436 - val_loss: 0.0602 - val_mean_absolute_error: 0.0602 - 141ms/epoch - 141ms/step
# Epoch 43/1000
# 1/1 - 0s - loss: 0.0432 - mean_absolute_error: 0.0432 - val_loss: 0.0592 - val_mean_absolute_error: 0.0592 - 164ms/epoch - 164ms/step
# Epoch 44/1000
# 1/1 - 0s - loss: 0.0429 - mean_absolute_error: 0.0429 - val_loss: 0.0578 - val_mean_absolute_error: 0.0578 - 167ms/epoch - 167ms/step
# Epoch 45/1000
# 1/1 - 0s - loss: 0.0424 - mean_absolute_error: 0.0424 - val_loss: 0.0573 - val_mean_absolute_error: 0.0573 - 165ms/epoch - 165ms/step
# Epoch 46/1000
# 1/1 - 0s - loss: 0.0430 - mean_absolute_error: 0.0430 - val_loss: 0.0573 - val_mean_absolute_error: 0.0573 - 140ms/epoch - 140ms/step
# Epoch 47/1000
# 1/1 - 0s - loss: 0.0429 - mean_absolute_error: 0.0429 - val_loss: 0.0575 - val_mean_absolute_error: 0.0575 - 140ms/epoch - 140ms/step
# Epoch 48/1000
# 1/1 - 0s - loss: 0.0426 - mean_absolute_error: 0.0426 - val_loss: 0.0583 - val_mean_absolute_error: 0.0583 - 147ms/epoch - 147ms/step
# Epoch 49/1000
# 1/1 - 0s - loss: 0.0426 - mean_absolute_error: 0.0426 - val_loss: 0.0588 - val_mean_absolute_error: 0.0588 - 142ms/epoch - 142ms/step
# Epoch 50/1000
# 1/1 - 0s - loss: 0.0425 - mean_absolute_error: 0.0425 - val_loss: 0.0584 - val_mean_absolute_error: 0.0584 - 144ms/epoch - 144ms/step
# Epoch 51/1000
# 1/1 - 0s - loss: 0.0427 - mean_absolute_error: 0.0427 - val_loss: 0.0578 - val_mean_absolute_error: 0.0578 - 167ms/epoch - 167ms/step
# Epoch 52/1000
# 1/1 - 0s - loss: 0.0417 - mean_absolute_error: 0.0417 - val_loss: 0.0576 - val_mean_absolute_error: 0.0576 - 142ms/epoch - 142ms/step
# Epoch 53/1000
# 1/1 - 0s - loss: 0.0421 - mean_absolute_error: 0.0421 - val_loss: 0.0577 - val_mean_absolute_error: 0.0577 - 140ms/epoch - 140ms/step
# Epoch 54/1000
# 1/1 - 0s - loss: 0.0418 - mean_absolute_error: 0.0418 - val_loss: 0.0580 - val_mean_absolute_error: 0.0580 - 142ms/epoch - 142ms/step
# Epoch 55/1000
# 1/1 - 0s - loss: 0.0416 - mean_absolute_error: 0.0416 - val_loss: 0.0589 - val_mean_absolute_error: 0.0589 - 163ms/epoch - 163ms/step
# Epoch 56/1000
# 1/1 - 0s - loss: 0.0416 - mean_absolute_error: 0.0416 - val_loss: 0.0590 - val_mean_absolute_error: 0.0590 - 144ms/epoch - 144ms/step
# Epoch 57/1000
# 1/1 - 0s - loss: 0.0409 - mean_absolute_error: 0.0409 - val_loss: 0.0586 - val_mean_absolute_error: 0.0586 - 172ms/epoch - 172ms/step
# Epoch 58/1000
# 1/1 - 0s - loss: 0.0419 - mean_absolute_error: 0.0419 - val_loss: 0.0585 - val_mean_absolute_error: 0.0585 - 143ms/epoch - 143ms/step
# Epoch 59/1000
# 1/1 - 0s - loss: 0.0418 - mean_absolute_error: 0.0418 - val_loss: 0.0586 - val_mean_absolute_error: 0.0586 - 141ms/epoch - 141ms/step
# Epoch 60/1000
# 1/1 - 0s - loss: 0.0415 - mean_absolute_error: 0.0415 - val_loss: 0.0589 - val_mean_absolute_error: 0.0589 - 141ms/epoch - 141ms/step
# Epoch 61/1000
# 1/1 - 0s - loss: 0.0415 - mean_absolute_error: 0.0415 - val_loss: 0.0593 - val_mean_absolute_error: 0.0593 - 140ms/epoch - 140ms/step
# Epoch 62/1000
# 1/1 - 0s - loss: 0.0413 - mean_absolute_error: 0.0413 - val_loss: 0.0591 - val_mean_absolute_error: 0.0591 - 166ms/epoch - 166ms/step
# Epoch 63/1000
# 1/1 - 0s - loss: 0.0418 - mean_absolute_error: 0.0418 - val_loss: 0.0587 - val_mean_absolute_error: 0.0587 - 140ms/epoch - 140ms/step
# Epoch 64/1000
# 1/1 - 0s - loss: 0.0416 - mean_absolute_error: 0.0416 - val_loss: 0.0586 - val_mean_absolute_error: 0.0586 - 166ms/epoch - 166ms/step
# Epoch 65/1000
# 1/1 - 0s - loss: 0.0413 - mean_absolute_error: 0.0413 - val_loss: 0.0586 - val_mean_absolute_error: 0.0586 - 164ms/epoch - 164ms/step
# Epoch 66/1000
# 1/1 - 0s - loss: 0.0415 - mean_absolute_error: 0.0415 - val_loss: 0.0587 - val_mean_absolute_error: 0.0587 - 165ms/epoch - 165ms/step
# Epoch 67/1000
# 1/1 - 0s - loss: 0.0414 - mean_absolute_error: 0.0414 - val_loss: 0.0586 - val_mean_absolute_error: 0.0586 - 163ms/epoch - 163ms/step
# Epoch 68/1000
# 1/1 - 0s - loss: 0.0414 - mean_absolute_error: 0.0414 - val_loss: 0.0584 - val_mean_absolute_error: 0.0584 - 166ms/epoch - 166ms/step
# Epoch 69/1000
# 1/1 - 0s - loss: 0.0412 - mean_absolute_error: 0.0412 - val_loss: 0.0582 - val_mean_absolute_error: 0.0582 - 144ms/epoch - 144ms/step
# Epoch 70/1000
# 1/1 - 0s - loss: 0.0410 - mean_absolute_error: 0.0410 - val_loss: 0.0581 - val_mean_absolute_error: 0.0581 - 170ms/epoch - 170ms/step
# Epoch 71/1000
# 1/1 - 0s - loss: 0.0413 - mean_absolute_error: 0.0413 - val_loss: 0.0581 - val_mean_absolute_error: 0.0581 - 139ms/epoch - 139ms/step
# Epoch 72/1000
# 1/1 - 0s - loss: 0.0418 - mean_absolute_error: 0.0418 - val_loss: 0.0583 - val_mean_absolute_error: 0.0583 - 144ms/epoch - 144ms/step
# Epoch 73/1000
# 1/1 - 0s - loss: 0.0416 - mean_absolute_error: 0.0416 - val_loss: 0.0584 - val_mean_absolute_error: 0.0584 - 143ms/epoch - 143ms/step
# Epoch 74/1000
# 1/1 - 0s - loss: 0.0414 - mean_absolute_error: 0.0414 - val_loss: 0.0582 - val_mean_absolute_error: 0.0582 - 165ms/epoch - 165ms/step
# Epoch 75/1000
# 1/1 - 0s - loss: 0.0409 - mean_absolute_error: 0.0409 - val_loss: 0.0582 - val_mean_absolute_error: 0.0582 - 141ms/epoch - 141ms/step
# Epoch 76/1000
# 1/1 - 0s - loss: 0.0408 - mean_absolute_error: 0.0408 - val_loss: 0.0584 - val_mean_absolute_error: 0.0584 - 145ms/epoch - 145ms/step
# Epoch 77/1000
# 1/1 - 0s - loss: 0.0408 - mean_absolute_error: 0.0408 - val_loss: 0.0585 - val_mean_absolute_error: 0.0585 - 142ms/epoch - 142ms/step
# Epoch 78/1000
# 1/1 - 0s - loss: 0.0410 - mean_absolute_error: 0.0410 - val_loss: 0.0585 - val_mean_absolute_error: 0.0585 - 164ms/epoch - 164ms/step
# Epoch 79/1000
# 1/1 - 0s - loss: 0.0413 - mean_absolute_error: 0.0413 - val_loss: 0.0585 - val_mean_absolute_error: 0.0585 - 145ms/epoch - 145ms/step
# Epoch 80/1000
# 1/1 - 0s - loss: 0.0404 - mean_absolute_error: 0.0404 - val_loss: 0.0586 - val_mean_absolute_error: 0.0586 - 167ms/epoch - 167ms/step
# Epoch 81/1000
# 1/1 - 0s - loss: 0.0407 - mean_absolute_error: 0.0407 - val_loss: 0.0589 - val_mean_absolute_error: 0.0589 - 142ms/epoch - 142ms/step
# Epoch 82/1000
# 1/1 - 0s - loss: 0.0409 - mean_absolute_error: 0.0409 - val_loss: 0.0588 - val_mean_absolute_error: 0.0588 - 141ms/epoch - 141ms/step
# Epoch 83/1000
# 1/1 - 0s - loss: 0.0412 - mean_absolute_error: 0.0412 - val_loss: 0.0587 - val_mean_absolute_error: 0.0587 - 166ms/epoch - 166ms/step
# Epoch 84/1000
# 1/1 - 0s - loss: 0.0405 - mean_absolute_error: 0.0405 - val_loss: 0.0586 - val_mean_absolute_error: 0.0586 - 167ms/epoch - 167ms/step
# Epoch 85/1000
# 1/1 - 0s - loss: 0.0410 - mean_absolute_error: 0.0410 - val_loss: 0.0587 - val_mean_absolute_error: 0.0587 - 165ms/epoch - 165ms/step
# Epoch 86/1000
# 1/1 - 0s - loss: 0.0412 - mean_absolute_error: 0.0412 - val_loss: 0.0588 - val_mean_absolute_error: 0.0588 - 165ms/epoch - 165ms/step
# Epoch 87/1000
# 1/1 - 0s - loss: 0.0411 - mean_absolute_error: 0.0411 - val_loss: 0.0584 - val_mean_absolute_error: 0.0584 - 142ms/epoch - 142ms/step
# Epoch 88/1000
# 1/1 - 0s - loss: 0.0402 - mean_absolute_error: 0.0402 - val_loss: 0.0584 - val_mean_absolute_error: 0.0584 - 166ms/epoch - 166ms/step
# Epoch 89/1000
# 1/1 - 0s - loss: 0.0407 - mean_absolute_error: 0.0407 - val_loss: 0.0586 - val_mean_absolute_error: 0.0586 - 167ms/epoch - 167ms/step
# Epoch 90/1000
# 1/1 - 0s - loss: 0.0409 - mean_absolute_error: 0.0409 - val_loss: 0.0586 - val_mean_absolute_error: 0.0586 - 141ms/epoch - 141ms/step
# Epoch 91/1000
# 1/1 - 0s - loss: 0.0407 - mean_absolute_error: 0.0407 - val_loss: 0.0582 - val_mean_absolute_error: 0.0582 - 142ms/epoch - 142ms/step
# Epoch 92/1000
# 1/1 - 0s - loss: 0.0403 - mean_absolute_error: 0.0403 - val_loss: 0.0582 - val_mean_absolute_error: 0.0582 - 143ms/epoch - 143ms/step
# Epoch 93/1000
# 1/1 - 0s - loss: 0.0413 - mean_absolute_error: 0.0413 - val_loss: 0.0583 - val_mean_absolute_error: 0.0583 - 143ms/epoch - 143ms/step
# Epoch 94/1000
# 1/1 - 0s - loss: 0.0405 - mean_absolute_error: 0.0405 - val_loss: 0.0590 - val_mean_absolute_error: 0.0590 - 143ms/epoch - 143ms/step
# Epoch 95/1000
# 1/1 - 0s - loss: 0.0413 - mean_absolute_error: 0.0413 - val_loss: 0.0585 - val_mean_absolute_error: 0.0585 - 163ms/epoch - 163ms/step
# Epoch 96/1000
# 1/1 - 0s - loss: 0.0407 - mean_absolute_error: 0.0407 - val_loss: 0.0583 - val_mean_absolute_error: 0.0583 - 165ms/epoch - 165ms/step
# Epoch 97/1000
# 1/1 - 0s - loss: 0.0405 - mean_absolute_error: 0.0405 - val_loss: 0.0584 - val_mean_absolute_error: 0.0584 - 165ms/epoch - 165ms/step
# Epoch 98/1000
# 1/1 - 0s - loss: 0.0409 - mean_absolute_error: 0.0409 - val_loss: 0.0588 - val_mean_absolute_error: 0.0588 - 168ms/epoch - 168ms/step
# Epoch 99/1000
# 1/1 - 0s - loss: 0.0412 - mean_absolute_error: 0.0412 - val_loss: 0.0585 - val_mean_absolute_error: 0.0585 - 167ms/epoch - 167ms/step
# Epoch 100/1000
# 1/1 - 0s - loss: 0.0401 - mean_absolute_error: 0.0401 - val_loss: 0.0584 - val_mean_absolute_error: 0.0584 - 142ms/epoch - 142ms/step
# Epoch 101/1000
# 1/1 - 0s - loss: 0.0404 - mean_absolute_error: 0.0404 - val_loss: 0.0584 - val_mean_absolute_error: 0.0584 - 164ms/epoch - 164ms/step
# Epoch 102/1000
# 1/1 - 0s - loss: 0.0407 - mean_absolute_error: 0.0407 - val_loss: 0.0585 - val_mean_absolute_error: 0.0585 - 142ms/epoch - 142ms/step
# Epoch 103/1000
# 1/1 - 0s - loss: 0.0407 - mean_absolute_error: 0.0407 - val_loss: 0.0583 - val_mean_absolute_error: 0.0583 - 141ms/epoch - 141ms/step
# Epoch 104/1000
# 1/1 - 0s - loss: 0.0405 - mean_absolute_error: 0.0405 - val_loss: 0.0582 - val_mean_absolute_error: 0.0582 - 143ms/epoch - 143ms/step
# Epoch 105/1000
# 1/1 - 0s - loss: 0.0410 - mean_absolute_error: 0.0410 - val_loss: 0.0581 - val_mean_absolute_error: 0.0581 - 163ms/epoch - 163ms/step
# Epoch 106/1000
# 1/1 - 0s - loss: 0.0405 - mean_absolute_error: 0.0405 - val_loss: 0.0581 - val_mean_absolute_error: 0.0581 - 145ms/epoch - 145ms/step
# Epoch 107/1000
# 1/1 - 0s - loss: 0.0407 - mean_absolute_error: 0.0407 - val_loss: 0.0580 - val_mean_absolute_error: 0.0580 - 164ms/epoch - 164ms/step
# Epoch 108/1000
# 1/1 - 0s - loss: 0.0402 - mean_absolute_error: 0.0402 - val_loss: 0.0580 - val_mean_absolute_error: 0.0580 - 167ms/epoch - 167ms/step
# Epoch 109/1000
# 1/1 - 0s - loss: 0.0399 - mean_absolute_error: 0.0399 - val_loss: 0.0580 - val_mean_absolute_error: 0.0580 - 166ms/epoch - 166ms/step
# Epoch 110/1000
# 1/1 - 0s - loss: 0.0399 - mean_absolute_error: 0.0399 - val_loss: 0.0583 - val_mean_absolute_error: 0.0583 - 146ms/epoch - 146ms/step
# Epoch 111/1000
# 1/1 - 0s - loss: 0.0399 - mean_absolute_error: 0.0399 - val_loss: 0.0582 - val_mean_absolute_error: 0.0582 - 166ms/epoch - 166ms/step
# Epoch 112/1000
# 1/1 - 0s - loss: 0.0397 - mean_absolute_error: 0.0397 - val_loss: 0.0583 - val_mean_absolute_error: 0.0583 - 168ms/epoch - 168ms/step
# Epoch 113/1000
# 1/1 - 0s - loss: 0.0400 - mean_absolute_error: 0.0400 - val_loss: 0.0584 - val_mean_absolute_error: 0.0584 - 166ms/epoch - 166ms/step
# Epoch 114/1000
# 1/1 - 0s - loss: 0.0402 - mean_absolute_error: 0.0402 - val_loss: 0.0583 - val_mean_absolute_error: 0.0583 - 166ms/epoch - 166ms/step
# Epoch 115/1000
# 1/1 - 0s - loss: 0.0399 - mean_absolute_error: 0.0399 - val_loss: 0.0582 - val_mean_absolute_error: 0.0582 - 164ms/epoch - 164ms/step
# Epoch 116/1000
# 1/1 - 0s - loss: 0.0401 - mean_absolute_error: 0.0401 - val_loss: 0.0581 - val_mean_absolute_error: 0.0581 - 166ms/epoch - 166ms/step
# Epoch 117/1000
# 1/1 - 0s - loss: 0.0396 - mean_absolute_error: 0.0396 - val_loss: 0.0583 - val_mean_absolute_error: 0.0583 - 147ms/epoch - 147ms/step
# Epoch 118/1000
# 1/1 - 0s - loss: 0.0399 - mean_absolute_error: 0.0399 - val_loss: 0.0579 - val_mean_absolute_error: 0.0579 - 171ms/epoch - 171ms/step
# Epoch 119/1000
# 1/1 - 0s - loss: 0.0398 - mean_absolute_error: 0.0398 - val_loss: 0.0579 - val_mean_absolute_error: 0.0579 - 141ms/epoch - 141ms/step
# Epoch 120/1000
# 1/1 - 0s - loss: 0.0394 - mean_absolute_error: 0.0394 - val_loss: 0.0582 - val_mean_absolute_error: 0.0582 - 167ms/epoch - 167ms/step
# Epoch 121/1000
# 1/1 - 0s - loss: 0.0400 - mean_absolute_error: 0.0400 - val_loss: 0.0579 - val_mean_absolute_error: 0.0579 - 141ms/epoch - 141ms/step
# Epoch 122/1000
# 1/1 - 0s - loss: 0.0395 - mean_absolute_error: 0.0395 - val_loss: 0.0579 - val_mean_absolute_error: 0.0579 - 165ms/epoch - 165ms/step
# Epoch 123/1000
# 1/1 - 0s - loss: 0.0392 - mean_absolute_error: 0.0392 - val_loss: 0.0583 - val_mean_absolute_error: 0.0583 - 142ms/epoch - 142ms/step
# Epoch 124/1000
# 1/1 - 0s - loss: 0.0397 - mean_absolute_error: 0.0397 - val_loss: 0.0579 - val_mean_absolute_error: 0.0579 - 166ms/epoch - 166ms/step
# Epoch 125/1000
# 1/1 - 0s - loss: 0.0385 - mean_absolute_error: 0.0385 - val_loss: 0.0579 - val_mean_absolute_error: 0.0579 - 165ms/epoch - 165ms/step
# Epoch 126/1000
# 1/1 - 0s - loss: 0.0398 - mean_absolute_error: 0.0398 - val_loss: 0.0581 - val_mean_absolute_error: 0.0581 - 142ms/epoch - 142ms/step
# Epoch 127/1000
# 1/1 - 0s - loss: 0.0392 - mean_absolute_error: 0.0392 - val_loss: 0.0579 - val_mean_absolute_error: 0.0579 - 166ms/epoch - 166ms/step
# Epoch 128/1000
# 1/1 - 0s - loss: 0.0390 - mean_absolute_error: 0.0390 - val_loss: 0.0579 - val_mean_absolute_error: 0.0579 - 144ms/epoch - 144ms/step
# Epoch 129/1000
# 1/1 - 0s - loss: 0.0391 - mean_absolute_error: 0.0391 - val_loss: 0.0577 - val_mean_absolute_error: 0.0577 - 150ms/epoch - 150ms/step
# Epoch 130/1000
# 1/1 - 0s - loss: 0.0387 - mean_absolute_error: 0.0387 - val_loss: 0.0576 - val_mean_absolute_error: 0.0576 - 167ms/epoch - 167ms/step
# Epoch 131/1000
# 1/1 - 0s - loss: 0.0393 - mean_absolute_error: 0.0393 - val_loss: 0.0576 - val_mean_absolute_error: 0.0576 - 141ms/epoch - 141ms/step
# Epoch 132/1000
# 1/1 - 0s - loss: 0.0386 - mean_absolute_error: 0.0386 - val_loss: 0.0577 - val_mean_absolute_error: 0.0577 - 145ms/epoch - 145ms/step
# Epoch 133/1000
# 1/1 - 0s - loss: 0.0386 - mean_absolute_error: 0.0386 - val_loss: 0.0587 - val_mean_absolute_error: 0.0587 - 170ms/epoch - 170ms/step
# Epoch 134/1000
# 1/1 - 0s - loss: 0.0395 - mean_absolute_error: 0.0395 - val_loss: 0.0586 - val_mean_absolute_error: 0.0586 - 171ms/epoch - 171ms/step
# Epoch 135/1000
# 1/1 - 0s - loss: 0.0403 - mean_absolute_error: 0.0403 - val_loss: 0.0581 - val_mean_absolute_error: 0.0581 - 141ms/epoch - 141ms/step
# Epoch 136/1000
# 1/1 - 0s - loss: 0.0387 - mean_absolute_error: 0.0387 - val_loss: 0.0577 - val_mean_absolute_error: 0.0577 - 171ms/epoch - 171ms/step
# Epoch 137/1000
# 1/1 - 0s - loss: 0.0387 - mean_absolute_error: 0.0387 - val_loss: 0.0576 - val_mean_absolute_error: 0.0576 - 143ms/epoch - 143ms/step
# Epoch 138/1000
# 1/1 - 0s - loss: 0.0382 - mean_absolute_error: 0.0382 - val_loss: 0.0573 - val_mean_absolute_error: 0.0573 - 143ms/epoch - 143ms/step
# Epoch 139/1000
# 1/1 - 0s - loss: 0.0381 - mean_absolute_error: 0.0381 - val_loss: 0.0571 - val_mean_absolute_error: 0.0571 - 167ms/epoch - 167ms/step
# Epoch 140/1000
# 1/1 - 0s - loss: 0.0370 - mean_absolute_error: 0.0370 - val_loss: 0.0570 - val_mean_absolute_error: 0.0570 - 166ms/epoch - 166ms/step
# Epoch 141/1000
# 1/1 - 0s - loss: 0.0375 - mean_absolute_error: 0.0375 - val_loss: 0.0568 - val_mean_absolute_error: 0.0568 - 165ms/epoch - 165ms/step
# Epoch 142/1000
# 1/1 - 0s - loss: 0.0371 - mean_absolute_error: 0.0371 - val_loss: 0.0565 - val_mean_absolute_error: 0.0565 - 167ms/epoch - 167ms/step
# Epoch 143/1000
# 1/1 - 0s - loss: 0.0374 - mean_absolute_error: 0.0374 - val_loss: 0.0569 - val_mean_absolute_error: 0.0569 - 140ms/epoch - 140ms/step
# Epoch 144/1000
# 1/1 - 0s - loss: 0.0382 - mean_absolute_error: 0.0382 - val_loss: 0.0652 - val_mean_absolute_error: 0.0652 - 166ms/epoch - 166ms/step
# Epoch 145/1000
# 1/1 - 0s - loss: 0.0457 - mean_absolute_error: 0.0457 - val_loss: 0.0549 - val_mean_absolute_error: 0.0549 - 147ms/epoch - 147ms/step
# Epoch 146/1000
# 1/1 - 0s - loss: 0.0375 - mean_absolute_error: 0.0375 - val_loss: 0.0553 - val_mean_absolute_error: 0.0553 - 151ms/epoch - 151ms/step
# Epoch 147/1000
# 1/1 - 0s - loss: 0.0386 - mean_absolute_error: 0.0386 - val_loss: 0.0617 - val_mean_absolute_error: 0.0617 - 143ms/epoch - 143ms/step
# Epoch 148/1000
# 1/1 - 0s - loss: 0.0419 - mean_absolute_error: 0.0419 - val_loss: 0.0572 - val_mean_absolute_error: 0.0572 - 166ms/epoch - 166ms/step
# Epoch 149/1000
# 1/1 - 0s - loss: 0.0367 - mean_absolute_error: 0.0367 - val_loss: 0.0601 - val_mean_absolute_error: 0.0601 - 142ms/epoch - 142ms/step
# Epoch 150/1000
# 1/1 - 0s - loss: 0.0423 - mean_absolute_error: 0.0423 - val_loss: 0.0625 - val_mean_absolute_error: 0.0625 - 168ms/epoch - 168ms/step
# Epoch 151/1000
# 1/1 - 0s - loss: 0.0428 - mean_absolute_error: 0.0428 - val_loss: 0.0565 - val_mean_absolute_error: 0.0565 - 143ms/epoch - 143ms/step
# Epoch 152/1000
# 1/1 - 0s - loss: 0.0395 - mean_absolute_error: 0.0395 - val_loss: 0.0546 - val_mean_absolute_error: 0.0546 - 144ms/epoch - 144ms/step
# Epoch 153/1000
# 1/1 - 0s - loss: 0.0420 - mean_absolute_error: 0.0420 - val_loss: 0.0553 - val_mean_absolute_error: 0.0553 - 141ms/epoch - 141ms/step
# Epoch 154/1000
# 1/1 - 0s - loss: 0.0369 - mean_absolute_error: 0.0369 - val_loss: 0.0572 - val_mean_absolute_error: 0.0572 - 167ms/epoch - 167ms/step
# Epoch 155/1000
# 1/1 - 0s - loss: 0.0372 - mean_absolute_error: 0.0372 - val_loss: 0.0589 - val_mean_absolute_error: 0.0589 - 164ms/epoch - 164ms/step
# Epoch 156/1000
# 1/1 - 0s - loss: 0.0385 - mean_absolute_error: 0.0385 - val_loss: 0.0575 - val_mean_absolute_error: 0.0575 - 142ms/epoch - 142ms/step
# Epoch 157/1000
# 1/1 - 0s - loss: 0.0371 - mean_absolute_error: 0.0371 - val_loss: 0.0574 - val_mean_absolute_error: 0.0574 - 164ms/epoch - 164ms/step
# Epoch 158/1000
# 1/1 - 0s - loss: 0.0378 - mean_absolute_error: 0.0378 - val_loss: 0.0563 - val_mean_absolute_error: 0.0563 - 144ms/epoch - 144ms/step
# Epoch 159/1000
# 1/1 - 0s - loss: 0.0381 - mean_absolute_error: 0.0381 - val_loss: 0.0550 - val_mean_absolute_error: 0.0550 - 165ms/epoch - 165ms/step
# Epoch 160/1000
# 1/1 - 0s - loss: 0.0372 - mean_absolute_error: 0.0372 - val_loss: 0.0560 - val_mean_absolute_error: 0.0560 - 144ms/epoch - 144ms/step
# Epoch 161/1000
# 1/1 - 0s - loss: 0.0380 - mean_absolute_error: 0.0380 - val_loss: 0.0551 - val_mean_absolute_error: 0.0551 - 144ms/epoch - 144ms/step
# Epoch 162/1000
# 1/1 - 0s - loss: 0.0370 - mean_absolute_error: 0.0370 - val_loss: 0.0564 - val_mean_absolute_error: 0.0564 - 170ms/epoch - 170ms/step
# Epoch 163/1000
# 1/1 - 0s - loss: 0.0376 - mean_absolute_error: 0.0376 - val_loss: 0.0562 - val_mean_absolute_error: 0.0562 - 164ms/epoch - 164ms/step
# Epoch 164/1000
# 1/1 - 0s - loss: 0.0358 - mean_absolute_error: 0.0358 - val_loss: 0.0570 - val_mean_absolute_error: 0.0570 - 143ms/epoch - 143ms/step
# Epoch 165/1000
# 1/1 - 0s - loss: 0.0368 - mean_absolute_error: 0.0368 - val_loss: 0.0575 - val_mean_absolute_error: 0.0575 - 171ms/epoch - 171ms/step
# Epoch 166/1000
# 1/1 - 0s - loss: 0.0368 - mean_absolute_error: 0.0368 - val_loss: 0.0564 - val_mean_absolute_error: 0.0564 - 147ms/epoch - 147ms/step
# Epoch 167/1000
# 1/1 - 0s - loss: 0.0358 - mean_absolute_error: 0.0358 - val_loss: 0.0558 - val_mean_absolute_error: 0.0558 - 164ms/epoch - 164ms/step
# Epoch 168/1000
# 1/1 - 0s - loss: 0.0369 - mean_absolute_error: 0.0369 - val_loss: 0.0540 - val_mean_absolute_error: 0.0540 - 170ms/epoch - 170ms/step
# Epoch 169/1000
# 1/1 - 0s - loss: 0.0372 - mean_absolute_error: 0.0372 - val_loss: 0.0533 - val_mean_absolute_error: 0.0533 - 168ms/epoch - 168ms/step
# Epoch 170/1000
# 1/1 - 0s - loss: 0.0355 - mean_absolute_error: 0.0355 - val_loss: 0.0546 - val_mean_absolute_error: 0.0546 - 170ms/epoch - 170ms/step
# Epoch 171/1000
# 1/1 - 0s - loss: 0.0359 - mean_absolute_error: 0.0359 - val_loss: 0.0563 - val_mean_absolute_error: 0.0563 - 178ms/epoch - 178ms/step
# Epoch 172/1000
# 1/1 - 0s - loss: 0.0373 - mean_absolute_error: 0.0373 - val_loss: 0.0563 - val_mean_absolute_error: 0.0563 - 142ms/epoch - 142ms/step
# Epoch 173/1000
# 1/1 - 0s - loss: 0.0363 - mean_absolute_error: 0.0363 - val_loss: 0.0562 - val_mean_absolute_error: 0.0562 - 164ms/epoch - 164ms/step
# Epoch 174/1000
# 1/1 - 0s - loss: 0.0351 - mean_absolute_error: 0.0351 - val_loss: 0.0560 - val_mean_absolute_error: 0.0560 - 144ms/epoch - 144ms/step
# Epoch 175/1000
# 1/1 - 0s - loss: 0.0378 - mean_absolute_error: 0.0378 - val_loss: 0.0537 - val_mean_absolute_error: 0.0537 - 165ms/epoch - 165ms/step
# Epoch 176/1000
# 1/1 - 0s - loss: 0.0359 - mean_absolute_error: 0.0359 - val_loss: 0.0553 - val_mean_absolute_error: 0.0553 - 167ms/epoch - 167ms/step
# Epoch 177/1000
# 1/1 - 0s - loss: 0.0371 - mean_absolute_error: 0.0371 - val_loss: 0.0548 - val_mean_absolute_error: 0.0548 - 164ms/epoch - 164ms/step
# Epoch 178/1000
# 1/1 - 0s - loss: 0.0355 - mean_absolute_error: 0.0355 - val_loss: 0.0548 - val_mean_absolute_error: 0.0548 - 144ms/epoch - 144ms/step
# Epoch 179/1000
# 1/1 - 0s - loss: 0.0347 - mean_absolute_error: 0.0347 - val_loss: 0.0552 - val_mean_absolute_error: 0.0552 - 167ms/epoch - 167ms/step
# Epoch 180/1000
# 1/1 - 0s - loss: 0.0355 - mean_absolute_error: 0.0355 - val_loss: 0.0559 - val_mean_absolute_error: 0.0559 - 147ms/epoch - 147ms/step
# Epoch 181/1000
# 1/1 - 0s - loss: 0.0356 - mean_absolute_error: 0.0356 - val_loss: 0.0556 - val_mean_absolute_error: 0.0556 - 143ms/epoch - 143ms/step
# Epoch 182/1000
# 1/1 - 0s - loss: 0.0360 - mean_absolute_error: 0.0360 - val_loss: 0.0549 - val_mean_absolute_error: 0.0549 - 169ms/epoch - 169ms/step
# Epoch 183/1000
# 1/1 - 0s - loss: 0.0351 - mean_absolute_error: 0.0351 - val_loss: 0.0543 - val_mean_absolute_error: 0.0543 - 145ms/epoch - 145ms/step
# Epoch 184/1000
# 1/1 - 0s - loss: 0.0355 - mean_absolute_error: 0.0355 - val_loss: 0.0543 - val_mean_absolute_error: 0.0543 - 145ms/epoch - 145ms/step
# Epoch 185/1000
# 1/1 - 0s - loss: 0.0356 - mean_absolute_error: 0.0356 - val_loss: 0.0548 - val_mean_absolute_error: 0.0548 - 142ms/epoch - 142ms/step
# Epoch 186/1000
# 1/1 - 0s - loss: 0.0357 - mean_absolute_error: 0.0357 - val_loss: 0.0551 - val_mean_absolute_error: 0.0551 - 169ms/epoch - 169ms/step
# Epoch 187/1000
# 1/1 - 0s - loss: 0.0354 - mean_absolute_error: 0.0354 - val_loss: 0.0553 - val_mean_absolute_error: 0.0553 - 166ms/epoch - 166ms/step
# Epoch 188/1000
# 1/1 - 0s - loss: 0.0354 - mean_absolute_error: 0.0354 - val_loss: 0.0552 - val_mean_absolute_error: 0.0552 - 167ms/epoch - 167ms/step
# Epoch 189/1000
# 1/1 - 0s - loss: 0.0349 - mean_absolute_error: 0.0349 - val_loss: 0.0550 - val_mean_absolute_error: 0.0550 - 142ms/epoch - 142ms/step
# Epoch 190/1000
# 1/1 - 0s - loss: 0.0348 - mean_absolute_error: 0.0348 - val_loss: 0.0542 - val_mean_absolute_error: 0.0542 - 145ms/epoch - 145ms/step
# Epoch 191/1000
# 1/1 - 0s - loss: 0.0353 - mean_absolute_error: 0.0353 - val_loss: 0.0535 - val_mean_absolute_error: 0.0535 - 166ms/epoch - 166ms/step
# Epoch 192/1000
# 1/1 - 0s - loss: 0.0353 - mean_absolute_error: 0.0353 - val_loss: 0.0537 - val_mean_absolute_error: 0.0537 - 147ms/epoch - 147ms/step
# Epoch 193/1000
# 1/1 - 0s - loss: 0.0350 - mean_absolute_error: 0.0350 - val_loss: 0.0545 - val_mean_absolute_error: 0.0545 - 142ms/epoch - 142ms/step
# Epoch 194/1000
# 1/1 - 0s - loss: 0.0348 - mean_absolute_error: 0.0348 - val_loss: 0.0548 - val_mean_absolute_error: 0.0548 - 168ms/epoch - 168ms/step
# Epoch 195/1000
# 1/1 - 0s - loss: 0.0350 - mean_absolute_error: 0.0350 - val_loss: 0.0545 - val_mean_absolute_error: 0.0545 - 180ms/epoch - 180ms/step
# Epoch 196/1000
# 1/1 - 0s - loss: 0.0351 - mean_absolute_error: 0.0351 - val_loss: 0.0537 - val_mean_absolute_error: 0.0537 - 172ms/epoch - 172ms/step
# Epoch 197/1000
# 1/1 - 0s - loss: 0.0351 - mean_absolute_error: 0.0351 - val_loss: 0.0535 - val_mean_absolute_error: 0.0535 - 167ms/epoch - 167ms/step
# Epoch 198/1000
# 1/1 - 0s - loss: 0.0354 - mean_absolute_error: 0.0354 - val_loss: 0.0544 - val_mean_absolute_error: 0.0544 - 171ms/epoch - 171ms/step
# Epoch 199/1000
# 1/1 - 0s - loss: 0.0357 - mean_absolute_error: 0.0357 - val_loss: 0.0547 - val_mean_absolute_error: 0.0547 - 176ms/epoch - 176ms/step
# Epoch 200/1000
# 1/1 - 0s - loss: 0.0357 - mean_absolute_error: 0.0357 - val_loss: 0.0548 - val_mean_absolute_error: 0.0548 - 172ms/epoch - 172ms/step
# Epoch 201/1000
# 1/1 - 0s - loss: 0.0346 - mean_absolute_error: 0.0346 - val_loss: 0.0545 - val_mean_absolute_error: 0.0545 - 167ms/epoch - 167ms/step
# Epoch 202/1000
# 1/1 - 0s - loss: 0.0345 - mean_absolute_error: 0.0345 - val_loss: 0.0540 - val_mean_absolute_error: 0.0540 - 180ms/epoch - 180ms/step
# Epoch 203/1000
# 1/1 - 0s - loss: 0.0344 - mean_absolute_error: 0.0344 - val_loss: 0.0536 - val_mean_absolute_error: 0.0536 - 170ms/epoch - 170ms/step
# Epoch 204/1000
# 1/1 - 0s - loss: 0.0335 - mean_absolute_error: 0.0335 - val_loss: 0.0545 - val_mean_absolute_error: 0.0545 - 168ms/epoch - 168ms/step
# Epoch 205/1000
# 1/1 - 0s - loss: 0.0351 - mean_absolute_error: 0.0351 - val_loss: 0.0559 - val_mean_absolute_error: 0.0559 - 149ms/epoch - 149ms/step
# Epoch 206/1000
# 1/1 - 0s - loss: 0.0369 - mean_absolute_error: 0.0369 - val_loss: 0.0563 - val_mean_absolute_error: 0.0563 - 173ms/epoch - 173ms/step
# Epoch 207/1000
# 1/1 - 0s - loss: 0.0365 - mean_absolute_error: 0.0365 - val_loss: 0.0538 - val_mean_absolute_error: 0.0538 - 142ms/epoch - 142ms/step
# Epoch 208/1000
# 1/1 - 0s - loss: 0.0347 - mean_absolute_error: 0.0347 - val_loss: 0.0531 - val_mean_absolute_error: 0.0531 - 186ms/epoch - 186ms/step
# Epoch 209/1000
# 1/1 - 0s - loss: 0.0340 - mean_absolute_error: 0.0340 - val_loss: 0.0532 - val_mean_absolute_error: 0.0532 - 173ms/epoch - 173ms/step
# Epoch 210/1000
# 1/1 - 0s - loss: 0.0341 - mean_absolute_error: 0.0341 - val_loss: 0.0542 - val_mean_absolute_error: 0.0542 - 178ms/epoch - 178ms/step
# Epoch 211/1000
# 1/1 - 0s - loss: 0.0346 - mean_absolute_error: 0.0346 - val_loss: 0.0551 - val_mean_absolute_error: 0.0551 - 154ms/epoch - 154ms/step
# Epoch 212/1000
# 1/1 - 0s - loss: 0.0350 - mean_absolute_error: 0.0350 - val_loss: 0.0559 - val_mean_absolute_error: 0.0559 - 157ms/epoch - 157ms/step
# Epoch 213/1000
# 1/1 - 0s - loss: 0.0364 - mean_absolute_error: 0.0364 - val_loss: 0.0549 - val_mean_absolute_error: 0.0549 - 143ms/epoch - 143ms/step
# Epoch 214/1000
# 1/1 - 0s - loss: 0.0367 - mean_absolute_error: 0.0367 - val_loss: 0.0531 - val_mean_absolute_error: 0.0531 - 168ms/epoch - 168ms/step
# Epoch 215/1000
# 1/1 - 0s - loss: 0.0349 - mean_absolute_error: 0.0349 - val_loss: 0.0529 - val_mean_absolute_error: 0.0529 - 165ms/epoch - 165ms/step
# Epoch 216/1000
# 1/1 - 0s - loss: 0.0349 - mean_absolute_error: 0.0349 - val_loss: 0.0543 - val_mean_absolute_error: 0.0543 - 144ms/epoch - 144ms/step
# Epoch 217/1000
# 1/1 - 0s - loss: 0.0361 - mean_absolute_error: 0.0361 - val_loss: 0.0544 - val_mean_absolute_error: 0.0544 - 147ms/epoch - 147ms/step
# Epoch 218/1000
# 1/1 - 0s - loss: 0.0351 - mean_absolute_error: 0.0351 - val_loss: 0.0542 - val_mean_absolute_error: 0.0542 - 168ms/epoch - 168ms/step
# Epoch 219/1000
# 1/1 - 0s - loss: 0.0348 - mean_absolute_error: 0.0348 - val_loss: 0.0546 - val_mean_absolute_error: 0.0546 - 167ms/epoch - 167ms/step
# Epoch 220/1000
# 1/1 - 0s - loss: 0.0345 - mean_absolute_error: 0.0345 - val_loss: 0.0536 - val_mean_absolute_error: 0.0536 - 170ms/epoch - 170ms/step
# Epoch 221/1000
# 1/1 - 0s - loss: 0.0345 - mean_absolute_error: 0.0345 - val_loss: 0.0534 - val_mean_absolute_error: 0.0534 - 141ms/epoch - 141ms/step
# Epoch 222/1000
# 1/1 - 0s - loss: 0.0347 - mean_absolute_error: 0.0347 - val_loss: 0.0537 - val_mean_absolute_error: 0.0537 - 168ms/epoch - 168ms/step
# Epoch 223/1000
# 1/1 - 0s - loss: 0.0362 - mean_absolute_error: 0.0362 - val_loss: 0.0534 - val_mean_absolute_error: 0.0534 - 145ms/epoch - 145ms/step
# Epoch 224/1000
# 1/1 - 0s - loss: 0.0339 - mean_absolute_error: 0.0339 - val_loss: 0.0535 - val_mean_absolute_error: 0.0535 - 166ms/epoch - 166ms/step
# Epoch 225/1000
# 1/1 - 0s - loss: 0.0339 - mean_absolute_error: 0.0339 - val_loss: 0.0539 - val_mean_absolute_error: 0.0539 - 144ms/epoch - 144ms/step
# Epoch 226/1000
# 1/1 - 0s - loss: 0.0344 - mean_absolute_error: 0.0344 - val_loss: 0.0537 - val_mean_absolute_error: 0.0537 - 144ms/epoch - 144ms/step
# Epoch 227/1000
# 1/1 - 0s - loss: 0.0347 - mean_absolute_error: 0.0347 - val_loss: 0.0527 - val_mean_absolute_error: 0.0527 - 144ms/epoch - 144ms/step
# Epoch 228/1000
# 1/1 - 0s - loss: 0.0356 - mean_absolute_error: 0.0356 - val_loss: 0.0527 - val_mean_absolute_error: 0.0527 - 144ms/epoch - 144ms/step
# Epoch 229/1000
# 1/1 - 0s - loss: 0.0373 - mean_absolute_error: 0.0373 - val_loss: 0.0532 - val_mean_absolute_error: 0.0532 - 166ms/epoch - 166ms/step
# Epoch 230/1000
# 1/1 - 0s - loss: 0.0359 - mean_absolute_error: 0.0359 - val_loss: 0.0532 - val_mean_absolute_error: 0.0532 - 145ms/epoch - 145ms/step
# Epoch 231/1000
# 1/1 - 0s - loss: 0.0340 - mean_absolute_error: 0.0340 - val_loss: 0.0540 - val_mean_absolute_error: 0.0540 - 172ms/epoch - 172ms/step
# Epoch 232/1000
# 1/1 - 0s - loss: 0.0349 - mean_absolute_error: 0.0349 - val_loss: 0.0538 - val_mean_absolute_error: 0.0538 - 169ms/epoch - 169ms/step
# Epoch 233/1000
# 1/1 - 0s - loss: 0.0360 - mean_absolute_error: 0.0360 - val_loss: 0.0539 - val_mean_absolute_error: 0.0539 - 140ms/epoch - 140ms/step
# Epoch 234/1000
# 1/1 - 0s - loss: 0.0349 - mean_absolute_error: 0.0349 - val_loss: 0.0529 - val_mean_absolute_error: 0.0529 - 168ms/epoch - 168ms/step
# Epoch 235/1000
# 1/1 - 0s - loss: 0.0349 - mean_absolute_error: 0.0349 - val_loss: 0.0536 - val_mean_absolute_error: 0.0536 - 143ms/epoch - 143ms/step
# Epoch 236/1000
# 1/1 - 0s - loss: 0.0342 - mean_absolute_error: 0.0342 - val_loss: 0.0538 - val_mean_absolute_error: 0.0538 - 171ms/epoch - 171ms/step
# Epoch 237/1000
# 1/1 - 0s - loss: 0.0340 - mean_absolute_error: 0.0340 - val_loss: 0.0546 - val_mean_absolute_error: 0.0546 - 165ms/epoch - 165ms/step
# Epoch 238/1000
# 1/1 - 0s - loss: 0.0348 - mean_absolute_error: 0.0348 - val_loss: 0.0533 - val_mean_absolute_error: 0.0533 - 144ms/epoch - 144ms/step
# Epoch 239/1000
# 1/1 - 0s - loss: 0.0349 - mean_absolute_error: 0.0349 - val_loss: 0.0536 - val_mean_absolute_error: 0.0536 - 166ms/epoch - 166ms/step
# Epoch 240/1000
# 1/1 - 0s - loss: 0.0351 - mean_absolute_error: 0.0351 - val_loss: 0.0526 - val_mean_absolute_error: 0.0526 - 147ms/epoch - 147ms/step
# Epoch 241/1000
# 1/1 - 0s - loss: 0.0353 - mean_absolute_error: 0.0353 - val_loss: 0.0527 - val_mean_absolute_error: 0.0527 - 172ms/epoch - 172ms/step
# Epoch 242/1000
# 1/1 - 0s - loss: 0.0329 - mean_absolute_error: 0.0329 - val_loss: 0.0528 - val_mean_absolute_error: 0.0528 - 145ms/epoch - 145ms/step
# Epoch 243/1000
# 1/1 - 0s - loss: 0.0334 - mean_absolute_error: 0.0334 - val_loss: 0.0533 - val_mean_absolute_error: 0.0533 - 165ms/epoch - 165ms/step
# Epoch 244/1000
# 1/1 - 0s - loss: 0.0347 - mean_absolute_error: 0.0347 - val_loss: 0.0534 - val_mean_absolute_error: 0.0534 - 168ms/epoch - 168ms/step
# Epoch 245/1000
# 1/1 - 0s - loss: 0.0353 - mean_absolute_error: 0.0353 - val_loss: 0.0520 - val_mean_absolute_error: 0.0520 - 149ms/epoch - 149ms/step
# Epoch 246/1000
# 1/1 - 0s - loss: 0.0340 - mean_absolute_error: 0.0340 - val_loss: 0.0515 - val_mean_absolute_error: 0.0515 - 166ms/epoch - 166ms/step
# Epoch 247/1000
# 1/1 - 0s - loss: 0.0337 - mean_absolute_error: 0.0337 - val_loss: 0.0523 - val_mean_absolute_error: 0.0523 - 142ms/epoch - 142ms/step
# Epoch 248/1000
# 1/1 - 0s - loss: 0.0341 - mean_absolute_error: 0.0341 - val_loss: 0.0532 - val_mean_absolute_error: 0.0532 - 165ms/epoch - 165ms/step
# Epoch 249/1000
# 1/1 - 0s - loss: 0.0360 - mean_absolute_error: 0.0360 - val_loss: 0.0535 - val_mean_absolute_error: 0.0535 - 167ms/epoch - 167ms/step
# Epoch 250/1000
# 1/1 - 0s - loss: 0.0350 - mean_absolute_error: 0.0350 - val_loss: 0.0520 - val_mean_absolute_error: 0.0520 - 165ms/epoch - 165ms/step
# Epoch 251/1000
# 1/1 - 0s - loss: 0.0334 - mean_absolute_error: 0.0334 - val_loss: 0.0523 - val_mean_absolute_error: 0.0523 - 140ms/epoch - 140ms/step
# Epoch 252/1000
# 1/1 - 0s - loss: 0.0340 - mean_absolute_error: 0.0340 - val_loss: 0.0539 - val_mean_absolute_error: 0.0539 - 144ms/epoch - 144ms/step
# Epoch 253/1000
# 1/1 - 0s - loss: 0.0363 - mean_absolute_error: 0.0363 - val_loss: 0.0538 - val_mean_absolute_error: 0.0538 - 167ms/epoch - 167ms/step
# Epoch 254/1000
# 1/1 - 0s - loss: 0.0370 - mean_absolute_error: 0.0370 - val_loss: 0.0522 - val_mean_absolute_error: 0.0522 - 143ms/epoch - 143ms/step
# Epoch 255/1000
# 1/1 - 0s - loss: 0.0328 - mean_absolute_error: 0.0328 - val_loss: 0.0532 - val_mean_absolute_error: 0.0532 - 146ms/epoch - 146ms/step
# Epoch 256/1000
# 1/1 - 0s - loss: 0.0371 - mean_absolute_error: 0.0371 - val_loss: 0.0530 - val_mean_absolute_error: 0.0530 - 145ms/epoch - 145ms/step
# Epoch 257/1000
# 1/1 - 0s - loss: 0.0361 - mean_absolute_error: 0.0361 - val_loss: 0.0512 - val_mean_absolute_error: 0.0512 - 146ms/epoch - 146ms/step
# Epoch 258/1000
# 1/1 - 0s - loss: 0.0343 - mean_absolute_error: 0.0343 - val_loss: 0.0550 - val_mean_absolute_error: 0.0550 - 145ms/epoch - 145ms/step
# Epoch 259/1000
# 1/1 - 0s - loss: 0.0383 - mean_absolute_error: 0.0383 - val_loss: 0.0529 - val_mean_absolute_error: 0.0529 - 146ms/epoch - 146ms/step
# Epoch 260/1000
# 1/1 - 0s - loss: 0.0332 - mean_absolute_error: 0.0332 - val_loss: 0.0540 - val_mean_absolute_error: 0.0540 - 146ms/epoch - 146ms/step
# Epoch 261/1000
# 1/1 - 0s - loss: 0.0376 - mean_absolute_error: 0.0376 - val_loss: 0.0516 - val_mean_absolute_error: 0.0516 - 167ms/epoch - 167ms/step
# Epoch 262/1000
# 1/1 - 0s - loss: 0.0351 - mean_absolute_error: 0.0351 - val_loss: 0.0508 - val_mean_absolute_error: 0.0508 - 166ms/epoch - 166ms/step
# Epoch 263/1000
# 1/1 - 0s - loss: 0.0324 - mean_absolute_error: 0.0324 - val_loss: 0.0527 - val_mean_absolute_error: 0.0527 - 142ms/epoch - 142ms/step
# Epoch 264/1000
# 1/1 - 0s - loss: 0.0349 - mean_absolute_error: 0.0349 - val_loss: 0.0529 - val_mean_absolute_error: 0.0529 - 147ms/epoch - 147ms/step
# Epoch 265/1000
# 1/1 - 0s - loss: 0.0345 - mean_absolute_error: 0.0345 - val_loss: 0.0515 - val_mean_absolute_error: 0.0515 - 167ms/epoch - 167ms/step
# Epoch 266/1000
# 1/1 - 0s - loss: 0.0332 - mean_absolute_error: 0.0332 - val_loss: 0.0512 - val_mean_absolute_error: 0.0512 - 166ms/epoch - 166ms/step
# Epoch 267/1000
# 1/1 - 0s - loss: 0.0343 - mean_absolute_error: 0.0343 - val_loss: 0.0517 - val_mean_absolute_error: 0.0517 - 165ms/epoch - 165ms/step
# Epoch 268/1000
# 1/1 - 0s - loss: 0.0345 - mean_absolute_error: 0.0345 - val_loss: 0.0507 - val_mean_absolute_error: 0.0507 - 144ms/epoch - 144ms/step
# Epoch 269/1000
# 1/1 - 0s - loss: 0.0332 - mean_absolute_error: 0.0332 - val_loss: 0.0513 - val_mean_absolute_error: 0.0513 - 166ms/epoch - 166ms/step
# Epoch 270/1000
# 1/1 - 0s - loss: 0.0336 - mean_absolute_error: 0.0336 - val_loss: 0.0521 - val_mean_absolute_error: 0.0521 - 146ms/epoch - 146ms/step
# Epoch 271/1000
# 1/1 - 0s - loss: 0.0336 - mean_absolute_error: 0.0336 - val_loss: 0.0516 - val_mean_absolute_error: 0.0516 - 143ms/epoch - 143ms/step
# Epoch 272/1000
# 1/1 - 0s - loss: 0.0333 - mean_absolute_error: 0.0333 - val_loss: 0.0503 - val_mean_absolute_error: 0.0503 - 148ms/epoch - 148ms/step
# Epoch 273/1000
# 1/1 - 0s - loss: 0.0330 - mean_absolute_error: 0.0330 - val_loss: 0.0508 - val_mean_absolute_error: 0.0508 - 166ms/epoch - 166ms/step
# Epoch 274/1000
# 1/1 - 0s - loss: 0.0333 - mean_absolute_error: 0.0333 - val_loss: 0.0519 - val_mean_absolute_error: 0.0519 - 169ms/epoch - 169ms/step
# Epoch 275/1000
# 1/1 - 0s - loss: 0.0337 - mean_absolute_error: 0.0337 - val_loss: 0.0519 - val_mean_absolute_error: 0.0519 - 143ms/epoch - 143ms/step
# Epoch 276/1000
# 1/1 - 0s - loss: 0.0329 - mean_absolute_error: 0.0329 - val_loss: 0.0505 - val_mean_absolute_error: 0.0505 - 143ms/epoch - 143ms/step
# Epoch 277/1000
# 1/1 - 0s - loss: 0.0326 - mean_absolute_error: 0.0326 - val_loss: 0.0498 - val_mean_absolute_error: 0.0498 - 167ms/epoch - 167ms/step
# Epoch 278/1000
# 1/1 - 0s - loss: 0.0333 - mean_absolute_error: 0.0333 - val_loss: 0.0522 - val_mean_absolute_error: 0.0522 - 167ms/epoch - 167ms/step
# Epoch 279/1000
# 1/1 - 0s - loss: 0.0331 - mean_absolute_error: 0.0331 - val_loss: 0.0512 - val_mean_absolute_error: 0.0512 - 145ms/epoch - 145ms/step
# Epoch 280/1000
# 1/1 - 0s - loss: 0.0335 - mean_absolute_error: 0.0335 - val_loss: 0.0506 - val_mean_absolute_error: 0.0506 - 143ms/epoch - 143ms/step
# Epoch 281/1000
# 1/1 - 0s - loss: 0.0324 - mean_absolute_error: 0.0324 - val_loss: 0.0486 - val_mean_absolute_error: 0.0486 - 147ms/epoch - 147ms/step
# Epoch 282/1000
# 1/1 - 0s - loss: 0.0327 - mean_absolute_error: 0.0327 - val_loss: 0.0498 - val_mean_absolute_error: 0.0498 - 168ms/epoch - 168ms/step
# Epoch 283/1000
# 1/1 - 0s - loss: 0.0322 - mean_absolute_error: 0.0322 - val_loss: 0.0522 - val_mean_absolute_error: 0.0522 - 164ms/epoch - 164ms/step
# Epoch 284/1000
# 1/1 - 0s - loss: 0.0325 - mean_absolute_error: 0.0325 - val_loss: 0.0502 - val_mean_absolute_error: 0.0502 - 171ms/epoch - 171ms/step
# Epoch 285/1000
# 1/1 - 0s - loss: 0.0327 - mean_absolute_error: 0.0327 - val_loss: 0.0486 - val_mean_absolute_error: 0.0486 - 165ms/epoch - 165ms/step
# Epoch 286/1000
# 1/1 - 0s - loss: 0.0327 - mean_absolute_error: 0.0327 - val_loss: 0.0495 - val_mean_absolute_error: 0.0495 - 167ms/epoch - 167ms/step
# Epoch 287/1000
# 1/1 - 0s - loss: 0.0328 - mean_absolute_error: 0.0328 - val_loss: 0.0518 - val_mean_absolute_error: 0.0518 - 141ms/epoch - 141ms/step
# Epoch 288/1000
# 1/1 - 0s - loss: 0.0324 - mean_absolute_error: 0.0324 - val_loss: 0.0509 - val_mean_absolute_error: 0.0509 - 166ms/epoch - 166ms/step
# Epoch 289/1000
# 1/1 - 0s - loss: 0.0316 - mean_absolute_error: 0.0316 - val_loss: 0.0498 - val_mean_absolute_error: 0.0498 - 146ms/epoch - 146ms/step
# Epoch 290/1000
# 1/1 - 0s - loss: 0.0332 - mean_absolute_error: 0.0332 - val_loss: 0.0514 - val_mean_absolute_error: 0.0514 - 145ms/epoch - 145ms/step
# Epoch 291/1000
# 1/1 - 0s - loss: 0.0331 - mean_absolute_error: 0.0331 - val_loss: 0.0517 - val_mean_absolute_error: 0.0517 - 143ms/epoch - 143ms/step
# Epoch 292/1000
# 1/1 - 0s - loss: 0.0342 - mean_absolute_error: 0.0342 - val_loss: 0.0513 - val_mean_absolute_error: 0.0513 - 168ms/epoch - 168ms/step
# Epoch 293/1000
# 1/1 - 0s - loss: 0.0333 - mean_absolute_error: 0.0333 - val_loss: 0.0480 - val_mean_absolute_error: 0.0480 - 168ms/epoch - 168ms/step
# Epoch 294/1000
# 1/1 - 0s - loss: 0.0331 - mean_absolute_error: 0.0331 - val_loss: 0.0482 - val_mean_absolute_error: 0.0482 - 167ms/epoch - 167ms/step
# Epoch 295/1000
# 1/1 - 0s - loss: 0.0319 - mean_absolute_error: 0.0319 - val_loss: 0.0495 - val_mean_absolute_error: 0.0495 - 145ms/epoch - 145ms/step
# Epoch 296/1000
# 1/1 - 0s - loss: 0.0316 - mean_absolute_error: 0.0316 - val_loss: 0.0489 - val_mean_absolute_error: 0.0489 - 147ms/epoch - 147ms/step
# Epoch 297/1000
# 1/1 - 0s - loss: 0.0336 - mean_absolute_error: 0.0336 - val_loss: 0.0502 - val_mean_absolute_error: 0.0502 - 169ms/epoch - 169ms/step
# Epoch 298/1000
# 1/1 - 0s - loss: 0.0335 - mean_absolute_error: 0.0335 - val_loss: 0.0499 - val_mean_absolute_error: 0.0499 - 147ms/epoch - 147ms/step
# Epoch 299/1000
# 1/1 - 0s - loss: 0.0319 - mean_absolute_error: 0.0319 - val_loss: 0.0498 - val_mean_absolute_error: 0.0498 - 144ms/epoch - 144ms/step
# Epoch 300/1000
# 1/1 - 0s - loss: 0.0318 - mean_absolute_error: 0.0318 - val_loss: 0.0472 - val_mean_absolute_error: 0.0472 - 145ms/epoch - 145ms/step
# Epoch 301/1000
# 1/1 - 0s - loss: 0.0323 - mean_absolute_error: 0.0323 - val_loss: 0.0491 - val_mean_absolute_error: 0.0491 - 168ms/epoch - 168ms/step
# Epoch 302/1000
# 1/1 - 0s - loss: 0.0332 - mean_absolute_error: 0.0332 - val_loss: 0.0507 - val_mean_absolute_error: 0.0507 - 170ms/epoch - 170ms/step
# Epoch 303/1000
# 1/1 - 0s - loss: 0.0333 - mean_absolute_error: 0.0333 - val_loss: 0.0480 - val_mean_absolute_error: 0.0480 - 168ms/epoch - 168ms/step
# Epoch 304/1000
# 1/1 - 0s - loss: 0.0310 - mean_absolute_error: 0.0310 - val_loss: 0.0484 - val_mean_absolute_error: 0.0484 - 144ms/epoch - 144ms/step
# Epoch 305/1000
# 1/1 - 0s - loss: 0.0318 - mean_absolute_error: 0.0318 - val_loss: 0.0502 - val_mean_absolute_error: 0.0502 - 164ms/epoch - 164ms/step
# Epoch 306/1000
# 1/1 - 0s - loss: 0.0330 - mean_absolute_error: 0.0330 - val_loss: 0.0512 - val_mean_absolute_error: 0.0512 - 142ms/epoch - 142ms/step
# Epoch 307/1000
# 1/1 - 0s - loss: 0.0336 - mean_absolute_error: 0.0336 - val_loss: 0.0464 - val_mean_absolute_error: 0.0464 - 167ms/epoch - 167ms/step
# Epoch 308/1000
# 1/1 - 0s - loss: 0.0331 - mean_absolute_error: 0.0331 - val_loss: 0.0478 - val_mean_absolute_error: 0.0478 - 143ms/epoch - 143ms/step
# Epoch 309/1000
# 1/1 - 0s - loss: 0.0312 - mean_absolute_error: 0.0312 - val_loss: 0.0515 - val_mean_absolute_error: 0.0515 - 153ms/epoch - 153ms/step
# Epoch 310/1000
# 1/1 - 0s - loss: 0.0329 - mean_absolute_error: 0.0329 - val_loss: 0.0507 - val_mean_absolute_error: 0.0507 - 166ms/epoch - 166ms/step
# Epoch 311/1000
# 1/1 - 0s - loss: 0.0315 - mean_absolute_error: 0.0315 - val_loss: 0.0465 - val_mean_absolute_error: 0.0465 - 166ms/epoch - 166ms/step
# Epoch 312/1000
# 1/1 - 0s - loss: 0.0331 - mean_absolute_error: 0.0331 - val_loss: 0.0477 - val_mean_absolute_error: 0.0477 - 144ms/epoch - 144ms/step
# Epoch 313/1000
# 1/1 - 0s - loss: 0.0327 - mean_absolute_error: 0.0327 - val_loss: 0.0492 - val_mean_absolute_error: 0.0492 - 143ms/epoch - 143ms/step
# Epoch 314/1000
# 1/1 - 0s - loss: 0.0327 - mean_absolute_error: 0.0327 - val_loss: 0.0530 - val_mean_absolute_error: 0.0530 - 147ms/epoch - 147ms/step
# Epoch 315/1000
# 1/1 - 0s - loss: 0.0338 - mean_absolute_error: 0.0338 - val_loss: 0.0516 - val_mean_absolute_error: 0.0516 - 144ms/epoch - 144ms/step
# Epoch 316/1000
# 1/1 - 0s - loss: 0.0318 - mean_absolute_error: 0.0318 - val_loss: 0.0495 - val_mean_absolute_error: 0.0495 - 166ms/epoch - 166ms/step
# Epoch 317/1000
# 1/1 - 0s - loss: 0.0329 - mean_absolute_error: 0.0329 - val_loss: 0.0491 - val_mean_absolute_error: 0.0491 - 141ms/epoch - 141ms/step
# Epoch 318/1000
# 1/1 - 0s - loss: 0.0351 - mean_absolute_error: 0.0351 - val_loss: 0.0478 - val_mean_absolute_error: 0.0478 - 166ms/epoch - 166ms/step
# Epoch 319/1000
# 1/1 - 0s - loss: 0.0323 - mean_absolute_error: 0.0323 - val_loss: 0.0497 - val_mean_absolute_error: 0.0497 - 167ms/epoch - 167ms/step
# Epoch 320/1000
# 1/1 - 0s - loss: 0.0316 - mean_absolute_error: 0.0316 - val_loss: 0.0495 - val_mean_absolute_error: 0.0495 - 166ms/epoch - 166ms/step
# Epoch 321/1000
# 1/1 - 0s - loss: 0.0316 - mean_absolute_error: 0.0316 - val_loss: 0.0474 - val_mean_absolute_error: 0.0474 - 166ms/epoch - 166ms/step
# Epoch 322/1000
# 1/1 - 0s - loss: 0.0316 - mean_absolute_error: 0.0316 - val_loss: 0.0486 - val_mean_absolute_error: 0.0486 - 166ms/epoch - 166ms/step
# Epoch 323/1000
# ...
# Epoch 474/1000
# 1/1 - 0s - loss: 0.0286 - mean_absolute_error: 0.0286 - val_loss: 0.0468 - val_mean_absolute_error: 0.0468 - 165ms/epoch - 165ms/step
# Epoch 475/1000
# 1/1 - 0s - loss: 0.0281 - mean_absolute_error: 0.0281 - val_loss: 0.0495 - val_mean_absolute_error: 0.0495 - 170ms/epoch - 170ms/step
# Epoch 476/1000
# 1/1 - 0s - loss: 0.0305 - mean_absolute_error: 0.0305 - val_loss: 0.0489 - val_mean_absolute_error: 0.0489 - 167ms/epoch - 167ms/step
# Epoch 477/1000
# 1/1 - 0s - loss: 0.0290 - mean_absolute_error: 0.0290 - val_loss: 0.0491 - val_mean_absolute_error: 0.0491 - 143ms/epoch - 143ms/step
# Epoch 478/1000
# 1/1 - 0s - loss: 0.0279 - mean_absolute_error: 0.0279 - val_loss: 0.0468 - val_mean_absolute_error: 0.0468 - 145ms/epoch - 145ms/step
# Epoch 479/1000
# 1/1 - 0s - loss: 0.0280 - mean_absolute_error: 0.0280 - val_loss: 0.0430 - val_mean_absolute_error: 0.0430 - 148ms/epoch - 148ms/step
# Epoch 480/1000
# 1/1 - 0s - loss: 0.0285 - mean_absolute_error: 0.0285 - val_loss: 0.0447 - val_mean_absolute_error: 0.0447 - 145ms/epoch - 145ms/step
# Epoch 481/1000
# 1/1 - 0s - loss: 0.0284 - mean_absolute_error: 0.0284 - val_loss: 0.0479 - val_mean_absolute_error: 0.0479 - 168ms/epoch - 168ms/step
# Epoch 482/1000
# 1/1 - 0s - loss: 0.0278 - mean_absolute_error: 0.0278 - val_loss: 0.0496 - val_mean_absolute_error: 0.0496 - 146ms/epoch - 146ms/step
# Epoch 483/1000
# 1/1 - 0s - loss: 0.0284 - mean_absolute_error: 0.0284 - val_loss: 0.0512 - val_mean_absolute_error: 0.0512 - 150ms/epoch - 150ms/step
# Epoch 484/1000
# 1/1 - 0s - loss: 0.0300 - mean_absolute_error: 0.0300 - val_loss: 0.0469 - val_mean_absolute_error: 0.0469 - 147ms/epoch - 147ms/step
# Epoch 485/1000
# 1/1 - 0s - loss: 0.0288 - mean_absolute_error: 0.0288 - val_loss: 0.0483 - val_mean_absolute_error: 0.0483 - 145ms/epoch - 145ms/step
# Epoch 486/1000
# 1/1 - 0s - loss: 0.0280 - mean_absolute_error: 0.0280 - val_loss: 0.0512 - val_mean_absolute_error: 0.0512 - 174ms/epoch - 174ms/step
# Epoch 487/1000
# 1/1 - 0s - loss: 0.0299 - mean_absolute_error: 0.0299 - val_loss: 0.0471 - val_mean_absolute_error: 0.0471 - 144ms/epoch - 144ms/step
# Epoch 488/1000
# 1/1 - 0s - loss: 0.0281 - mean_absolute_error: 0.0281 - val_loss: 0.0467 - val_mean_absolute_error: 0.0467 - 176ms/epoch - 176ms/step
# Epoch 489/1000
# 1/1 - 0s - loss: 0.0271 - mean_absolute_error: 0.0271 - val_loss: 0.0478 - val_mean_absolute_error: 0.0478 - 149ms/epoch - 149ms/step
# Epoch 490/1000
# 1/1 - 0s - loss: 0.0293 - mean_absolute_error: 0.0293 - val_loss: 0.0452 - val_mean_absolute_error: 0.0452 - 170ms/epoch - 170ms/step
# Epoch 491/1000
# 1/1 - 0s - loss: 0.0301 - mean_absolute_error: 0.0301 - val_loss: 0.0472 - val_mean_absolute_error: 0.0472 - 165ms/epoch - 165ms/step
# Epoch 492/1000
# 1/1 - 0s - loss: 0.0275 - mean_absolute_error: 0.0275 - val_loss: 0.0519 - val_mean_absolute_error: 0.0519 - 168ms/epoch - 168ms/step
# Epoch 493/1000
# 1/1 - 0s - loss: 0.0314 - mean_absolute_error: 0.0314 - val_loss: 0.0469 - val_mean_absolute_error: 0.0469 - 165ms/epoch - 165ms/step
# Epoch 494/1000
# 1/1 - 0s - loss: 0.0283 - mean_absolute_error: 0.0283 - val_loss: 0.0465 - val_mean_absolute_error: 0.0465 - 168ms/epoch - 168ms/step
# Epoch 495/1000
# 1/1 - 0s - loss: 0.0278 - mean_absolute_error: 0.0278 - val_loss: 0.0500 - val_mean_absolute_error: 0.0500 - 144ms/epoch - 144ms/step
# Epoch 496/1000
# 1/1 - 0s - loss: 0.0305 - mean_absolute_error: 0.0305 - val_loss: 0.0449 - val_mean_absolute_error: 0.0449 - 173ms/epoch - 173ms/step
# Epoch 497/1000
# 1/1 - 0s - loss: 0.0275 - mean_absolute_error: 0.0275 - val_loss: 0.0461 - val_mean_absolute_error: 0.0461 - 143ms/epoch - 143ms/step
# Epoch 498/1000
# 1/1 - 0s - loss: 0.0269 - mean_absolute_error: 0.0269 - val_loss: 0.0509 - val_mean_absolute_error: 0.0509 - 145ms/epoch - 145ms/step
# Epoch 499/1000
# 1/1 - 0s - loss: 0.0299 - mean_absolute_error: 0.0299 - val_loss: 0.0457 - val_mean_absolute_error: 0.0457 - 174ms/epoch - 174ms/step
# Epoch 500/1000
# 1/1 - 0s - loss: 0.0273 - mean_absolute_error: 0.0273 - val_loss: 0.0462 - val_mean_absolute_error: 0.0462 - 143ms/epoch - 143ms/step
# Epoch 501/1000
# 1/1 - 0s - loss: 0.0281 - mean_absolute_error: 0.0281 - val_loss: 0.0489 - val_mean_absolute_error: 0.0489 - 144ms/epoch - 144ms/step
# Epoch 502/1000
# 1/1 - 0s - loss: 0.0281 - mean_absolute_error: 0.0281 - val_loss: 0.0470 - val_mean_absolute_error: 0.0470 - 148ms/epoch - 148ms/step
# Epoch 503/1000
# 1/1 - 0s - loss: 0.0269 - mean_absolute_error: 0.0269 - val_loss: 0.0449 - val_mean_absolute_error: 0.0449 - 144ms/epoch - 144ms/step
# Epoch 504/1000
# 1/1 - 0s - loss: 0.0292 - mean_absolute_error: 0.0292 - val_loss: 0.0484 - val_mean_absolute_error: 0.0484 - 168ms/epoch - 168ms/step
# Epoch 505/1000
# 1/1 - 0s - loss: 0.0271 - mean_absolute_error: 0.0271 - val_loss: 0.0480 - val_mean_absolute_error: 0.0480 - 170ms/epoch - 170ms/step
# Epoch 506/1000
# 1/1 - 0s - loss: 0.0282 - mean_absolute_error: 0.0282 - val_loss: 0.0467 - val_mean_absolute_error: 0.0467 - 169ms/epoch - 169ms/step
# Epoch 507/1000
# 1/1 - 0s - loss: 0.0290 - mean_absolute_error: 0.0290 - val_loss: 0.0486 - val_mean_absolute_error: 0.0486 - 147ms/epoch - 147ms/step
# Epoch 508/1000
# 1/1 - 0s - loss: 0.0298 - mean_absolute_error: 0.0298 - val_loss: 0.0513 - val_mean_absolute_error: 0.0513 - 169ms/epoch - 169ms/step
# Epoch 509/1000
# 1/1 - 0s - loss: 0.0294 - mean_absolute_error: 0.0294 - val_loss: 0.0494 - val_mean_absolute_error: 0.0494 - 165ms/epoch - 165ms/step
# Epoch 510/1000
# 1/1 - 0s - loss: 0.0284 - mean_absolute_error: 0.0284 - val_loss: 0.0479 - val_mean_absolute_error: 0.0479 - 143ms/epoch - 143ms/step
# Epoch 511/1000
# 1/1 - 0s - loss: 0.0271 - mean_absolute_error: 0.0271 - val_loss: 0.0455 - val_mean_absolute_error: 0.0455 - 166ms/epoch - 166ms/step
# Epoch 512/1000
# 1/1 - 0s - loss: 0.0275 - mean_absolute_error: 0.0275 - val_loss: 0.0526 - val_mean_absolute_error: 0.0526 - 145ms/epoch - 145ms/step
# Epoch 513/1000
# 1/1 - 0s - loss: 0.0283 - mean_absolute_error: 0.0283 - val_loss: 0.0454 - val_mean_absolute_error: 0.0454 - 170ms/epoch - 170ms/step
# Epoch 514/1000
# 1/1 - 0s - loss: 0.0282 - mean_absolute_error: 0.0282 - val_loss: 0.0455 - val_mean_absolute_error: 0.0455 - 145ms/epoch - 145ms/step
# Epoch 515/1000
# 1/1 - 0s - loss: 0.0277 - mean_absolute_error: 0.0277 - val_loss: 0.0460 - val_mean_absolute_error: 0.0460 - 167ms/epoch - 167ms/step
# Epoch 516/1000
# 1/1 - 0s - loss: 0.0276 - mean_absolute_error: 0.0276 - val_loss: 0.0454 - val_mean_absolute_error: 0.0454 - 174ms/epoch - 174ms/step
# Epoch 517/1000
# 1/1 - 0s - loss: 0.0269 - mean_absolute_error: 0.0269 - val_loss: 0.0557 - val_mean_absolute_error: 0.0557 - 143ms/epoch - 143ms/step
# Epoch 518/1000
# 1/1 - 0s - loss: 0.0284 - mean_absolute_error: 0.0284 - val_loss: 0.0556 - val_mean_absolute_error: 0.0556 - 167ms/epoch - 167ms/step
# Epoch 519/1000
# 1/1 - 0s - loss: 0.0276 - mean_absolute_error: 0.0276 - val_loss: 0.0477 - val_mean_absolute_error: 0.0477 - 144ms/epoch - 144ms/step
# Epoch 520/1000
# 1/1 - 0s - loss: 0.0268 - mean_absolute_error: 0.0268 - val_loss: 0.0470 - val_mean_absolute_error: 0.0470 - 147ms/epoch - 147ms/step
# Epoch 521/1000
# 1/1 - 0s - loss: 0.0281 - mean_absolute_error: 0.0281 - val_loss: 0.0475 - val_mean_absolute_error: 0.0475 - 145ms/epoch - 145ms/step
# Epoch 522/1000
# 1/1 - 0s - loss: 0.0284 - mean_absolute_error: 0.0284 - val_loss: 0.0460 - val_mean_absolute_error: 0.0460 - 170ms/epoch - 170ms/step
# Epoch 523/1000
# 1/1 - 0s - loss: 0.0278 - mean_absolute_error: 0.0278 - val_loss: 0.0466 - val_mean_absolute_error: 0.0466 - 144ms/epoch - 144ms/step
# Epoch 524/1000
# 1/1 - 0s - loss: 0.0272 - mean_absolute_error: 0.0272 - val_loss: 0.0455 - val_mean_absolute_error: 0.0455 - 145ms/epoch - 145ms/step
# Epoch 525/1000
# 1/1 - 0s - loss: 0.0273 - mean_absolute_error: 0.0273 - val_loss: 0.0456 - val_mean_absolute_error: 0.0456 - 170ms/epoch - 170ms/step
# Epoch 526/1000
# 1/1 - 0s - loss: 0.0266 - mean_absolute_error: 0.0266 - val_loss: 0.0478 - val_mean_absolute_error: 0.0478 - 168ms/epoch - 168ms/step
# Epoch 527/1000
# 1/1 - 0s - loss: 0.0271 - mean_absolute_error: 0.0271 - val_loss: 0.0456 - val_mean_absolute_error: 0.0456 - 142ms/epoch - 142ms/step
# Epoch 528/1000
# 1/1 - 0s - loss: 0.0273 - mean_absolute_error: 0.0273 - val_loss: 0.0465 - val_mean_absolute_error: 0.0465 - 170ms/epoch - 170ms/step
# Epoch 529/1000
# 1/1 - 0s - loss: 0.0262 - mean_absolute_error: 0.0262 - val_loss: 0.0475 - val_mean_absolute_error: 0.0475 - 143ms/epoch - 143ms/step
# Epoch 530/1000
# 1/1 - 0s - loss: 0.0269 - mean_absolute_error: 0.0269 - val_loss: 0.0450 - val_mean_absolute_error: 0.0450 - 149ms/epoch - 149ms/step
# Epoch 531/1000
# 1/1 - 0s - loss: 0.0277 - mean_absolute_error: 0.0277 - val_loss: 0.0451 - val_mean_absolute_error: 0.0451 - 167ms/epoch - 167ms/step
# Epoch 532/1000
# 1/1 - 0s - loss: 0.0274 - mean_absolute_error: 0.0274 - val_loss: 0.0540 - val_mean_absolute_error: 0.0540 - 165ms/epoch - 165ms/step
# Epoch 533/1000
# 1/1 - 0s - loss: 0.0273 - mean_absolute_error: 0.0273 - val_loss: 0.0468 - val_mean_absolute_error: 0.0468 - 165ms/epoch - 165ms/step
# Epoch 534/1000
# 1/1 - 0s - loss: 0.0259 - mean_absolute_error: 0.0259 - val_loss: 0.0503 - val_mean_absolute_error: 0.0503 - 168ms/epoch - 168ms/step
# Epoch 535/1000
# 1/1 - 0s - loss: 0.0268 - mean_absolute_error: 0.0268 - val_loss: 0.0489 - val_mean_absolute_error: 0.0489 - 145ms/epoch - 145ms/step
# Epoch 536/1000
# 1/1 - 0s - loss: 0.0268 - mean_absolute_error: 0.0268 - val_loss: 0.0465 - val_mean_absolute_error: 0.0465 - 167ms/epoch - 167ms/step
# Epoch 537/1000
# 1/1 - 0s - loss: 0.0284 - mean_absolute_error: 0.0284 - val_loss: 0.0467 - val_mean_absolute_error: 0.0467 - 145ms/epoch - 145ms/step
# Epoch 538/1000
# 1/1 - 0s - loss: 0.0271 - mean_absolute_error: 0.0271 - val_loss: 0.0510 - val_mean_absolute_error: 0.0510 - 169ms/epoch - 169ms/step
# Epoch 539/1000
# 1/1 - 0s - loss: 0.0272 - mean_absolute_error: 0.0272 - val_loss: 0.0510 - val_mean_absolute_error: 0.0510 - 143ms/epoch - 143ms/step
# Epoch 540/1000
# 1/1 - 0s - loss: 0.0285 - mean_absolute_error: 0.0285 - val_loss: 0.0502 - val_mean_absolute_error: 0.0502 - 172ms/epoch - 172ms/step
# Epoch 541/1000
# 1/1 - 0s - loss: 0.0265 - mean_absolute_error: 0.0265 - val_loss: 0.0487 - val_mean_absolute_error: 0.0487 - 145ms/epoch - 145ms/step
# Epoch 542/1000
# 1/1 - 0s - loss: 0.0268 - mean_absolute_error: 0.0268 - val_loss: 0.0468 - val_mean_absolute_error: 0.0468 - 174ms/epoch - 174ms/step
# Epoch 543/1000
# 1/1 - 0s - loss: 0.0275 - mean_absolute_error: 0.0275 - val_loss: 0.0471 - val_mean_absolute_error: 0.0471 - 143ms/epoch - 143ms/step
# Epoch 544/1000
# 1/1 - 0s - loss: 0.0266 - mean_absolute_error: 0.0266 - val_loss: 0.0481 - val_mean_absolute_error: 0.0481 - 169ms/epoch - 169ms/step
# Epoch 545/1000
# 1/1 - 0s - loss: 0.0281 - mean_absolute_error: 0.0281 - val_loss: 0.0483 - val_mean_absolute_error: 0.0483 - 165ms/epoch - 165ms/step
# Epoch 546/1000
# 1/1 - 0s - loss: 0.0272 - mean_absolute_error: 0.0272 - val_loss: 0.0477 - val_mean_absolute_error: 0.0477 - 168ms/epoch - 168ms/step
# Epoch 547/1000
# 1/1 - 0s - loss: 0.0262 - mean_absolute_error: 0.0262 - val_loss: 0.0492 - val_mean_absolute_error: 0.0492 - 164ms/epoch - 164ms/step
# Epoch 548/1000
# 1/1 - 0s - loss: 0.0262 - mean_absolute_error: 0.0262 - val_loss: 0.0477 - val_mean_absolute_error: 0.0477 - 170ms/epoch - 170ms/step
# Epoch 549/1000
# 1/1 - 0s - loss: 0.0275 - mean_absolute_error: 0.0275 - val_loss: 0.0484 - val_mean_absolute_error: 0.0484 - 168ms/epoch - 168ms/step
# Epoch 550/1000
# 1/1 - 0s - loss: 0.0270 - mean_absolute_error: 0.0270 - val_loss: 0.0457 - val_mean_absolute_error: 0.0457 - 168ms/epoch - 168ms/step
# Epoch 551/1000
# 1/1 - 0s - loss: 0.0277 - mean_absolute_error: 0.0277 - val_loss: 0.0459 - val_mean_absolute_error: 0.0459 - 164ms/epoch - 164ms/step
# Epoch 552/1000
# 1/1 - 0s - loss: 0.0268 - mean_absolute_error: 0.0268 - val_loss: 0.0478 - val_mean_absolute_error: 0.0478 - 145ms/epoch - 145ms/step
# Epoch 553/1000
# 1/1 - 0s - loss: 0.0267 - mean_absolute_error: 0.0267 - val_loss: 0.0466 - val_mean_absolute_error: 0.0466 - 171ms/epoch - 171ms/step
# Epoch 554/1000
# 1/1 - 0s - loss: 0.0275 - mean_absolute_error: 0.0275 - val_loss: 0.0479 - val_mean_absolute_error: 0.0479 - 168ms/epoch - 168ms/step
# Epoch 555/1000
# 1/1 - 0s - loss: 0.0263 - mean_absolute_error: 0.0263 - val_loss: 0.0500 - val_mean_absolute_error: 0.0500 - 166ms/epoch - 166ms/step
# Epoch 556/1000
# 1/1 - 0s - loss: 0.0267 - mean_absolute_error: 0.0267 - val_loss: 0.0508 - val_mean_absolute_error: 0.0508 - 145ms/epoch - 145ms/step
# Epoch 557/1000
# 1/1 - 0s - loss: 0.0283 - mean_absolute_error: 0.0283 - val_loss: 0.0585 - val_mean_absolute_error: 0.0585 - 167ms/epoch - 167ms/step
# Epoch 558/1000
# 1/1 - 0s - loss: 0.0270 - mean_absolute_error: 0.0270 - val_loss: 0.0581 - val_mean_absolute_error: 0.0581 - 167ms/epoch - 167ms/step
# Epoch 559/1000
# 1/1 - 0s - loss: 0.0268 - mean_absolute_error: 0.0268 - val_loss: 0.0453 - val_mean_absolute_error: 0.0453 - 146ms/epoch - 146ms/step
# Epoch 560/1000
# 1/1 - 0s - loss: 0.0259 - mean_absolute_error: 0.0259 - val_loss: 0.0478 - val_mean_absolute_error: 0.0478 - 147ms/epoch - 147ms/step
# Epoch 561/1000
# 1/1 - 0s - loss: 0.0262 - mean_absolute_error: 0.0262 - val_loss: 0.0488 - val_mean_absolute_error: 0.0488 - 166ms/epoch - 166ms/step
# Epoch 562/1000
# 1/1 - 0s - loss: 0.0255 - mean_absolute_error: 0.0255 - val_loss: 0.0482 - val_mean_absolute_error: 0.0482 - 169ms/epoch - 169ms/step
# Epoch 563/1000
# 1/1 - 0s - loss: 0.0270 - mean_absolute_error: 0.0270 - val_loss: 0.0490 - val_mean_absolute_error: 0.0490 - 146ms/epoch - 146ms/step
# Epoch 564/1000
# 1/1 - 0s - loss: 0.0259 - mean_absolute_error: 0.0259 - val_loss: 0.0477 - val_mean_absolute_error: 0.0477 - 172ms/epoch - 172ms/step
# Epoch 565/1000
# 1/1 - 0s - loss: 0.0260 - mean_absolute_error: 0.0260 - val_loss: 0.0473 - val_mean_absolute_error: 0.0473 - 169ms/epoch - 169ms/step
# Epoch 566/1000
# 1/1 - 0s - loss: 0.0263 - mean_absolute_error: 0.0263 - val_loss: 0.0500 - val_mean_absolute_error: 0.0500 - 148ms/epoch - 148ms/step
# Epoch 567/1000
# 1/1 - 0s - loss: 0.0258 - mean_absolute_error: 0.0258 - val_loss: 0.0481 - val_mean_absolute_error: 0.0481 - 148ms/epoch - 148ms/step
# Epoch 568/1000
# 1/1 - 0s - loss: 0.0270 - mean_absolute_error: 0.0270 - val_loss: 0.0484 - val_mean_absolute_error: 0.0484 - 168ms/epoch - 168ms/step
# Epoch 569/1000
# 1/1 - 0s - loss: 0.0261 - mean_absolute_error: 0.0261 - val_loss: 0.0494 - val_mean_absolute_error: 0.0494 - 144ms/epoch - 144ms/step
# Epoch 570/1000
# 1/1 - 0s - loss: 0.0263 - mean_absolute_error: 0.0263 - val_loss: 0.0461 - val_mean_absolute_error: 0.0461 - 147ms/epoch - 147ms/step
# Epoch 571/1000
# 1/1 - 0s - loss: 0.0268 - mean_absolute_error: 0.0268 - val_loss: 0.0467 - val_mean_absolute_error: 0.0467 - 145ms/epoch - 145ms/step
# Epoch 572/1000
# 1/1 - 0s - loss: 0.0255 - mean_absolute_error: 0.0255 - val_loss: 0.0486 - val_mean_absolute_error: 0.0486 - 144ms/epoch - 144ms/step
# Epoch 573/1000
# 1/1 - 0s - loss: 0.0257 - mean_absolute_error: 0.0257 - val_loss: 0.0464 - val_mean_absolute_error: 0.0464 - 168ms/epoch - 168ms/step
# Epoch 574/1000
# 1/1 - 0s - loss: 0.0257 - mean_absolute_error: 0.0257 - val_loss: 0.0484 - val_mean_absolute_error: 0.0484 - 144ms/epoch - 144ms/step
# Epoch 575/1000
# 1/1 - 0s - loss: 0.0273 - mean_absolute_error: 0.0273 - val_loss: 0.0468 - val_mean_absolute_error: 0.0468 - 165ms/epoch - 165ms/step
# Epoch 576/1000
# 1/1 - 0s - loss: 0.0268 - mean_absolute_error: 0.0268 - val_loss: 0.0491 - val_mean_absolute_error: 0.0491 - 167ms/epoch - 167ms/step
# Epoch 577/1000
# 1/1 - 0s - loss: 0.0250 - mean_absolute_error: 0.0250 - val_loss: 0.0503 - val_mean_absolute_error: 0.0503 - 166ms/epoch - 166ms/step
# Epoch 578/1000
# 1/1 - 0s - loss: 0.0258 - mean_absolute_error: 0.0258 - val_loss: 0.0504 - val_mean_absolute_error: 0.0504 - 145ms/epoch - 145ms/step
# Epoch 579/1000
# Restoring model weights from the end of the best epoch: 479.
# 1/1 - 0s - loss: 0.0261 - mean_absolute_error: 0.0261 - val_loss: 0.0497 - val_mean_absolute_error: 0.0497 - 155ms/epoch - 155ms/step
# Epoch 579: early stopping

# %%
# Loss Curve
import matplotlib.pyplot as plt
from matplotlib import pyplot
pyplot.plot(history.history['loss'][:], label='train')
pyplot.plot(history.history['val_loss'][:], label='test')
pyplot.legend()
pyplot.show()

# %%
# prediction
yhat_test = model.predict(X_test)
yhat_train = model.predict(X_train)
# Out:
# 35/35 [==============================] - 1s 10ms/step
# 35/35 [==============================] - 0s 7ms/step

# %%
# Evaluating the residual error using Nash-Sutcliffe and denormalization
def nse(predictions, targets):
    return (1-(np.sum((predictions-targets)**2)/np.sum((targets-np.mean(targets))**2)))
inv_yhat_train = inv_yhat(yhat_train)
inv_yhat_test = inv_yhat(yhat_test)
inv_y_train = inv_y(y_train)
inv_y_test = inv_y(y_test)
print("train",nse(np.array(inv_yhat_train),np.array(inv_y_train)))
print("test",nse(np.array(inv_yhat_test),np.array(inv_y_test)))
# Out:
# train 0.4346877726410239
# test 0.35021615615191504

# %%
# Adding Simulated residual error in the data frame
df= pd.read_csv("/content/drive/MyDrive/Data/FourYearResidualErrorModelling.csv",index_col=0)
df=df[365:].reset_index(drop=True)
df.loc[:,"SimulatedResidualError"]=df.loc[:,"Residual Error"]
df.loc[365:,"SimulatedResidualError"]=inv_yhat_train+inv_yhat_test

# %%
# Data Frame
df
# Out:
#             Date  Temperature (Deg C)  Precipitation (mm)  \
# 0     2004-01-01                12.50                 0.0
# 1     2004-01-02                12.20                 0.0
# 2     2004-01-03                12.25                 0.0
# 3     2004-01-04                12.25                 0.0
# 4     2004-01-05                13.50                 0.0
# ...          ...                  ...                 ...
# 2552  2010-12-27                14.85                 0.0
# 2553  2010-12-28                14.85                 0.0
# 2554  2010-12-29                15.50                 0.0
# 2555  2010-12-30                15.60                 0.0
# 2556  2010-12-31                12.75                 0.0
#
#       Observed Discharge (m3/s)  Simulated Discharge (m3/s)  \
# 0                          53.1                      272.09
# 1                          52.4                      295.06
# 2                          51.3                      177.75
# 3                          50.3                      175.05
# 4                          49.6                      167.57
# ...                         ...                         ...
# 2552                       74.0                       67.91
# 2553                       67.1                       67.59
# 2554                       67.9                       67.27
# 2555                       64.3                       66.95
# 2556                       55.9                       66.65
#
#       Precipitation0816 (mm)  Temperature0816 (Deg C)  Residual Error  \
# 0                        0.0                     6.00         -218.99
# 1                        0.0                     6.50         -242.66
# 2                        0.0                     5.00         -126.45
# 3                        6.0                     5.25         -124.75
# 4                        0.0                     7.00         -117.97
# ...                      ...                      ...             ...
# 2552                     0.0                     2.00            6.09
# 2553                     0.0                     2.00           -0.49
# 2554                     0.0                     2.20            0.63
# 2555                     0.0                     2.50           -2.65
# 2556                     0.0                     1.75          -10.75
#
#       SimulatedResidualError
# 0                -218.990000
# 1                -242.660000
# 2                -126.450000
# 3                -124.750000
# 4                -117.970000
# ...                      ...
# 2552               -7.957282
# 2553               -8.273242
# 2554               -8.453224
# 2555               -8.468565
# 2556               -9.299071
#
# [2557 rows x 9 columns]

# %%
# Training Plot
import matplotlib.pyplot as plt
plt.plot(inv_y_train[:])
plt.plot(inv_yhat_train[:])

# %%
# Testing plot
import matplotlib.pyplot as plt
plt.plot(inv_y_test[:])
plt.plot(inv_yhat_test[:])
